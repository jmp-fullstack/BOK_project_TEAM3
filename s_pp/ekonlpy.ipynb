# %%
# pip install pandas

# %%
# pip install ekonlpy

# %%
# 뉴스
news_pattern = ['\[.*\]','(?<=[가-힣])\.','\w{4,}\@[a-zA-Z0-9\-]{2,}\.[a-z]{2,}(\.[a-z]{2})?','....기자']

# 채권 보고서
bone_pattern = []

text = '"이종우 아이엠투자증권 리서치센터장은 11일 한국은행 금융통화위원회가 기준금리를 인하한 데 대해 \"증시에 주는 영향은\
극히 미미할 것\"이라고 말했다.  이 센터장은 \"대부분이 금리인하를 예상한 상황이기 때문에 시장에 미치는 영향은 적을 수밖에 없다\"며 \"이날 건설·증권 등 일부 업종이 수혜\
기대감에 주가가 오르지만 금리인하가 발표된 오늘 이후에는 큰 영향을 주지 못할 것\"이라고 밝혔다.  또 \"이미 시중금리는 사상 최저치를 기록하는 등 금리인하 기대감\
은 시장에 다 반영이 된 상태\"라며 \"주식시장 뿐 아니라 채권시장에도 호재는 아니다\"라고 설명했다.  이날 한국은행 금통위는 지난 7월 이후 3개월만에 기준금리\
를 종전 연 3%에서 2.75%로 0.25%포인트 낮췄다. 기준금리가 2%대로 떨어진 것은 지난해 2월(2.75%) 이후 20개월만이다.  이 센터장은 \"이번 금리인하가 채권\
시장에는 다소 영향을 줄 수 있을 것\"이라며 \"하지만 기준금리 인하 이후 발행되는 물량의 매력이 줄어드는 만큼 신규 고객자산의 채권시장 유입이 줄어들 수 있어 채권시장에도\
호재는 아니다\"라고 분석했다.  이어 \"기준금리 인하는 그만큼 경기가 좋지 않다는 상황을 반영하는 것\"이라며 \"빠르면 올 12월 중에, 늦어도 내년 상반기나 1분기 중에 1회 정도\
금리 추가인하가 예상된다\"고 내다봤다.  하지만 기준금리 인하를 너무 부정적으로 볼 필요는 없다는 의견도 내놨다. 이 센터장은 \"세계적으로 금리가 낮은 상태여서 (우리가) 기준금리를\
인하하더라도 큰 부담은 없다\"며 \"(주요국에 비해) 아직 금리를 추가로 인하할 여지가 있다\"고 평가했다."'

# 특정패턴 제거
import re
for pattern in news_pattern :
    text = re.sub(pattern, '', text)
print(text)

# 위에는 품사 태깅전에 돌려야하는것


# korean stop words 불러오기
stopwords_path = 'korean_sotp_words.txt'
stopwords = []
with open(stopwords_path, 'r', encoding='utf-8') as file:
    for line in file:
        stopwords.append(line.strip())



print(stopwords)  # 불용어 모음
word = []
for tag in text: #토큰화된 text
    if tag[1] not in stopwords:
        if tag[0] not in stopwords:
            word.append(tag[0])
# Out:
# "이종우 아이엠투자증권 리서치센터장은 11 한국은행 금융통화위원회가 기준금리를 인하한 데 대해 "증시에 주는 영향은극히 미미할 것"이라고 말했다  이 센터장은 "대부분이 금리인하를 예상한 상황이기 때문에 시장에 미치는 영향은 적을 수밖에 없다"며 "이날 건설·증권 등 부 업종이 수혜기대감에 주가가 오르지만 금리인하가 발표된 오늘 이후에는 큰 영향을 주지 못할 것"이라고 밝혔다  또 "이미 시중금리는 사상 최저치를 기록하는 등 금리인하 기대감은 시장에 다 반영이 된 상태"라며 "주식시장 뿐 아니라 채권시장에도 호재는 아니다"라고 설명했다  이날 한국은행 금통위는 지난 7 이후 3개만에 기준금리를 종전 연 3%에서 2.75%로 0.25%포인트 낮췄다 기준금리가 2%대로 떨어진 것은 지난해 2(2.75%) 이후 20개만이다  이 센터장은 "이번 금리인하가 채권시장에는 다소 영향을 줄 수 있을 것"이라며 "하지만 기준금리 인하 이후 발행되는 물량의 매력이 줄어드는 만큼 신규 고객자산의 채권시장 유입이 줄어들 수 있어 채권시장에도호재는 아니다"라고 분석했다  이어 "기준금리 인하는 그만큼 경기가 좋지 않다는 상황을 반영하는 것"이라며 "빠르면 올 12 중에, 늦어도 내년 상반기나 1분기 중에 1회 정도금리 추가인하가 예상된다"고 내다봤다  하지만 기준금리 인하를 너무 부정적으로 볼 필요는 없다는 의견도 내놨다 이 센터장은 "세계적으로 금리가 낮은 상태여서 (우리가) 기준금리를인하하더라도 큰 부담은 없다"며 "(주요국에 비해) 아직 금리를 추가로 인하할 여지가 있다"고 평가했다"
# ...

# %%
import numpy as np
import pandas as pd
from gensim.models import Word2Vec
from gensim.models.phrases import Phrases, Phraser
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import os
from collections import Counter

# %%
from konlpy.tag import Mecab
mecab = Mecab(dicpath=r"C:\mecab\mecab-ko-dic")

# %%
import konlpy as kn
import MeCab as mc
import ekonlpy as ek
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from ekonlpy.tag import Mecab
from ekonlpy.sentiment import MPCK

# %%
money_path = '/crawl/crawl_result/moneytoday.json'
try :
    with open(money_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    print(lines)
except :
    print('오류발생')
# Out:
# 오류발생

# %%
df = pd.read_json(money_path)

# %%
for i in range(len(df['content'])): 
    print(df['content'][i])
    print(df['token'][i])
# Out:
# 원/달러 환율이 스페인의 신용등급 하락과 기준금리 인하로 상승하고 있다.  11일 서울외환시장에서 원/달러 환율은 오전 10시11분 현재 전날 종가 보다 1.85원 오른 1116.45원에 거래되고 있다.   전날(현지시간) 국제신용평가사인 스탠더드앤드푸어스(S&P)가 스페인의 국가신용등급을 'BBB+'에서 'BBB-'로 2단계 낮춰 세계 증시와 유로화가 하락했고 환율 상승을 부추겼다.  아울러 금융통화위원회의 기준금리 인하도 환율 상승 요인으로 작용하고 있다. 금통위는 이날 오전 기준금리를 연 3%에서 2.75%로 인하했다.   다만 중고업체의 네고(달러 매도)물량들이 쏟아지면서 상승폭은 제한적이다.   외환시장 한 전문가는 "금통위의 기준금리 인하로 환율은 상승 압력을 받겠지만 이미 시장에 일정 부분 반영 돼 있어 상승폭은 제한적일 것"이라고 전망했다.  이 전문가는 오늘 원/달러 환율은 1112원~1118원에서 거래될 것으로 내다봤다.
# 달러/NNG.신용등급/NNG.하락/NNG.금리/NNG.인하/NNG.상승/NNG.하/XSV.외환시장/NNG.원달러/NNG.종가/NNG.보다/MAG.오르/VV.거래/NNG.되/XSV.현지/NNG.국제/NNG.s&p/NNG.국가/NNG.신용등급/NNG.낮/VV.세계/NNG.증시/NNG.유로/NNG.하락/NNG.하/VV.환율/NNG.상승/NNG.부추기/VV.아울러/MAG.금리/NNG.인하/NNG.환율/NNG.상승/NNG.요인/NNG.작용/NNG.하/XSV.금리/NNG.연/VV.인하/NNG.하/VV.중고/NNG.업체/NNG.네고/NNG.달러/NNG.매도/NNG.물량/NNG.쏟/VV.상승/NNG.제한적/VAX.외환시장/NNG.금리/NNG.인하/NNG.환율/NNG.상승/NNG.압력/NNG.받/VV.이미/MAG.시장/NNG.반영/NNG.되/VV.상승/NNG.제한적/VAX.전망/NNG.하/VV.달러/NNG.거래/NNG.되/VV.보/VV
# ...

# %%
# Out:
#          date                                        title  \
# 20 2019-08-01                10년만에 돈줄 푸는 美…세계 금리인하 흐름 강해진다
# 19 2019-08-01                우아한형제들, 자영업자 대상 우대금리 대출상품 만든다
# 18 2019-08-01  [인베스팅닷컴 펄스] 美 증시 주요 이슈는? JP 모건, 금리인하… 주가 상승
# 17 2019-08-01       [예민수의 예각(예리한 시각)] 이번 금리인하는 중간 조정일 뿐이다?
# 16 2019-08-01                  [Asia오전]고대하던 美금리 인하에도 투심 악화
# 14 2019-08-01                    한미금리차 부담덜었다…이주열 "국내상황 대응"
# 13 2019-08-01         [굿모닝 인베스팅닷컴] 연준, 금리인하… 트럼프 대통령 반응 주목
# 12 2016-01-16         아파트담보대출금리비교 사이트로 주택매매잔금 및 후순위담보대출 확인
# 10 2016-01-15         '외환은행 금리조작사건' 전·현직 임직원들 1심서 '무죄'(종합)
# 11 2016-01-12             주거래은행 아니어도 최저금리? 아파트담보대출 금리비교 활용
# 8  2012-11-22                   [채권마감]금리 상승…"이슈 연동 박스권 흐름"
# 9  2012-11-21                      커버드본드가 뭐지?..저금리 시대 투자대안
# 15 2012-11-21                      [채권마감]금리 꽁꽁…美 풀리면 EU 꼬여
# 6  2012-11-20                   佛 CDS, 한 달 고점으로 상승…국채 금리도↑
# 4  2012-11-20                           터키, 기준금리 5.75%로 동결
# ...

# %%
mpck = MPCK()
df = pd.read_json("test_news.json")
df = df.sort_values(by=["date"], ascending=False)
# 데이터프레임 확인
df['token']=""
df['ngram']="" 
for i, row in df.iterrows() :
    tmp_df = df['content']
    tokens = mpck.tokenize(tmp_df[i])
    row['token'] = '.'.join(tokens)
    df.loc[i, 'token'] = row['token']
    print("success")
    if i % 100 == 0 :
        print('{}/{} : 성공'.format(i, df.shape[0]))
df.to_csv("news_test.csv", mode='w')
# Out:
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# 0/21 : 성공

# %%
text = df['token'][0]
# 텍스트를 공백을 기준으로 분할하여 토큰으로 만듭니다.
tokens = text.split('.')

# 각 토큰의 출현 빈도를 계산합니다.
token_counter = Counter(tokens)

# 결과를 출력합니다.
print(token_counter)
# Out:
# Counter({'금리/NNG': 26, '하/VV': 9, '오르/VV': 8, '대출/NNG': 6, '국고채/NNG': 6, 'fed/NNG': 4, '되/VV': 4, '금융채/NNG': 4, '은행/NNG': 3, '주택담보대출/NNG': 3, '영향/NNG': 3, '동결/NNG': 2, '신호/NNG': 2, '고금리/NNG': 2, '기조/NNG': 2, '전망/NNG': 2, '따르/VV': 2, '변동/NNG': 2, '상하단/NNG': 2, '고정/NNG': 2, '현지/NNG': 2, '유지/NNG': 2, '지속/NNG': 2, '수준/NNG': 2, '하/XSV': 2, '미/NNG': 2, '가장/MAG': 2, '높/VA': 2, '기록/NNG': 2, '외형/NNG': 2, '경쟁/NNG': 2, '매파/NNG': 1, '당분간/MAG': 1, '이어지/VV': 1, '금융/NNG': 1, '국민/NNG': 1, '농협/NNG': 1, '비해/VV': 1, '구간/NNG': 1, '포인트/NNG': 1, '같/VA': 1, '뛰/VV': 1, '장기/NNG': 1, '가능성/NNG': 1, '채권/NNG': 1, '연/VV': 1, '긴축/NNG': 1, '보내/VV': 1, '인플레이션/NNG': 1, '목표/NNG': 1, '안정화/NNG': 1, '확신/NNG': 1, '들/VV': 1, '때/NNG': 1, '긴축정책/NNG': 1, '적절/NNG': 1, '판단/NNG': 1, '추가/NNG': 1, '준비/NNG': 1, '들썩이/VV': 1, '국채/NNG': 1, '고시금리/NNG': 1, '연고점/NNG': 1, '모두/MAG': 1, '경신/NNG': 1, '줘/VV': 1, '끌어올린다/VV': 1, '신용/NNG': 1, '주로/MAG': 1, '주/VV': 1, '무보증/NNG': 1, '기준/NNG': 1, '최고/NNG': 1, '준거/NNG': 1, '최고점/NNG': 1, '은행채/NNG': 1,
# ...

# %%
counter = df['token'][0].Counter()
counter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 counter = df['token'][0].Counter()
#       2 counter
#
# AttributeError: 'str' object has no attribute 'Counter'

# %%
t = 'teted.안녕/efioj.하세/dea.요/de.수'

a = t.split('/')
for b in a:
    # print(b)
    c = b.split('.')[1]
    print(c)
# Out:
# 안녕
# 하세
# 요
# 수

# %%
len(df['token'])
# Out:
# 17

# %%
temp = []
for j in range(0,len(df['token'])):
    a = df['token'][j].split('/')
    print(a)
    for i in a :
        b = i.split('.')
        temp.append(b[-1])
    print(b)
# Out:
# ['fed', 'NNG.fed', 'NNG.금리', 'NNG.동결', 'NNG.하', 'VV.매파', 'NNG.신호', 'NNG.대출', 'NNG.금리', 'NNG.당분간', 'MAG.고금리', 'NNG.기조', 'NNG.이어지', 'VV.전망', 'NNG.금융', 'NNG.따르', 'VV.은행', 'NNG.국민', 'NNG.농협', 'NNG.주택담보대출', 'NNG.변동', 'NNG.금리', 'NNG.비해', 'VV.금리', 'NNG.구간', 'NNG.상하단', 'NNG.포인트', 'NNG.오르', 'VV.같', 'VA.고정', 'NNG.금리', 'NNG.상하단', 'NNG.뛰', 'VV.대출', 'NNG.금리', 'NNG.오르', 'VV.고금리', 'NNG.장기', 'NNG.가능성', 'NNG.채권', 'NNG.금리', 'NNG.오르', 'VV.fed', 'NNG.현지', 'NNG.금리', 'NNG.연', 'VV.동결', 'NNG.하', 'VV.긴축', 'NNG.기조', 'NNG.유지', 'NNG.하', 'VV.신호', 'NNG.지속', 'NNG.보내', 'VV.fed', 'NNG.인플레이션', 'NNG.목표', 'NNG.수준', 'NNG.안정화', 'NNG.되', 'VV.확신', 'NNG.들', 'VV.때', 'NNG.긴축정책', 'NNG.유지', 'NNG.하', 'VV.적절', 'NNG.판단', 'NNG.하', 'XSV.금리', 'NNG.추가', 'NNG.오르', 'VV.준비', 'NNG.되', 'VV.하', 'VV.현지', 'NNG.미', 'NNG.국고채', 'NNG.금리', 'NNG.가장', 'MAG.높', 'VA.수준', 'NNG.오르', 'VV.가장', 'MAG.높', 'VA.오르', 'VV.미', 'NNG.국고채', 'NNG.들썩이', 'VV.국채', 'NNG.금리', 'NNG.오르', 'VV.따르', 'VV.국고채', 'NNG.고시금리', 'NNG.연고점', 'NNG.모두', 'MAG.경신', 'NNG.하', 'VV.국고채', 'NNG.금
# ...

# %%
def getNgramWord(N,txt):
    txt = txt.split()
    ngrams = [txt[i:i+N] for i in range(len(txt)-N+1)]
    return ngrams

getNgramWord(2,df['content'][0])
# Out:
# [['미국', '연방준비위원회(연준)이'],
#  ['연방준비위원회(연준)이', '기준금리를'],
#  ['기준금리를', '동결했지만,'],
#  ['동결했지만,', "'매파적"],
#  ["'매파적", "신호'에"],
#  ["신호'에", '국내'],
#  ['국내', '은행의'],
#  ['은행의', '대출금리도'],
#  ['대출금리도', '당분간'],
#  ['당분간', '고금리'],
#  ['고금리', '기조가'],
#  ['기조가', '이어질'],
#  ['이어질', '전망이다.'],
#  ['전망이다.', '21일'],
#  ['21일', '금융권에'],
#  ['금융권에', '따르면'],
#  ['따르면', '국내'],
#  ['국내', '5대'],
#  ['5대', '은행(KB국민·신한·하나·우리·NH농협)의'],
#  ['은행(KB국민·신한·하나·우리·NH농협)의', '이날'],
#  ['이날', '주택담보대출'],
#  ['주택담보대출', '변동금리는'],
#  ['변동금리는', '4.17~6.187%로'],
#  ['4.17~6.187%로', '지난달'],
#  ['지난달', '1일(4.08~6.064%)에'],
#  ['1일(4.08~6.064%)에', '비해'],
#  ['비해', '금리구간'],
#  ['금리구간', '상·하단이'],
#  ['상·하단이', '각각'],
#  ['각각', '0.09·0.123%포인트(p)'],
#  ['0.09·0.123%포인트(p)', '올랐다.'],
#  ['올랐다.', '같은'],
#  ['같은', '기간'],
#  ['기간', '고정금리도'],
#  ['고정금리도', '3.90~6.09%로'],
#  ['3.90~6.09%로', '상·하단이'],
#  ['상·하단이', '각각'],
#  ['각각', '0.14·0.25%p'],
#  ['0.14·0.25%p', '뛰었다.'],
#  ['뛰었다.', '은행권의'],
#  ['은행권의', '대출금리가'],
#  ['대출금리가', '오르는'],
# ...

# %%
# n-gram 어휘 벡터 생성
def getNgramWord(N,txt):
    txt = txt.split()
    ngrams = [txt[i:i+N] for i in range(len(txt)-N+1)]
    return ngrams

# n-gram 어휘 벡터의 빈도수 추출
def getFrequencyVector(N, documentTxt, arrVocabulary):
    # arrVocabulary 길이로 Bag-Of-Words 벡터 초기화
    vectorBoW = [0] * len(arrVocabulary)

    # n-gram 빈도수 벡터 생성
    words = getNgramWord(N, documentTxt)
    for word in words:
        wordIndex = arrVocabulary.index(word)
        vectorBoW[wordIndex] = 1
    return vectorBoW

# %%
df['content'].tolist()
# Out:
# ['원/달러 환율이 장중 한때 1360원에 근접했다. 중동분쟁 긴장감이 고조되고 미국 10년 만기 국채 금리가 4.9%까지 치솟는 등 시장에 위험자산 회피 심리가 강화하는 분위기다.  19일 서울 외환시장에서 원/달러 환율은 전날(1349.6원)보다 7.8원 오른 1357.4원에 마감했다.  이날 원/달러 환율은 전 거래일보다 6.4원 오른 1356원에 거래를 시작했다. 이후 상승폭을 키워 장중 한때 1359.1원까지 오르며 1360원에 육박했다.  원/달러 환율 상승은 간밤 미국 국채금리 상승 영향으로 분석된다.  간밤 글로벌 채권 금리 벤치마크 역할을 하는 미 국채 10년물 수익률은 장중 4.93%까지 올랐다. 10년물 금리가 4.9%대를 돌파한 건 2007년 이후 약 16년 만에 처음이다.  미 국채 금리가 오른 건 미국 소비 호조로 연방준비제도(Fed, 연준)의 추가 긴축 우려가 커진 영향이다. 미국 상무부 발표에 따르면 미국의 9월 소매 판매는 7049억달러(약 955조원)로 전월 대비 0.7% 증가했다. 시장 전망치(0.2%)를 크게 웃돈 수준이다.  여기에 미국이 우크라이나에 이어 이스라엘에도 지원 약속을 하며 국채 발행이 늘어날 것이란 전망이 나오는 것도 국채 금리를 끌어올리고 있다.  이에 시장에 안전자산 선호 심리가 확대됐고 미 국채 금리가 급등했다.  대표적 안전자산인 달러화도 강세로 돌아섰다. 주요 6개국 통화 대비 달러화 가치를 나타내는 달러인덱스는 이날 한때 106.66까지 올랐다.  이스라엘과 팔레스타인 무장정파 하마스 간 분쟁도 원/달러 환율을 끌어올린 요인으로 분석된다.  미국 조 바이든 미국 대통령이 이스라엘을 방문했지만 성과는 기대보다 미흡했단 평가다. 당초 예정돼 있던 이집트·요르단·팔레스타인 지도자들과 4자 회담이 취소되면서 단기간 내 중동 안정이 어려울 수 있다는 우려가 증폭되면서다.  이에 국제유가는 상승했다. 18일(현지시간) 미국 뉴욕상업거래소에서 서부텍사스산원유(WTI) 가격은 전거래일 대비 1.92% 오른 배
# ...

# %%
sort_df = df.sort_values(by=["date"], ascending=False)
list_df = sort_df['title'].tolist()
X_train = list_df
vocab = [token.split() for token in X_train]
phrases = Phrases([x for x in vocab], min_count=15, threshold=1.3)

# %%
def ngram2vec_train(train_list):
    X_train = train_list

    # 2. 특성 추출 (형태소 분석 및 N-그램)
    vocab = [token.split() for token in X_train]

    # 3. N-그램 추출
    phrases = Phrases([x for x in vocab], min_count=1, threshold=1.1)
    ngram_X_train = [' '.join(phrases[x]) for x in vocab]
    New_test_ngrams = ngram_X_train

    # 4. Ngram2Vec 모델 학습
    model = Word2Vec([x.split() for x in New_test_ngrams], vector_size=300, window=5, min_count=25)
    return model,phrases
model,phrases = ngram2vec_train(list_df)
print("모델 생성 하였습니다")

# %%
import pandas as pd
import numpy as np

dovish_test_path = './data_list/dovish_test.csv'
hawkish_test_path = './data_list/hawkish_test.csv'
dovish_df = pd.read_csv(dovish_test_path,sep=',')
hawkish_df = pd.read_csv(hawkish_test_path,sep=',')

words = [word.split() for word in dovish_df['words'].tolist()]
df = pd.DataFrame(index=[0], columns=['P', 'N', 'Polarity','Intensity','label'])
print(df)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    news_df['words'], news_df['label'], shuffle=True, test_size=0.2)
X_train, y_train


label_mapping = {'비둘기파': 0,'매파':1}
Y_train = [label_mapping[label] for label in news_df['label'].tolist()]


from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
clf = MultinomialNB().fit(X_train_counts, y_train)


print(clf.predict(count_vect.transform(["a"])))
print(clf.predict_proba(count_vect.transform(["i_love"])))
