# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in c:\users\sda10\anaconda3\envs\study\lib\site-packages (2.11.1)
# Requirement already satisfied: Twisted>=18.9.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (24.3.0)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (42.0.5)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (1.9.0)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (24.1.0)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: service-identity>=18.1.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (24.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (2.1.2)
# Requirement already satisfied: zope.interface>=5.1.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (6.2)
# Requirement already satisfied: protego>=0.1.15 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (0.8.0)
# Requirement already satisfied: setuptools in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (68.2.2)
# Requirement already satisfied: packaging in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (23.2)
# Requirement already satisfied: tldextract in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (5.1.2)
# Requirement already satisfied: lxml>=4.4.1 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (5.1.0)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from cryptography>=36.0.0->scrapy) (1.16.0)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from service-identity>=18.1.0->scrapy) (23.2.0)
# Requirement already satisfied: pyasn1 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.5.1)
# Requirement already satisfied: pyasn1-modules in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Requirement already satisfied: automat>=0.8.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from Twisted>=18.9.0->scrapy) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=22.10.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from Twisted>=18.9.0->scrapy) (1.0.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from Twisted>=18.9.0->scrapy) (4.9.0)
# Requirement already satisfied: idna in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from tldextract->scrapy) (3.6)
# Requirement already satisfied: requests>=2.1.0 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from tldextract->scrapy) (2.31.0)
# Requirement already satisfied: requests-file>=1.4 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from tldextract->scrapy) (2.0.0)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from tldextract->scrapy) (3.13.1)
# Requirement already satisfied: six in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from automat>=0.8.0->Twisted>=18.9.0->scrapy) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sda10\anaconda3\envs\study\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2023.11.17)
# DEPRECATION: mecab-python 0.996-ko-0.9.2-msvc has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of mecab-python or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !scrapy startproject naver_news
# Out:
# New Scrapy project 'naver_news', using template directory 'C:\Users\SDA10\anaconda3\envs\study\Lib\site-packages\scrapy\templates\project', created in:
#     C:\Users\SDA10\Desktop\workpace\새 폴더\s_craw\test_packge\naver_news
#
# You can start your first spider with:
#     cd naver_news
#     scrapy genspider example example.com

# %%
# test

from bs4 import BeautifulSoup
import requests

# %%
import scrapy
from bs4 import BeautifulSoup

class MySpider(scrapy.Spider):
    name = 'mt_news'

    def start_requests(self):
        base_url = 'https://search.mt.co.kr/searchNewsList.html'
        page = 1
        while True:
            url = f'{base_url}?srchFd=T&range=TOTAL&reSrchFlag=&preKwd=&search_type=m&kwd=%B1%DD%B8%AE&bgndt=20150101&enddt=20211231&category=MTNW&sortType=display&subYear=&category=MTNW&subType=mt&pageNum={page}'
            yield scrapy.Request(url=url, callback=self.parse)
            page += 1

    def parse(self, response):
        soup = BeautifulSoup(response.text, 'html.parser')
        money_links = [link['href'] for link in soup.select('.conlist_p1.mgt23 a')]
        for link in money_links[::3]:
            yield {
                'link': link
            }

# %%
base_url = 'https://search.mt.co.kr/searchNewsList.html'
page = 1
next_page = True
while next_page:
    url = f'{base_url}?srchFd=T&range=TOTAL&reSrchFlag=&preKwd=&search_type=m&kwd=%B1%DD%B8%AE&bgndt=20150101&enddt=20211231&category=MTNW&sortType=display&subYear=&category=MTNW&subType=mt&pageNum={page}'

    res = requests.get(url)
    soup = BeautifulSoup(res.text,'html.parser')

    # 해당 페이지의 하이퍼링크 가져오기
    money_links = [link['href'] for link in soup.select('.conlist_p1.mgt23 a')]
    if money_links:
        for link in money_links[::3]:
            print(link)
            

        page += 1
    else:
        next_page = False
# Out:
# https://news.mt.co.kr/mtview.php?no=2024032113145310760&type=1
# https://news.mt.co.kr/mtview.php?no=2024032115592328069&type=1
# https://news.mt.co.kr/mtview.php?no=2024032112260737179&type=1
# https://news.mt.co.kr/mtview.php?no=2024032113170358999&type=1
# https://news.mt.co.kr/mtview.php?no=2024032110514840726&type=1
# https://news.mt.co.kr/mtview.php?no=2024032110011387215&type=1
# https://news.mt.co.kr/mtview.php?no=2024022206213577724&type=1
# https://news.mt.co.kr/mtview.php?no=2024022206022593307&type=1
# https://news.mt.co.kr/mtview.php?no=2024022122065017502&type=1
# https://news.mt.co.kr/mtview.php?no=2024022114550970360&type=1
# https://news.mt.co.kr/mtview.php?no=2024022110531656304&type=1
# https://news.mt.co.kr/mtview.php?no=2024022110362138685&type=1
# https://news.mt.co.kr/mtview.php?no=2024022109290196301&type=1
# https://news.mt.co.kr/mtview.php?no=2024022021454594953&type=1
# https://news.mt.co.kr/mtview.php?no=2024022017340646158&type=1
# https://news.mt.co.kr/mtview.php?no=2024022016595393456&type=1
# https://news.mt.co.kr/mtview.php?no=2024022014345894098&type=1
# https://news.mt.co.kr/mtview.php?no=2024022011054928837&type=1
# https://news.mt.co.kr/mtview.php?no=2024022008462978829&type=1
# https://news.mt.co.kr/mtview.php?no=2024022010460210579&type=1
# https://news.mt.co.kr/mtview.php?no=2024022009012873123&type=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 7
#       4 while next_page:
#       5     url = f'{base_url}?srchFd=T&range=TOTAL&reSrchFlag=&preKwd=&search_type=m&kwd=%B1%DD%B8%AE&bgndt=20150101&enddt=20211231&category=MTNW&sortType=display&subYear=&category=MTNW&subType=mt&pageNum={page}'
# ----> 7     res = requests.get(url)
#       8     soup = BeautifulSoup(res.text,'html.parser')
#      10     # 해당 페이지의 하이퍼링크 가져오기
#
# File c:\Users\SDA10\anaconda3\envs\study\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\SDA10\anaconda3\envs\study\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\SDA10\anaconda3\envs\study\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\SDA10\anaconda3\envs\study\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\SDA10\anaconda3\envs\study\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\SDA10\anaconda3\envs\study\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\SDA10\anaconda3\envs\study\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\SDA10\anaconda3\envs\study\lib\site-packages\urllib3\connectionpool.py:1096, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 # Force connect early to allow us to validate the connection.
#    1095 if conn.is_closed:
# -> 1096     conn.connect()
#    1098 if not conn.is_verified:
#    1099     warnings.warn(
#    1100         (
#    1101             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1106         InsecureRequestWarning,
#    1107     )
#
# File c:\Users\SDA10\anaconda3\envs\study\lib\site-packages\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File c:\Users\SDA10\anaconda3\envs\study\lib\site-packages\urllib3\connection.py:782, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     779     if is_ipaddress(normalized):
#     780         server_hostname = normalized
# --> 782 ssl_sock = ssl_wrap_socket(
#     783     sock=sock,
#     784     keyfile=key_file,
#     785     certfile=cert_file,
#     786     key_password=key_password,
#     787     ca_certs=ca_certs,
#     788     ca_cert_dir=ca_cert_dir,
#     789     ca_cert_data=ca_cert_data,
#     790     server_hostname=server_hostname,
#     791     ssl_context=context,
#     792     tls_in_tls=tls_in_tls,
#     793 )
#     795 try:
#     796     if assert_fingerprint:
#
# File c:\Users\SDA10\anaconda3\envs\study\lib\site-packages\urllib3\util\ssl_.py:445, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     443 if ca_certs or ca_cert_dir or ca_cert_data:
#     444     try:
# --> 445         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     446     except OSError as e:
#     447         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
for money_link in money_links:
    url = money_link
    res = requests.get(url)
    soup = BeautifulSoup(res.text,'html.parser')
    title = soup.select_one('.view_top h1').get_text(strip=True)
    print(title)
# Out:
# 영업제한 계속되는데…대출 금리는 오른다
# 예대금리차 9개월만에 반등, 은행업 순이자이익 증가 전망-케이프證
# 대학생 학자금 대출금리 1.7%…한 학기만에 또 0.15%p 인하
# "이자 85억원↓"…1학기 학자금 대출금리 '1.7%'로 인하
# [기고]최고금리 인하, 부작용 최소화 하려면
# "이혼 못해" 버티는 이범수…아내 이윤진 저격에 '외도설'까지
# '3번 이혼' 김혜영 "첫 남편, 신혼집에 여자랑 있더라…바로 이혼"
# 故이선균 협박녀 얼굴 공개됐다…"95년생 미혼모" 신상공개한 유튜버
# 강호동 '육칠팔', 대박인줄 알았는데…

# %%
# 영업제한 계속되는데…대출 금리는 오른다
# 예대금리차 9개월만에 반등, 은행업 순이자이익 증가 전망-케이프證
# 대학생 학자금 대출금리 1.7%…한 학기만에 또 0.15%p 인하
# "이자 85억원↓"…1학기 학자금 대출금리 '1.7%'로 인하
# [기고]최고금리 인하, 부작용 최소화 하려면
# "이혼 못해" 버티는 이범수…아내 이윤진 저격에 '외도설'까지
# '3번 이혼' 김혜영 "첫 남편, 신혼집에 여자랑 있더라…바로 이혼"
# 김용건 "정준하에 맞아 15일 입원…병원비 1400만원 썼다"
# "한국산 세계 첫 반잠수정, 우즈도 '사겠다'"
