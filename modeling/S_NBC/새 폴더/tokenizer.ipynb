# %%
import pandas as pd
import numpy as np
import re
from datetime import date, timedelta
import konlpy as kn
import MeCab as mc
import ekonlpy as ek
from konlpy.tag import Mecab
mecab = Mecab(dicpath=r"C:\mecab\mecab-ko-dic")

# %%
day = date(2024, 3, 1)
day_dateoffset = day - pd.DateOffset(months=1)
print(day_dateoffset)

day = date(2024, 3, 1)
day_timedelta = day - timedelta(days=31)
print(day_timedelta)
# Out:
# 2024-02-01 00:00:00

# %%
f = open('./crawl_result/call_rate.csv', 'r', encoding='utf-8')

# 데이터를 완전히 동일하게 가져올 수 있는가
headers = f.readline().rstrip() # 헤더 읽기, 맨 끝 줄바꿈기호 삭제
print(headers.split('\t'))
headers = headers.split('\t') # 같은 이름의 변수에 리스트로 바꾼 것 넣어주기

# 데이터 읽기
lines = f.readlines()
print(lines[:5])

new_datas = []
for line in lines: # 한 줄씩 
    data = line.rstrip().split('\t') # 줄바꿈 기호 지우고, ,로 잘라준다.
    dict_data = { header: data[i] for i, header in enumerate(headers) }
    new_datas.append(dict_data) # 데이터를 딕셔너리로 만들어서 넣어야된다.

f.close()

# %%
def find_nearest_date(df, target_date):
    delta = pd.Timedelta(days=1)
    nearest_date = None,
    min_difference = pd.Timedelta.max

    for date in df['date']:
        difference = abs(target_date - date)
        if difference < min_difference:
            min_difference = difference
            nearest_date = date

    return nearest_date

def label_call(df):
    df_ud = pd.DataFrame(index=df.index, columns=['date', 'price', 'label'])

    # 'date' 열을 datetime 형식으로 변환
    df['date'] = pd.to_datetime(df['date'])

    for i, row in df.iterrows():
        time = row['date']
        time2 = time - pd.DateOffset(months=1)

        # 이전 달의 날짜가 인덱스에 있는지 확인
        if time2 in df['date'].values:
            prev_row = df[df['date'] == time2].iloc[0]
        else:
            # 이전 날짜가 없는 경우 가장 가까운 날짜로 설정
            nearest_date = find_nearest_date(df, time2)
            prev_row = df[df['date'] == nearest_date].iloc[0]

        if row['price'] > prev_row['price']:
            label = '1'
        elif row['price'] == prev_row['price']:
            label = 0
        else:
            label = '-1'
            
        df_ud.loc[i] = [time.date(), row['price'], label]

    return df_ud

# %%
df = pd.DataFrame(new_datas)

call = label_call(df)
call
# Out:
#             date   price label
# 0     2024-03-21  3.5290    -1
# 1     2024-03-20  3.5330    -1
# 2     2024-03-19  3.5130    -1
# 3     2024-03-18  3.4410    -1
# 4     2024-03-15  3.4640    -1
# ...          ...     ...   ...
# 3253  2011-01-07  2.4900     0
# 3254  2011-01-06  2.4900     0
# 3255  2011-01-05  2.4900     0
# 3256  2011-01-04  2.5000     1
# 3257  2011-01-03  2.4900     0
#
# [3258 rows x 3 columns]

# %%
# 크롤링 결과물 불러오기 - 이데일리 뉴스 (4분 소요)
from ekonlpy.tag import Mecab
from ekonlpy.sentiment import MPCK
mpck = MPCK()

jong_path = './crawl_result/jong_test.json'
edaily_path = './crawl_result/edaily_news_test.json'


df_news_1 = pd.read_json(jong_path)
df_news_2 = pd.read_json(edaily_path)

df_news_1 = df.sort_values(by=["date"], ascending=False) # 날짜별 내림차순
df_news_2 = df.sort_values(by=["date"], ascending=False)

# %% [markdown]
# ### 혹시나 모르시겠으면 연락주세요 밑에서 부터 건들였습니다

# %% [markdown]
# ### path 경로 수정하시고 사용 하시면 됩니다  (제가 한 부분)
#
# * 각각의 뉴스들을 넣어서 문서,문장화 만드는 부분인데 주석 푸시고 넣고싶은 뉴스 기사 패스 지정하시고 사용하면 됩니다!

# %%
# 문장 분할을 위한 정규표현식 패턴
sentence_pattern = r'(?<=[.!?]) +'

# 데이터프레임으로부터 문서를 읽어와 딕셔너리 구조로 저장하는 함수
def read_documents_to_dict(df):
    date_dict = {}
    change_pattern = '(?<=[가-힣])\\.'
    news_pattern = ['\\[.*\\]', '\\w{4,}\\@[a-zA-Z0-9\\-]{2,}\\.[a-z]{2,}(\\.[a-z]{2})?', '....기자']

    # DataFrame의 각 행에 대해 반복
    for index, row in df.iterrows():
        date = str(row['date']).split(' ')[0] 
        text = row['content'] 
        
        # 뉴스 패턴 제거
        news_text = text
        for pattern in news_pattern:
            news_text = re.sub(pattern, '', news_text)

        # 변경 패턴 적용
        change_text = re.sub(change_pattern, '@@@', news_text)  
        split_text = change_text.split('@@@')  
        split_text = [sent.strip() for sent in split_text]
        
        # 문서별로 문장 추가
        if date not in date_dict:
            date_dict[date] = []
        
        # 문장 추가
        if split_text:  # 빈 리스트인 경우 추가하지 않음
            date_dict[date].append(split_text)

    return date_dict

# 문서 데이터프레임 읽기
# -------------------------------------------------------------------------------------예시 경로 설정 필요 (여기만 건드시면 됩니다 함수 안건드셔도되요)-------------------------------------
jong_path = "./crawl_result/jong_test.json"
edaily_path = "./crawl_result/edaily_news_test.json"

df_news_1 = pd.read_json(jong_path)
df_news_2 = pd.read_json(edaily_path)

# 문서들을 딕셔너리 구조로 저장
date_dict_1 = read_documents_to_dict(df_news_1)
date_dict_2 = read_documents_to_dict(df_news_2)

# %% [markdown]
# ### 여기서 딕셔너리 두개 합쳐주세요 , 여러개 합치고 싶을시 합친 merged_date_dict과 합칠 dict 넣으시면 됩니다.

# %%
# 두 개의 딕셔너리를 합치는 함수
def merge_dicts(dict1, dict2):
    merged_dict = dict1.copy()
    for key, value in dict2.items():
        if key in merged_dict:
            merged_dict[key].extend(value)  # 이미 있는 키의 경우 값들을 합침
        else:
            merged_dict[key] = value  # 새로운 키의 경우 값을 그대로 추가
    return merged_dict



# 두 개의 딕셔너리 합치기 -------------------------- 함수 건들지 마시고 밑에꺼에 dict 값 넣으시면 됩니다. ------------------------------------------------
merged_date_dict = merge_dicts(date_dict_1, date_dict_2)

# %% [markdown]
# ### 아래는 딕셔너리 사용법 예시입니다.

# %%
merged_date_dict['2013-03-15']
####  딕셔너리 이름 [날짜] [몇번째 문서인지] [그 문서의 몇번째 문장인지]

# %%
from ekonlpy.tag import Mecab

# ekonlpy의 Mecab 형태소 분석기 인스턴스 생성
tokenizer = Mecab()

# 토큰화 함수 정의
def tokenize(sentence):
    tokens_with_pos = tokenizer.pos(sentence)
    return tokens_with_pos

# 각 문서의 문장을 토큰화하여 출력
for date, documents in merged_date_dict.items():
    for doc_num, sentences in enumerate(documents, start=1):
        print(f"{date}의 문서 {doc_num} 토큰화 결과:")
        for sentence in sentences:
            tokens_with_pos = tokenize(sentence)
            print(tokens_with_pos)
# Out:
# 2022-06-23의 문서 1 토큰화 결과:
# [('코스피', 'NNG'), ('와', 'JC'), ('코스닥', 'NNG'), ('이', 'JKS'), ('이틀', 'NNG'), ('연속', 'NNG'), ('연저점', 'NNG'), ('으로', 'JKB'), ('추락', 'NNG'), ('한', 'XSA'), ('23', 'SN'), ('일', 'NNG'), ('오후', 'NNG'), ('서울', 'NNP'), ('중구', 'NNG'), ('하나은행', 'NNP'), ('본점', 'NNG'), ('딜링룸', 'NNG'), ('에서', 'JKB'), ('직원', 'NNG'), ('이', 'JKS'), ('전광판', 'NNG'), ('앞', 'NNG'), ('을', 'JKO'), ('지나', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('이날', 'NNG'), ('코스피', 'NNG'), ('는', 'JX'), ('전', 'MM'), ('거래일', 'NNG'), ('보다', 'JKB'), ('1', 'SN'), ('.', 'SY'), ('22', 'SN'), ('%', 'SY'), ('내린', 'VV'), ('2314', 'SN'), ('.', 'SY'), ('32', 'SN'), ('에', 'JKB'), ('장', 'NNG'), ('을', 'JKO'), ('마쳤', 'VV'), ('다', 'EC')]
# [('코스닥', 'NNG'), ('은', 'JX'), ('전날', 'NNG'), ('보다', 'JKB'), ('4', 'SN'), ('.', 'SY'), ('36', 'SN'), ('%', 'SY'), ('급락', 'NNG'), ('한', 'XSA'), ('714', 'SN'), ('.', 'SY'), ('38', 'SN'), ('에', 'JKB'), ('마감', 'NNG'), ('하', 'XSV'), ('며', 'EC'), ('이틀', 'NNG'), ('연속', 'NNG'), ('4', 'SN'), ('%', 'SY'), ('대', 'XPN'), ('하락', 'NNG'), ('률', 'XSN'), ('을', 'JKO'), ('기록', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('연합뉴스', 'NNP'), ('“', 'SSO'), ('주식', 'NNG'), ('수익률', 'NNG'), ('이', 'JKS'), ('-', 'SY'), ('28', 'SN'), ('%', 'SY'), ('인데도', 'VCP'), (',', 'SC'), ('끝내', 'MAG'), ('손절', 'NNG'), ('손절매', 'NNG'), ('했', 'XSV'), ('네요', 'EC')]
# [('올해', 'NNG'), ('여름휴가', 'NNG'), ('는', 'JX'), ('포기', 'NNG'), ('에', 'JKB'), ('요', 'JX')]
# [('”', 'SSC'), ('회사원', 'NNG'), ('박모', 'NNG'), ('(', 'SSO'), ('34', 'SN'), ('씨', 'NNG'), (')', 'SSC'), ('는', 'JX'), ('1', 'SN'), ('년', 'NNBC'), ('여간', 'MAG'), ('모아', 'VV'), ('왔', 'VX'), ('던', 'ETM'), ('주식', 'NNG'), ('을', 'JKO'), ('이달', 'NNG'), ('들', 'VV'), ('어', 'EC'), ('나눠', 'VV'), ('팔', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('주식', 'NNG'), ('이', 'JKS'), ('오를', 'VV'), ('기미', 'NNG'), ('가', 'JKS'), ('보이', 'VV'), ('지', 'EC'), ('않', 'VX'), ('아서', 'EC'), ('다', 'MAG')]
# [('그', 'NP'), ('는', 'JX'), ('주가', 'NNG'), ('가', 'JKS'), ('바닥', 'NNG'), ('권', 'XSN'), ('이', 'VCP'), ('라고', 'EC'), ('생각', 'NNG'), ('해', 'XSV'), ('지난해', 'NNG'), ('부터', 'JX'), ('삼성전자', 'NNP'), ('와', 'JC'), ('네이버', 'NNP'), (',', 'SC'), ('카카오', 'NNP'), ('등', 'NNB'), ('코스피', 'NNG'), ('시가총액', 'NNG'), ('상위', 'NNG'), ('10', 'SN'), ('위', 'NNBC'), ('종목', 'NNG'), ('에', 'JKB'), ('적립식', 'NNG'), ('으로', 'JKB'), ('투자', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('꾸준', 'NNG'), ('한', 'XSA'), ("'", 'SY'), ('물타기', 'NNG'), ("'(", 'SY'), ('매수', 'NNG'), ('단가', 'NNG'), ('를', 'JKO'), ('낮추', 'VV'), ('기', 'ETN'), ('위한', 'VV'), ('추가', 'NNG'), ('매수', 'NNG'), (')', 'SSC'), ('로', 'JKB'), ('누적', 'NNG'), ('투', 'NR'), ('자금', 'NNG'), ('은', 'JX'), ('3000', 'SN'), ('만', 'NR'), ('원', 'NNBC'), ('을', 'JKO'), ('넘겼', 'VV'), ('지만', 'EC'), (',', 'SC'), ('현재', 'MAG'), ('수익률', 'NNG'), ('은', 'JX'), ('-', 'SY'), ('28', 'SN'), ('%', 'SY'), ('정도', 'NNG'), ('다', 'VCP')]
# [('그', 'NP'), ('는', 'JX'), ('“', 'SSO'), ('바닥', 'NNG'), ('아래', 'NNG'), ('지하실', 'NNG'), ('이', 'JKS'), ('있', 'VV'), ('다더니', 'EC'), (',', 'SC'), ('무서워서', 'VA'), ('더', 'MAG'), ('는', 'JX'), ('매수', 'NNG'), ('할', 'XSV'), ('수', 'NNB'), ('가', 'JKS'), ('없', 'VA'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('말', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('국내', 'NNG'), ('증시', 'NNG'), ('버팀목', 'NNG'), ('역할', 'NNG'), ('을', 'JKO'), ('했', 'VV'), ('던', 'ETM'), ('', 'SY'), ('‘', 'SY'), ('동학', 'NNG'), ('개미', 'NNG'), ('’', 'SY'), ('가', 'JKS'), ('돌아서', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('바닥', 'NNG'), ('없이', 'MAG'), ('미끄러지', 'VV'), ('는', 'ETM'), ('시장', 'NNG'), ('에', 'JKB'), ('지친', 'VV'), ('개인', 'NNG'), ('투자자', 'NNG'), ('‘', 'SY'), ('팔자', 'NNG'), ('’', 'SY'), ('엔', 'NNG'), ('나서', 'VV'), ('자', 'EC'), ('개미', 'NNG'), ('의', 'JKG'), ('‘', 'SY'), ('항복', 'NNG'), ('신호', 'NNG'), ('’', 'SY'), ('라는', 'VCP'), ('시각', 'NNG'), ('도', 'JX'), ('나온다', 'VV')]
# [('제롬', 'NNP'), ('파월', 'NNP'), ('미', 'NNG'), ('연방준비제도', 'NNG'), ('Fed', 'NNG'), ('의장', 'NNG'), ('이', 'JKS'), ('22', 'SN'), ('일', 'NNG'), ('(', 'SSO'), ('현지', 'NNG'), ('시각', 'NNG'), (')', 'SSC'), ('‘', 'SY'), ('경기', 'NNG'), ('침체', 'NNG'), ('가능성', 'NNG'), ('’', 'SY'), ('을', 'JKO'), ('언급', 'NNG'), ('하', 'XSV'), ('며', 'EC'), (',', 'SC'), ('주가', 'NNG'), ('추가', 'NNG'), ('하락', 'NNG'), ('에', 'JKB'), ('대한', 'VV'), ('개인', 'NNG'), ('의', 'JKG'), ('공포감', 'NNG'), ('에', 'JKB'), ('불', 'NNG'), ('을', 'JKO'), ('지폈', 'VV'), ('다', 'EC')]
# [('회사원', 'NNG'), ('박모', 'NNG'), ('(', 'SSO'), ('34', 'SN'), (')', 'SSC'), ('씨', 'NNB'), ('의', 'JKG'), ('증권', 'NNG'), ('계좌', 'NNG'), ('수익', 'NNG'), ('률', 'XSN')]
# [('독자', 'NNG'), ('제공', 'NNG'), ('23', 'SN'), ('일', 'NNG'), ('코스피', 'NNG'), ('는', 'JX'), ('전날', 'NNG'), ('보다', 'JKB'), ('1', 'SN'), ('.', 'SY'), ('22', 'SN'), ('%', 'SY'), ('내린', 'VV'), ('2314', 'SN'), ('.', 'SY'), ('32', 'SN'), ('에', 'JKB'), ('마감', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('52', 'SN'), ('주', 'NNBC'), ('최저치', 'NNG'), ('(', 'SSO'), ('2339', 'SN'), ('.', 'SY'), ('64', 'SN'), (')', 'SSC'), ('를', 'JKO'), ('다시', 'MAG'), ('갈', 'VV'), ('아', 'EC'), ('치웠', 'VX'), ('다', 'EC')]
# [('장', 'NNG'), ('중', 'NNG'), ('에', 'JKB'), ('는', 'JX'), ('2306', 'SN'), ('.', 'SY'), ('48', 'SN'), ('까지', 'JX'), ('밀리', 'VV'), ('며', 'EC'), ('2300', 'SN'), ('선', 'NNG'), ('도', 'JX'), ('위태', 'NNG'), ('로웠', 'XSA'), ('다', 'EC')]
# [('코스닥', 'NNG'), ('은', 'JX'), ('투자자', 'NNG'), ('는', 'JX'), ('할', 'VV'), ('말', 'NNG'), ('을', 'JKO'), ('잃', 'VV'), ('었', 'EP'), ('다', 'EC')]
# [('전날', 'NNG'), ('보다', 'JKB'), ('4', 'SN'), ('.', 'SY'), ('36', 'SN'), ('%', 'SY'), ('급락', 'NNG'), ('한', 'XSA'), ('714', 'SN'), ('.', 'SY'), ('38', 'SN'), ('에', 'JKB'), ('장', 'NNG'), ('을', 'JKO'), ('마쳤', 'VV'), ('다', 'EC')]
# [('역시', 'MAJ'), ('52', 'SN'), ('주', 'NNBC'), ('최저치', 'NNG'), ('를', 'JKO'), ('새로', 'MAG'), ('썼', 'VV'), ('다', 'EC')]
# [('이날', 'NNG'), ('주가', 'NNG'), ('를', 'JKO'), ('끌어내린', 'VV'), ('건', 'NNB'), ('개인', 'NNG'), ('이', 'JKS'), ('던진', 'VV'), ('매도', 'NNG'), ('폭탄', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('개인', 'NNG'), ('은', 'JX'), ('코스피', 'NNG'), ('(', 'SSO'), ('6711', 'SN'), ('억', 'NR'), ('원', 'NNBC'), (')', 'SSC'), ('와', 'JC'), ('코스닥', 'NNG'), ('(', 'SSO'), ('640', 'SN'), ('억', 'NR'), ('원', 'NNBC'), (')', 'SSC'), ('시장', 'NNG'), ('에서', 'JKB'), ('모두', 'NNG'), ("'", 'SY'), ('팔자', 'NNG'), ("'", 'SY'), ('에', 'JKB'), ('나섰', 'VV'), ('다', 'EC')]
# [("'", 'SY'), ('셀코리아', 'NNG'), ("'", 'SY'), ('중', 'NNG'), ('인', 'VCP'), ('외국인', 'NNG'), ('은', 'JX'), ('이날', 'NNG'), ('도', 'JX'), ('코스피', 'NNG'), ('에서', 'JKB'), ('2969', 'SN'), ('억', 'NR'), ('원', 'NNBC'), ('어치', 'NNG'), ('를', 'JKO'), ('팔', 'VV'), ('아', 'EC'), ('치웠', 'VX'), ('다', 'EC')]
# [('기관', 'NNG'), ('(', 'SSO'), ('9264', 'SN'), ('억', 'NR'), ('원', 'NNBC'), (')', 'SSC'), ('이', 'JKS'), ('코스피', 'NNG'), ('에서', 'JKB'), ('개인', 'NNG'), ('과', 'JC'), ('외국인', 'NNG'), ('이', 'JKS'), ('던진', 'VV'), ('물량', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('았', 'EP'), ('지만', 'EC'), ('하락', 'NNG'), ('을', 'JKO'), ('막지', 'NNG'), ('는', 'JX'), ('못', 'MAG'), ('했', 'VV'), ('다', 'EC')]
# [('개미', 'NNG'), ('의', 'JKG'), ("'", 'SY'), ('팔자', 'NNG'), ("'", 'SY'), ('는', 'JX'), ('시장', 'NNG'), ('은', 'JX'), ('인내심', 'NNG'), ('이', 'JKS'), ('바닥난', 'VV'), ('개인', 'NNG'), ('투자자', 'NNG'), ('의', 'JKG'), ('‘', 'SY'), ('항복', 'NNG'), ('신호', 'NNG'), ('’', 'SY'), ('란', 'VCP'), ('진단', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('이달', 'NNG'), ('들', 'VV'), ('어', 'EC'), ('', 'SY'), ('15', 'SN'), ('거래일', 'NNG'), ('동안', 'NNG'), ('개인', 'NNG'), ('이', 'JKS'), ('순매도', 'NNG'), ('로', 'JKB'), ('거래', 'NNG'), ('를', 'JKO'), ('마친', 'VV'), ('건', 'NNB'), ('이', 'MM'), ('날', 'NNG'), ('포함', 'NNG'), ('4', 'SN'), ('거래일', 'NNG'), ('(', 'SSO'), ('3', 'SN'), ('일', 'NNG'), ('·', 'SC'), ('16', 'SN'), ('일', 'NNG'), ('·', 'SC'), ('21', 'SN'), ('일', 'NNG'), ('·', 'SC'), ('23', 'SN'), ('일', 'NNG'), (')', 'SSC'), ('뿐', 'JX'), ('이', 'VCP'), ('다', 'EC')]
# [('특히', 'MAG'), ('코스피', 'NNG'), ('가', 'JKS'), ('하락', 'NNG'), ('마감', 'NNG'), ('한', 'XSA'), ('날', 'NNG'), ('개인', 'NNG'), ('이', 'JKS'), ('순매도', 'NNG'), ('를', 'JKO'), ('기록', 'NNG'), ('한', 'XSA'), ('건', 'NNB'), ('이달', 'NNG'), ('들', 'VV'), ('어', 'EC'), ('처음', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('순매도', 'NNG'), ('규모', 'NNG'), ('도', 'JX'), ('이달', 'NNG'), ('들', 'VV'), ('어', 'EC'), ('가장', 'MAG'), ('컸', 'VA'), ('다', 'EC')]
# [('그동안', 'MAG'), ('세', 'MM'), ('차례', 'NNG'), ('있', 'VV'), ('었', 'EP'), ('던', 'ETM'), ('개인', 'NNG'), ('투자자', 'NNG'), ('의', 'JKG'), ('순매도', 'NNG'), ('는', 'JX'), ('시장', 'NNG'), ('반등시', 'NNG'), ('손실', 'NNG'), ('폭', 'NNG'), ('을', 'JKO'), ('줄이', 'VV'), ('기', 'ETN'), ('위한', 'VV'), ('것', 'NNB'), ('이', 'VCP'), ('었', 'EP'), ('다면', 'EC'), ('이날', 'NNG'), ('은', 'JX'), ('손해', 'NNG'), ('를', 'JKO'), ('무릅쓴', 'VV'), ('‘', 'SY'), ('투매', 'NNG'), ('’', 'SY'), ('의', 'JKG'), ('성격', 'NNG'), ('이', 'JKS'), ('강했', 'VV'), ('다는', 'ETM'), ('게', 'NNB'), ('시장', 'NNG'), ('의', 'JKG'), ('시각', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('박광남', 'NNP'), ('미래에셋증권', 'NNP'), ('디지털', 'NNG'), ('리서치', 'NNG'), ('팀장', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('코스피', 'NNG'), ('와', 'JC'), ('코스닥', 'NNG'), ('이', 'JKS'), ('한', 'MM'), ('달', 'NNBC'), ('간', 'NNG'), ('10', 'SN'), ('~', 'SY'), ('18', 'SN'), ('%', 'SY'), ('급락', 'NNG'), ('하', 'XSV'), ('자', 'EC'), ('투자심리', 'NNG'), ('가', 'JKS'), ('완전히', 'MAG'), ('무너졌', 'VV'), ('다', 'EC'), ('”', 'SSC'), ('며', 'EC'), ('“', 'SSO'), ('소위', 'NNG'), ('백기', 'NNG'), ('투항', 'NNG'), ('의', 'JKG'), ('모습', 'NNG'), ('”', 'SSC'), ('이', 'VCP'), ('라고', 'EC'), ('진단', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('무너지', 'VV'), ('는', 'ETM'), ('시장', 'NNG'), ('의', 'JKG'), ('잔해', 'NNG'), ('속', 'NNG'), ('에', 'JKB'), ('도', 'JX'), ('개인', 'NNG'), ('투자자', 'NNG'), ('는', 'JX'), ('국내', 'NNG'), ('증시', 'NNG'), ('에', 'JKB'), ('대한', 'VV'), ('믿음', 'NNG'), ('보여', 'VV'), ('왔', 'VX'), ('다', 'EC')]
# [('23', 'SN'), ('일', 'NNG'), ('기준', 'NNG'), ('연초', 'NNG'), ('이후', 'NNG'), ('코스피', 'NNG'), ('시장', 'NNG'), ('에서', 'JKB'), ('외국인', 'NNG'), ('(', 'SSO'), ('14', 'SN'), ('조', 'NR'), ('4020', 'SN'), ('억', 'NR'), ('원', 'NNBC'), (')', 'SSC'), ('과', 'JC'), ('기관', 'NNG'), ('(', 'SSO'), ('12', 'SN'), ('조', 'NR'), ('7740', 'SN'), ('억', 'NR'), ('원', 'NNBC'), (')', 'SSC'), ('이', 'JKS'), ('27', 'SN'), ('조', 'NR'), ('1760', 'SN'), ('억', 'NR'), ('원', 'NNBC'), ('어치', 'NNG'), ('팔', 'VV'), ('아', 'EC'), ('치울', 'VX'), ('때', 'NNG'), ('개인', 'NNG'), ('만', 'JX'), ('25', 'SN'), ('조', 'NR'), ('4190', 'SN'), ('억', 'NR'), ('원', 'NNBC'), ('순매수', 'NNG'), ('를', 'JKO'), ('기록', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('이렇게', 'MAG'), ('국내', 'NNG'), ('증시', 'NNG'), ('를', 'JKO'), ('지켰', 'VV'), ('던', 'ETM'), ('개인', 'NNG'), ('이', 'JKS'), ('등', 'NNG'), ('을', 'JKO'), ('돌리', 'VV'), ('기', 'ETN'), ('시작', 'NNG'), ('한', 'XSA'), ('것', 'NNB'), ('이', 'VCP'), ('다', 'EC')]
# [('이경민', 'NNP'), ('대신증권', 'NNP'), ('투자전략', 'NNG'), ('팀장', 'NNP'), ('도', 'JX'), ('“', 'SSO'), ('최근', 'NNG'), ('국내', 'NNG'), ('증시', 'NNG'), ('가', 'JKS'), ('(', 'SSO'), ('다른', 'MM'), ('시장', 'NNG'), ('보다', 'JKB'), (')', 'SSC'), ('유독', 'MAG'), ('약했', 'VA'), ('다', 'EC'), ('”', 'SSC'), ('며', 'EC'), ('“', 'SSO'), ('수급', 'NNG'), ('중심', 'NNG'), ('에', 'JKB'), ('있', 'VV'), ('던', 'ETM'), ('개인', 'NNG'), ('이', 'JKS'), ('버티', 'VV'), ('지', 'EC'), ('못하', 'VX'), ('며', 'EC'), ('매물', 'NNG'), ('이', 'JKS'), ('쏟아졌', 'VV'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('설명', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('지난', 'VV'), ('한', 'MM'), ('달', 'NNBC'), ('간', 'NNG'), ('뉴욕', 'NNG'), ('3', 'SN'), ('대', 'NNBC'), ('지수', 'NNG'), ('가', 'JKS'), ('4', 'SN'), ('~', 'SY'), ('5', 'SN'), ('%', 'SY'), ('하락', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('동안', 'NNG'), ('코스피', 'NNG'), ('와', 'JC'), ('코스닥', 'NNG'), ('은', 'JX'), ('각각', 'MAG'), ('11', 'SN'), ('.', 'SY'), ('19', 'SN'), ('%,', 'SY'), ('17', 'SN'), ('.', 'SY'), ('42', 'SN'), ('%', 'SY'), ('급락', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('그래픽', 'NNG'), ('=', 'SY'), ('개미', 'NNG'), ('의', 'JKG'), ('변심', 'NNG'), ('은', 'JX'), ('주식', 'NNG'), ('을', 'JKO'), ('팔', 'VV'), ('아', 'EC'), ('치우', 'VV'), ('는', 'ETM'), ('것', 'NNB'), ('만', 'JX'), ('으로', 'JKB'), ('끝', 'NNG'), ('이', 'JKC'), ('아니', 'VCN'), ('다', 'EC')]
# [('금', 'NNG'), ('은', 'JX'), ('올해', 'NNG'), ('들', 'VV'), ('어', 'EC'), ('가장', 'MAG'), ('낮', 'VA'), ('은', 'ETM'), ('수준', 'NNG'), ('으로', 'JKB'), ('떨어졌', 'VV'), ('다', 'EC')]
# [('23', 'SN'), ('일', 'NNG'), ('금융투자협회', 'NNP'), ('에', 'JKB'), ('따르', 'VV'), ('면', 'EC'), ('지난', 'VV'), ('22', 'SN'), ('일', 'NNG'), ('기준', 'NNG'), ('투자자', 'NNG'), ('예탁금', 'NNG'), ('은', 'JX'), ('56', 'SN'), ('조', 'NR'), ('3946', 'SN'), ('억', 'NR'), ('원', 'NNBC'), ('으로', 'JKB'), ('집계', 'NNG'), ('됐', 'XSV'), ('다', 'EC')]
# [('지난', 'VV'), ('9', 'SN'), ('일', 'NNG'), ('(', 'SSO'), ('56', 'SN'), ('조', 'NR'), ('9970', 'SN'), ('억', 'NR'), ('원', 'NNBC'), (')', 'SSC'), ('18', 'SN'), ('개월', 'NNBC'), ('만', 'NNB'), ('에', 'JKB'), ('56', 'SN'), ('조', 'NR'), ('원', 'NNBC'), ('밑', 'NNG'), ('으로', 'JKB'), ('떨어진', 'VV'), ('뒤', 'NNG'), ('올해', 'NNG'), ('들', 'VV'), ('어', 'EC'), ('가장', 'MAG'), ('낮', 'VA'), ('은', 'ETM'), ('수준', 'NNG'), ('을', 'JKO'), ('기록', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('투자자', 'NNG'), ('예탁금', 'NNG'), ('은', 'JX'), ('투자', 'NNG'), ('상품', 'NNG'), ('거래', 'NNG'), ('를', 'JKO'), ('위해', 'VV'), ('개인', 'NNG'), ('투자자', 'NNG'), ('가', 'JKS'), ('증권사', 'NNG'), ('에', 'JKB'), ('맡긴', 'VV'), ('자금', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('코로나', 'NNG'), ('19', 'SN'), ('사태', 'NNG'), ('속', 'NNG'), ('각국', 'NNG'), ('이', 'JKS'), ('유동성', 'NNG'), ('을', 'JKO'), ('풀', 'VV'), ('며', 'EC'), ('주식시장', 'NNG'), ('의', 'JKG'), ('호황', 'NNG'), ('을', 'JKO'), ('이', 'VV'), ('어', 'EC'), ('가', 'VX'), ('던', 'ETM'), ('지난해', 'NNG'), ('7', 'SN'), ('월', 'NNBC'), ('투자자', 'NNG'), ('예탁금', 'NNG'), ('은', 'JX'), ('77', 'SN'), ('조', 'NR'), ('원', 'NNBC'), ('을', 'JKO'), ('넘어섰으나', 'VV'), ('1', 'SN'), ('년', 'NNBC'), ('만', 'NNB'), ('에', 'JKB'), ('20', 'SN'), ('조', 'NR'), ('원', 'NNBC'), ('넘', 'VV'), ('게', 'EC'), ('줄어들', 'VV'), ('었', 'EP'), ('다', 'EC')]
# [('제롬', 'NNP'), ('파월', 'NNP'), ('미', 'NNG'), ('연방준비제도', 'NNG'), ('Fed', 'NNG'), ('의장', 'NNG'), ('은', 'JX'), ('22', 'SN'), ('일', 'NNG'), ('(', 'SSO'), ('현지', 'NNG'), ('시각', 'NNG'), (')', 'SSC'), ('미', 'NNG'), ('상원은행위원회', 'NNP'), ('에', 'JKB'), ('출석', 'NNG'), ('해', 'XSV'), ('물가', 'NNG'), ('상승', 'NNG'), ('인플레이션', 'NNG'), ('을', 'JKO'), ('잡', 'VV'), ('기', 'ETN'), ('위해', 'VV'), ('금리', 'NNG'), ('를', 'JKO'), ('올린', 'VV'), ('결과', 'NNG'), ('경기', 'NNG'), ('가', 'JKS'), ('침체', 'NNG'), ('에', 'JKB'), ('빠질', 'VV'), ('수', 'NNB'), ('있', 'VV'), ('다고', 'EC'), ('인정', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('제공', 'NNG'), ('=', 'SY'), ('AFP', 'SL'), (',', 'SC'), ('연합뉴스', 'NNP'), ('개인', 'NNG'), ('투자자', 'NNG'), ('가', 'JKS'), ('시장', 'NNG'), ('을', 'JKO'), ('떠날', 'VV'), ('기미', 'NNG'), ('에', 'JKB'), ('국내', 'NNG'), ('증시', 'NNG'), ('의', 'JKG'), ('변동성', 'NNG'), ('은', 'JX'), ('더', 'MAG'), ('커질', 'VA'), ('전망', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('이경민', 'NNP'), ('투자전략', 'NNG'), ('팀장', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('전세계', 'NNG'), ('적', 'XSN'), ('인', 'VCP'), ('긴축', 'NNG'), ('과', 'JC'), ('기업', 'NNG'), ('실적', 'NNG'), ('악화', 'NNG'), ('우려', 'NNG'), ('등', 'NNB'), ('거시경제', 'NNG'), ('환경', 'NNG'), ('이', 'JKS'), ('좋', 'VA'), ('지', 'EC'), ('않', 'VX'), ('은', 'ETM'), ('상황', 'NNG'), ('에서', 'JKB'), ('개인', 'NNG'), ('수급', 'NNG'), ('마저', 'JX'), ('불안', 'NNG'), ('해지', 'NNG'), ('면서', 'EC'), ('단기간', 'NNG'), ('에', 'JKB'), ('주가', 'NNG'), ('반등', 'NNG'), ('을', 'JKO'), ('기대', 'NNG'), ('하', 'XSV'), ('긴', 'ETN'), ('어렵', 'VA'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('말', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('이', 'MM'), ('웅', 'NNG'), ('찬', 'VV'), ('하이투자증권', 'NNP'), ('연구원', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('3', 'SN'), ('분기', 'NNG'), ('이후', 'NNG'), ('통화', 'NNG'), ('긴축', 'NNG'), ('속도', 'NNG'), ('가', 'JKS'), ('완만', 'NNG'), ('해지', 'NNG'), ('기', 'ETN'), ('전', 'NNG'), ('까지', 'JX'), ('는', 'JX'), ('보수', 'NNG'), ('적', 'XSN'), ('접근', 'NNG'), ('이', 'JKS'), ('필요', 'NNG'), ('하', 'XSV'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('말', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('외국인', 'NNG'), ('이', 'JKS'), ('국내', 'NNG'), ('주식', 'NNG'), ('을', 'JKO'), ('계속', 'MAG'), ('던지', 'VV'), ('며', 'EC'), ('원화가치', 'NNG'), ('약세', 'NNG'), ('도', 'JX'), ('이어지', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('23', 'SN'), ('일', 'NNG'), ('서울', 'NNP'), ('외환시장', 'NNG'), ('에서', 'JKB'), ('달러', 'NNG'), ('당', 'XSN'), ('원화가치', 'NNG'), ('는', 'ETM'), ('전날', 'NNG'), ('보다', 'JKB'), ('4', 'SN'), ('.', 'SY'), ('5', 'SN'), ('원', 'NNBC'), ('내린', 'VV'), ('달러', 'NNG'), ('당', 'XSN'), ('1301', 'SN'), ('.', 'SY'), ('8', 'SN'), ('원', 'NNBC'), ('에', 'JKB'), ('거래', 'NNG'), ('를', 'JKO'), ('마쳤', 'VV'), ('다', 'EC')]
# [('장', 'NNG'), ('중', 'NNG'), ('엔', 'NNG'), ('원화가치', 'NNG'), ('가', 'JKS'), ('달러', 'NNG'), ('당', 'XSN'), ('1302', 'SN'), ('.', 'SY'), ('8', 'SN'), ('원', 'NNBC'), ('까지', 'JX'), ('흔들리', 'VV'), ('며', 'EC'), ('연저점', 'NNG'), ('을', 'JKO'), ('경신', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('원화가치', 'NNG'), ('가', 'JKS'), ('달러', 'NNG'), ('당', 'XSN'), ('1300', 'SN'), ('원', 'NNBC'), ('선', 'NNG'), ('을', 'JKO'), ('내준', 'VV'), ('건', 'NNB'), ('지난', 'VV'), ('2009', 'SN'), ('년', 'NNBC'), ('', 'SY'), ('7', 'SN'), ('월', 'NNBC'), ('14', 'SN'), ('일', 'NNG'), ('(', 'SSO'), ('1303', 'SN'), ('원', 'NNBC'), (')', 'SSC'), ('이후', 'NNG'), ('약', 'MM'), ('13', 'SN'), ('년', 'NNBC'), ('만', 'NNB'), ('이', 'VCP'), ('다', 'EC')]
# [('lee', 'SL'), ('.', 'SF')]
# 2022-06-23의 문서 2 토큰화 결과:
# [('소비자', 'NNG'), ('물가지수', 'NNG'), ('(', 'SSO'), ('CPI', 'SL'), (')', 'SSC'), ('의', 'JKG'), ('선행', 'NNG'), ('지표', 'NNG'), ('인', 'VCP'), ('생산자', 'NNG'), ('물가지수', 'NNG'), ('(', 'SSO'), ('PPI', 'SL'), (')', 'SSC'), ('가', 'JKS'), ('5', 'SN'), ('개월', 'NNBC'), ('째', 'XSN'), ('오르막길', 'NNG'), ('을', 'JKO'), ('걷', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('제품', 'NNG'), ('과', 'JC'), ('서비스', 'NNG'), ('생산', 'NNG'), ('에', 'JKB'), ('드', 'VV'), ('는', 'ETM'), ('비용', 'NNG'), ('이', 'JKS'), ('점차', 'MAG'), ('오르', 'VV'), ('면서', 'EC'), ('소비자', 'NNG'), ('가', 'JKS'), ('구입', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('각종', 'NNG'), ('물건', 'NNG'), ('과', 'JC'), ('서비스', 'NNG'), ('의', 'JKG'), ('가격', 'NNG'), ('도', 'JX'), ('당분간', 'MAG'), ('상승세', 'NNG'), ('를', 'JKO'), ('이', 'VV'), ('어', 'EC'), ('갈', 'VX'), ('확률', 'NNG'), ('이', 'JKS'), ('높', 'VA'), ('아', 'EC'), ('졌', 'VX'), ('다', 'EC')]
# [('뉴스', 'NNG'), ('1', 'SN'), ('물가', 'NNG'), ('오름세', 'NNG'), ('가', 'JKS'), ('이어질', 'VV'), ('전망', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('소비자', 'NNG'), ('물가지수', 'NNG'), ('(', 'SSO'), ('CPI', 'SL'), (')', 'SSC'), ('의', 'JKG'), ('선행', 'NNG'), ('지표', 'NNG'), ('인', 'VCP'), ('생산자', 'NNG'), ('물가지수', 'NNG'), ('(', 'SSO'), ('PPI', 'SL'), (')', 'SSC'), ('가', 'JKS'), ('5', 'SN'), ('개월', 'NNBC'), ('째', 'XSN'), ('오르막길', 'NNG'), ('을', 'JKO'), ('걷', 'VV'), ('고', 'EC'), ('있', 'VX'), ('어서', 'EC'), ('다', 'MAG')]
# [('제품', 'NNG'), ('과', 'JC'), ('서비스', 'NNG'), ('생산', 'NNG'), ('에', 'JKB'), ('드', 'VV'), ('는', 'ETM'), ('비용', 'NNG'), ('이', 'JKS'), ('뛰', 'VV'), ('면서', 'EC'), ('소비자', 'NNG'), ('물가', 'NNG'), ('도', 'JX'), ('상승세', 'NNG'), ('를', 'JKO'), ('이', 'VV'), ('어', 'EC'), ('갈', 'VX'), ('가능성', 'NNG'), ('이', 'JKS'), ('커졌', 'VV'), ('다', 'EC')]
# [('22', 'SN'), ('일', 'NNG'), ('한국은행', 'NNG'), ('에', 'JKB'), ('따르', 'VV'), ('면', 'EC'), ('5', 'SN'), ('월', 'NNBC'), ('PPI', 'SL'), ('는', 'JX'), ('119', 'SN'), ('.', 'SY'), ('24', 'SN'), ('(', 'SSO'), ('2015', 'SN'), ('=', 'SY'), ('100', 'SN'), (')', 'SSC'), ('를', 'JKO'), ('기록', 'NNG'), ('해', 'XSV'), ('한', 'MM'), ('달', 'NNBC'), ('전', 'NNG'), ('(', 'SSO'), ('118', 'SN'), ('.', 'SY'), ('59', 'SN'), (')', 'SSC'), ('보다', 'JKB'), ('0', 'SN'), ('.', 'SY'), ('5', 'SN'), ('%', 'SY'), ('상승', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('지난', 'VV'), ('1', 'SN'), ('월', 'NNBC'), ('부터', 'JX'), ('5', 'SN'), ('개월', 'NNBC'), ('째', 'XSN'), ('상승세', 'NNG'), ('를', 'JKO'), ('이', 'VV'), ('어', 'EC'), ('가', 'VX'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('1', 'SN'), ('년', 'NNBC'), ('전', 'NNG'), ('같', 'VA'), ('은', 'ETM'), ('달', 'NNG'), ('(', 'SSO'), ('108', 'SN'), ('.', 'SY'), ('65', 'SN'), (')', 'SSC'), ('보다', 'JKB'), ('는', 'JX'), ('9', 'SN'), ('.', 'SY'), ('7', 'SN'), ('%', 'SY'), ('뛰', 'VV'), ('었', 'EP'), ('다', 'EC')]
# [('전년', 'NNG'), ('동월', 'NNG'), ('대비', 'NNG'), ('수치', 'NNG'), ('는', 'JX'), ('1', 'SN'), ('년', 'NNBC'), ('6', 'SN'), ('개월', 'NNBC'), ('째', 'XSN'), ('상승', 'NNG'), ('행진', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('세부', 'NNG'), ('품목', 'NNG'), ('별', 'XSN'), ('로', 'JKB'), ('살펴보', 'VV'), ('면', 'EC'), ("'", 'SY'), ('밥상', 'NNG'), ('물가', 'NNG'), ("'", 'SY'), ('에', 'JKB'), ('대한', 'VV'), ('우려', 'NNG'), ('가', 'JKS'), ('커지', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('축산업', 'NNG'), ('과', 'JC'), ('연관', 'NNG'), ('된', 'XSV'), ('물가', 'NNG'), ('가', 'JKS'), ('전방위', 'NNG'), ('적', 'XSN'), ('으로', 'JKB'), ('오른', 'VV'), ('영향', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('한', 'MM'), ('달', 'NNBC'), ('전', 'NNG'), ('보다', 'JKB'), ('돼지고기', 'NNG'), ('(', 'SSO'), ('21', 'SN'), ('.', 'SY'), ('8', 'SN'), ('%)', 'SY'), ('와', 'JC'), ('달걀', 'NNG'), ('(', 'SSO'), ('4', 'SN'), ('.', 'SY'), ('8', 'SN'), ('%)', 'SY'), ('가격', 'NNG'), ('이', 'JKS'), ('크', 'VA'), ('게', 'EC'), ('뛰', 'VV'), ('었', 'EP'), ('다', 'EC')]
# [('1', 'SN'), ('년', 'NNBC'), ('전', 'NNG'), ('과', 'JC'), ('비교', 'NNG'), ('하', 'XSV'), ('면', 'EC'), ('닭고기', 'NNG'), ('(', 'SSO'), ('26', 'SN'), ('.', 'SY'), ('8', 'SN'), ('%)', 'SY'), ('가격', 'NNG'), ('이', 'JKS'), ('큰', 'VA'), ('폭', 'NNG'), ('으로', 'JKB'), ('올랐', 'VV'), ('다', 'EC')]
# [('양우', 'NNG'), ('용', 'XSN'), ('배합사료', 'NNG'), ('(', 'SSO'), ('18', 'SN'), ('.', 'SY'), ('8', 'SN'), ('%)', 'SY'), ('값', 'NNG'), ('도', 'JX'), ('가파르', 'VA'), ('게', 'EC'), ('상승', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('가축', 'NNG'), ('사료', 'NNG'), ('로', 'JKB'), ('사용', 'NNG'), ('되', 'XSV'), ('는', 'ETM'), ('곡물', 'NNG'), ('값', 'NNG'), ('이', 'JKS'), ('폭등', 'NNG'), ('하', 'XSV'), ('면서', 'EC'), ('축산물', 'NNG'), ('가격', 'NNG'), ('이', 'JKS'), ('오르', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('시카고상품거래소', 'NNP'), ('(', 'SSO'), ('CBOT', 'SL'), (')', 'SSC'), ('에', 'JKB'), ('따르', 'VV'), ('면', 'EC'), ('22', 'SN'), ('일', 'NNG'), ('기준', 'NNG'), ('옥수수', 'NNG'), ('선물', 'NNG'), ('가격', 'NNG'), ('(', 'SSO'), ('월물', 'NNBC'), (')', 'SSC'), ('은', 'JX'), ('부셸', 'NNG'), ('(', 'SSO'), ('약', 'MM'), ('27', 'SN'), ('.', 'SY'), ('2', 'SN'), ('kg', 'SL'), (')', 'SSC'), ('당', 'XSN'), ('7', 'SN'), ('.', 'SY'), ('68', 'SN'), ('달러', 'NNG'), ('를', 'JKO'), ('기록', 'NNG'), ('해', 'XSV'), ('연초', 'NNG'), ('(', 'SSO'), ('5', 'SN'), ('.', 'SY'), ('89', 'SN'), ('달러', 'NNG'), (')', 'SSC'), ('대비', 'NNG'), ('30', 'SN'), ('.', 'SY'), ('4', 'SN'), ('%', 'SY'), ('뛰', 'VV'), ('었', 'EP'), ('다', 'EC')]
# [('같', 'VA'), ('은', 'ETM'), ('기간', 'NNG'), ('대두', 'NNG'), ('의', 'JKG'), ('선물', 'NNG'), ('가격', 'NNG'), ('(', 'SSO'), ('월물', 'NNBC'), (')', 'SSC'), ('은', 'JX'), ('13', 'SN'), ('.', 'SY'), ('71', 'SN'), ('달러', 'NNG'), ('에서', 'JKB'), ('16', 'SN'), ('.', 'SY'), ('52', 'SN'), ('달러', 'NNG'), ('로', 'JKB'), ('20', 'SN'), ('.', 'SY'), ('5', 'SN'), ('%', 'SY'), ('급등', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('한은', 'NNG'), ('관계자', 'NNG'), ('는', 'JX'), ('“', 'SSO'), ('러시아', 'NNG'), ('와', 'JC'), ('우크라이나', 'NNG'), ('전쟁', 'NNG'), ('으로', 'JKB'), ('곡물', 'NNG'), ('공급', 'NNG'), ('이', 'JKS'), ('굉장히', 'MAG'), ('제한적', 'VAX'), ('인', 'VCP'), ('데', 'NNB'), ('다', 'JX'), ('지난해', 'NNG'), ('부터', 'JX'), ('이어진', 'VV'), ('병목', 'NNG'), ('현상', 'NNG'), ('으로', 'JKB'), ('공급망', 'NNG'), ('도', 'JX'), ('망가진', 'VV'), ('상태', 'NNG'), ('”', 'SSC'), ('라며', 'VCP'), ('“', 'SSO'), ('기후변화', 'NNG'), ('등', 'NNB'), ('의', 'JKG'), ('영향', 'NNG'), ('으로', 'JKB'), ('작황', 'NNG'), ('조차', 'JX'), ('좋', 'VA'), ('지', 'EC'), ('않', 'VX'), ('아서', 'EC'), ('사료', 'NNG'), ('가격', 'NNG'), ('이', 'JKS'), ('폭등', 'NNG'), ('하', 'XSV'), ('며', 'EC'), ('달걀', 'NNG'), ('이나', 'JC'), ('닭고기', 'NNG'), ('가격', 'NNG'), ('등', 'NNB'), ('을', 'JKO'), ('밀', 'VV'), ('어', 'EC'), ('올리', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('설명', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('그래픽', 'NNG'), ('=', 'SY'), ('전유진', 'NNP'), ('인플레이션', 'NNG'), ('(', 'SSO'), ('물가', 'NNG'), ('상승', 'NNG'), (')', 'SSC'), ('을', 'JKO'), ('자극', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('건', 'NNB'), ('곡물', 'NNG'), ('뿐', 'JX'), ('만', 'JX'), ('이', 'JKC'), ('아니', 'VCN'), ('다', 'EC')]
# [('고공행진', 'NNG'), ('을', 'JKO'), ('이', 'VV'), ('어', 'EC'), ('가', 'VX'), ('는', 'ETM'), ('국제', 'NNG'), ('유가', 'NNG'), ('의', 'JKG'), ('영향', 'NNG'), ('으로', 'JKB'), ('석탄', 'NNG'), ('·', 'SC'), ('석유', 'NNG'), ('제품', 'NNG'), ('(', 'SSO'), ('5', 'SN'), ('.', 'SY'), ('9', 'SN'), ('%)', 'SY'), ('의', 'JKG'), ('가격', 'NNG'), ('도', 'JX'), ('전달', 'NNG'), ('보다', 'JKB'), ('상승', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('경유', 'NNG'), ('(', 'SSO'), ('8', 'SN'), ('.', 'SY'), ('3', 'SN'), ('%)', 'SY'), ('와', 'JC'), ('휘발유', 'NNG'), ('(', 'SSO'), ('9', 'SN'), ('.', 'SY'), ('8', 'SN'), ('%)', 'SY'), ('의', 'JKG'), ('가격', 'NNG'), ('이', 'JKS'), ('한', 'MM'), ('달', 'NNBC'), ('사이', 'NNG'), ('에', 'JKB'), ('크', 'VA'), ('게', 'EC'), ('오른', 'VV'), ('영향', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('1', 'SN'), ('년', 'NNBC'), ('전', 'NNG'), ('같', 'VA'), ('은', 'ETM'), ('달', 'NNG'), ('과', 'JC'), ('비교', 'NNG'), ('하', 'XSV'), ('면', 'EC'), ('경유', 'NNG'), ('(', 'SSO'), ('112', 'SN'), ('.', 'SY'), ('6', 'SN'), ('%)', 'SY'), ('와', 'JC'), ('나프타', 'NNG'), ('(', 'SSO'), ('64', 'SN'), ('.', 'SY'), ('2', 'SN'), ('%)', 'SY'), ('의', 'JKG'), ('가격', 'NNG'), ('은', 'JX'), ('그야말로', 'MAG'), ('폭등', 'NNG'), ('수준', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('PPI', 'SL'), ('상승세', 'NNG'), ('가', 'JKS'), ('계속', 'MAG'), ('되', 'VV'), ('면서', 'EC'), ('물가', 'NNG'), ('상승', 'NNG'), ('압력', 'NNG'), ('도', 'JX'), ('더욱', 'MAG'), ('커지', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('PPI', 'SL'), ('는', 'JX'), ('시차', 'NNG'), ('를', 'JKO'), ('두', 'VV'), ('고', 'EC'), ('소비자', 'NNG'), ('물가', 'NNG'), ('에', 'JKB'), ('영향', 'NNG'), ('을', 'JKO'), ('주', 'VV'), ('는', 'ETM'), ('선행', 'NNG'), ('지표', 'NNG'), ('역할', 'NNG'), ('을', 'JKO'), ('하', 'VV'), ('기', 'ETN'), ('때문', 'NNB'), ('이', 'VCP'), ('다', 'EC')]
# [('물가', 'NNG'), ('향방', 'NNG'), ('을', 'JKO'), ('가늠', 'NNG'), ('할', 'XSV'), ('수', 'NNB'), ('있', 'VV'), ('는', 'ETM'), ('일종', 'NNG'), ('의', 'JKG'), ('‘', 'SY'), ('예고편', 'NNG'), ('’', 'SY'), ('인', 'VCP'), ('셈', 'NNB'), ('이', 'VCP'), ('다', 'EC')]
# [('예', 'NNG'), ('를', 'JKO'), ('들', 'VV'), ('어', 'EC'), ('제조업체', 'NNG'), ('에서', 'JKB'), ('만드', 'VV'), ('는', 'ETM'), ('상품', 'NNG'), ('의', 'JKG'), ('원자재', 'NNG'), ('가격', 'NNG'), ('이나', 'JC'), ('유통비용', 'NNG'), ('등', 'NNB'), ('생산', 'NNG'), ('단가', 'NNG'), ('가', 'JKS'), ('올라가', 'VV'), ('면', 'EC'), (',', 'SC'), ('비용', 'NNG'), ('이', 'JKS'), ('올라간', 'VV'), ('만큼', 'NNB'), ('제품', 'NNG'), ('가격', 'NNG'), ('을', 'JKO'), ('밀', 'VV'), ('어', 'EC'), ('올리', 'VV'), ('는', 'ETM'), ('식', 'NNB'), ('이', 'VCP'), ('다', 'EC')]
# [('이런', 'MM'), ('분위기', 'NNG'), ('속', 'NNG'), ('한은', 'NNG'), ('도', 'JX'), ('지난해', 'NNG'), ('부터', 'JX'), ('올해', 'NNG'), ('의', 'JKG'), ('물가', 'NNG'), ('상승률', 'NNG'), ('전망치', 'NNG'), ('를', 'JKO'), ('높여', 'VV'), ('잡', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('지난달', 'NNG'), ('26', 'SN'), ('일', 'NNG'), ('수정', 'NNG'), ('경제', 'NNG'), ('전망', 'NNG'), ('에서', 'JKB'), ('한은', 'NNG'), ('은', 'JX'), ('올해', 'NNG'), ('의', 'JKG'), ('소비자', 'NNG'), ('물가', 'NNG'), ('상승률', 'NNG'), ('전망', 'NNG'), ('치를', 'XSV'), ('4', 'SN'), ('.', 'SY'), ('5', 'SN'), ('%', 'SY'), ('로', 'JKB'), ('예상', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('이', 'NP'), ('는', 'JX'), ('지난', 'VV'), ('2', 'SN'), ('월', 'NNBC'), ('(', 'SSO'), ('3', 'SN'), ('.', 'SY'), ('1', 'SN'), ('%)', 'SY'), ('과', 'JC'), ('지난해', 'NNG'), ('11', 'SN'), ('월', 'NNBC'), ('(', 'SSO'), ('2', 'SN'), ('.', 'SY'), ('0', 'SN'), ('%)', 'SY'), ('에', 'JKB'), ('내놓', 'VV'), ('은', 'ETM'), ('전망치', 'NNG'), ('보다', 'JKB'), ('각각', 'MAG'), ('1', 'SN'), ('.', 'SY'), ('4', 'SN'), ('%', 'SY'), ('포인트', 'NNG'), ('와', 'JC'), ('2', 'SN'), ('.', 'SY'), ('5', 'SN'), ('%', 'SY'), ('포인트', 'NNG'), ('가', 'JKS'), ('오른', 'VV'), ('수준', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('그래픽', 'NNG'), ('=', 'SY'), ('전유진', 'NNP'), ('문제', 'NNG'), ('는', 'JX'), ('PPI', 'SL'), ('가', 'JKS'), ('앞', 'NNG'), ('으로', 'JKB'), ('더', 'MAG'), ('오를', 'VV'), ('가능성', 'NNG'), ('이', 'JKS'), ('높', 'VA'), ('다는', 'ETM'), ('점', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('한은', 'NNG'), ('관계자', 'NNG'), ('“', 'SSO'), ('국내', 'NNG'), ('요인', 'NNG'), ('보다', 'JKB'), ('는', 'JX'), ('(', 'SSO'), ('국제', 'NNG'), ('유가', 'NNG'), ('와', 'JC'), ('우크라이나사태', 'NNG'), ('등', 'NNB'), (')', 'SSC'), ('대부분', 'NNG'), ('해외', 'NNG'), ('에서', 'JKB'), ('오', 'VV'), ('는', 'ETM'), ('요인', 'NNG'), ('이', 'JKS'), ('물가', 'NNG'), ('에', 'JKB'), ('복합', 'NNG'), ('적', 'XSN'), ('으로', 'JKB'), ('작용', 'NNG'), ('하', 'XSV'), ('고', 'EC'), ('있', 'VX'), ('어', 'EF'), (',', 'SC'), ('국내', 'NNG'), ('에서', 'JKB'), ('자체', 'NNG'), ('대응', 'NNG'), ('하', 'XSV'), ('거나', 'EC'), ('해결', 'NNG'), ('할', 'XSV'), ('수', 'NNB'), ('있', 'VV'), ('는', 'ETM'), ('여력', 'NNG'), ('이', 'JKS'), ('충분', 'NNG'), ('하', 'XSA'), ('지', 'EC'), ('않', 'VX'), ('은', 'ETM'), ('만큼', 'NNB'), ('물가', 'NNG'), ('상방', 'NNG'), ('압력', 'NNG'), ('이', 'JKS'), ('계속', 'MAG'), ('커질', 'VV'), ('확률', 'NNG'), ('이', 'JKS'), ('높', 'VA'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('분석', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('물가', 'NNG'), ('가', 'JKS'), ('쉽', 'VA'), ('게', 'EC'), ('잡히', 'VV'), ('지', 'EC'), ('않', 'VX'), ('으며', 'EC'), ('국내', 'NNG'), ('경제', 'NNG'), ('에', 'JKB'), ('도', 'JX'), ('‘', 'SY'), ('S', 'SL'), ('(', 'SSO'), ('스태그플레이션', 'NNG'), ('·', 'SC'), ('경기', 'NNG'), ('침체', 'NNG'), ('+', 'SY'), ('물가', 'NNG'), ('상승', 'NNG'), (')', 'SSC'), ('의', 'JKG'), ('공포', 'NNG'), ('’', 'SY'), ('가', 'JKS'), ('짙', 'VA'), ('어', 'EC'), ('지', 'VX'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('국제', 'NNG'), ('에너지', 'NNG'), ('와', 'JC'), ('원자재', 'NNG'), ('가격', 'NNG'), ('상승', 'NNG'), ('으로', 'JKB'), ('경기', 'NNG'), ('가', 'JKS'), ('위축', 'NNG'), ('된', 'XSV'), ('상황', 'NNG'), ('에서', 'JKB'), ('한은', 'NNG'), ('이', 'JKS'), ('물가', 'NNG'), ('를', 'JKO'), ('잡', 'VV'), ('기', 'ETN'), ('위해', 'VV'), ('기준금리', 'NNG'), ('를', 'JKO'), ('올리', 'VV'), ('면', 'EC'), ('경기', 'NNG'), ('침체', 'NNG'), ('가', 'JKS'), ('찾아올', 'VV'), ('가능성', 'NNG'), ('이', 'JKS'), ('커지', 'VV'), ('기', 'ETN'), ('때문', 'NNB'), ('이', 'VCP'), ('다', 'EC')]
# [('안동현', 'NNP'), ('서울대', 'NNP'), ('경제', 'NNG'), ('학부', 'NNG'), ('교수', 'NNG'), ('는', 'JX'), ('“', 'SSO'), ('지난해', 'NNG'), ('부터', 'JX'), ('물가', 'NNG'), ('상승세', 'NNG'), ('가', 'JKS'), ('이어지', 'VV'), ('는', 'ETM'), ('상황', 'NNG'), ('에서', 'JKB'), (',', 'SC'), ('올해', 'NNG'), ('초', 'XPN'), ('발생', 'NNG'), ('한', 'XSA'), ('우크라이나사태', 'NNG'), ('가', 'JKS'), ('각국', 'NNG'), ('의', 'JKG'), ('물가', 'NNG'), ('상승', 'NNG'), ('압력', 'NNG'), ('을', 'JKO'), ('더욱', 'MAG'), ('높이', 'VV'), ('는', 'ETM'), ('데', 'NNB'), ('결정', 'NNG'), ('적', 'XSN'), ('역할', 'NNG'), ('을', 'JKO'), ('했', 'VV'), ('다', 'EC'), ('”', 'SSC'), ('며', 'EC'), ('“', 'SSO'), ('이런', 'MM'), ('추세', 'NNG'), ('가', 'JKS'), ('계속', 'NNG'), ('될', 'XSV'), ('경우', 'NNG'), ('미', 'NNG'), ('연방준비제도', 'NNG'), ('Fed', 'NNG'), ('나', 'JC'), ('한은', 'NNG'), ('이', 'JKS'), ('경기', 'NNG'), ('침체', 'NNG'), ('를', 'JKO'), ('감수', 'NNG'), ('하', 'XSV'), ('고서라도', 'EC'), ('기준금리', 'NNG'), ('를', 'JKO'), ('계속', 'MAG'), ('올릴', 'VV'), ('수', 'NNB'), ('밖에', 'JX'), ('없', 'VA'), ('는', 'ETM'), ('상황', 'NNG'), ('이', 'JKS'), ('찾아올', 'VV'), ('것', 'NNB'), ('”', 'SSC'), ('이', 'VCP'), ('라고', 'EC'), ('분석', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('youn', 'SL'), ('.', 'SF')]
# 2022-06-24의 문서 1 토큰화 결과:
# [('조', 'NNP'), ('바이든', 'NNP'), ('미국', 'NNG'), ('대통령', 'NNG'), ('이', 'JKS'), ('22', 'SN'), ('일', 'NNG'), ('(', 'SSO'), ('현지', 'NNG'), ('시간', 'NNG'), (')', 'SSC'), ('백악관', 'NNG'), ('사우스', 'NNP'), ('코트', 'NNG'), ('강당', 'NNG'), ('에서', 'JKB'), ('유가', 'NNG'), ('대응', 'NNG'), ('과', 'JC'), ('관련', 'NNG'), ('해', 'XSV'), ('연설', 'NNG'), ('하', 'XSV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('바이든', 'NNP'), ('대통령', 'NNG'), ('은', 'JX'), ('이날', 'NNG'), ('의회', 'NNG'), ('에', 'JKB'), ('향후', 'MAG'), ('90', 'SN'), ('일', 'NNG'), ('간', 'NNG'), ('연방', 'NNG'), ('유류세', 'NNG'), ('면제', 'NNG'), ('를', 'JKO'), ('요청', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('“', 'SSO'), ('주식', 'NNG'), ('수익률', 'NNG'), ('이', 'JKS'), ('-', 'SY'), ('28', 'SN'), ('%', 'SY'), ('인데', 'VCP'), ('도', 'JX'), ('끝내', 'MAG'), ('손절', 'NNG'), ('손절매', 'NNG'), ('했', 'XSV'), ('네요', 'EC')]
# [('올해', 'NNG'), ('여름휴가', 'NNG'), ('는', 'JX'), ('포기', 'NNG'), ('예요', 'VCP')]
# [('”', 'SSC'), ('회사원', 'NNG'), ('박모', 'NNG'), ('(', 'SSO'), ('34', 'SN'), (')', 'SSC'), ('씨', 'NNB'), ('는', 'JX'), ('1', 'SN'), ('년', 'NNBC'), ('여간', 'MAG'), ('모아', 'VV'), ('왔', 'VX'), ('던', 'ETM'), ('주식', 'NNG'), ('을', 'JKO'), ('이달', 'NNG'), ('들', 'VV'), ('어', 'EC'), ('나눠', 'VV'), ('팔', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('주식', 'NNG'), ('이', 'JKS'), ('오를', 'VV'), ('기미', 'NNG'), ('가', 'JKS'), ('보이', 'VV'), ('지', 'EC'), ('않', 'VX'), ('아서', 'EC'), ('다', 'MAG')]
# [('그', 'NP'), ('는', 'JX'), ('주가', 'NNG'), ('가', 'JKS'), ('바닥', 'NNG'), ('권', 'XSN'), ('이', 'VCP'), ('라고', 'EC'), ('생각', 'NNG'), ('해', 'XSV'), ('지난해', 'NNG'), ('부터', 'JX'), ('삼성전자', 'NNP'), ('와', 'JC'), ('네이버', 'NNP'), (',', 'SC'), ('카카오', 'NNP'), ('등', 'NNB'), ('코스피', 'NNG'), ('시가총액', 'NNG'), ('상위', 'NNG'), ('10', 'SN'), ('위', 'NNBC'), ('종목', 'NNG'), ('에', 'JKB'), ('적립식', 'NNG'), ('으로', 'JKB'), ('투자', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('꾸준', 'NNG'), ('한', 'XSA'), ('‘', 'SY'), ('물타기', 'NNG'), ('’(', 'SY'), ('매수', 'NNG'), ('단가', 'NNG'), ('를', 'JKO'), ('낮추', 'VV'), ('기', 'ETN'), ('위한', 'VV'), ('추가', 'NNG'), ('매수', 'NNG'), (')', 'SSC'), ('로', 'JKB'), ('누적', 'NNG'), ('투', 'NR'), ('자금', 'NNG'), ('은', 'JX'), ('3000', 'SN'), ('만', 'NR'), ('원', 'NNBC'), ('을', 'JKO'), ('넘겼', 'VV'), ('지만', 'EC'), (',', 'SC'), ('현재', 'MAG'), ('수익률', 'NNG'), ('은', 'JX'), ('-', 'SY'), ('28', 'SN'), ('%', 'SY'), ('정도', 'NNG'), ('다', 'VCP')]
# [('그', 'NP'), ('는', 'JX'), ('“', 'SSO'), ('바닥', 'NNG'), ('아래', 'NNG'), ('지하실', 'NNG'), ('이', 'JKS'), ('있', 'VV'), ('다더니', 'EC'), (',', 'SC'), ('무서워서', 'VA'), ('더', 'MAG'), ('는', 'JX'), ('매수', 'NNG'), ('할', 'XSV'), ('수', 'NNB'), ('가', 'JKS'), ('없', 'VA'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('말', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('최근', 'NNG'), ('국내', 'NNG'), ('증시', 'NNG'), ('가', 'JKS'), ('급락', 'NNG'), ('하', 'XSV'), ('며', 'EC'), ('국내', 'NNG'), ('증시', 'NNG'), ('버팀목', 'NNG'), ('역할', 'NNG'), ('을', 'JKO'), ('했', 'VV'), ('던', 'ETM'), ('‘', 'SY'), ('동학', 'NNG'), ('개미', 'NNG'), ('’', 'SY'), ('가', 'JKS'), ('돌아서', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('바닥', 'NNG'), ('없이', 'MAG'), ('미끄러지', 'VV'), ('는', 'ETM'), ('시장', 'NNG'), ('에', 'JKB'), ('지친', 'VV'), ('개인', 'NNG'), ('투자자', 'NNG'), ('의', 'JKG'), ('‘', 'SY'), ('팔자', 'NNG'), ('’', 'SY'), ('엔', 'NNG'), ('개미', 'NNG'), ('의', 'JKG'), ('‘', 'SY'), ('항복', 'NNG'), ('신호', 'NNG'), ('’', 'SY'), ('라는', 'VCP'), ('시각', 'NNG'), ('도', 'JX'), ('나온다', 'VV')]
# [('또', 'MAG'), ('원화가치', 'NNG'), ('는', 'ETM'), ('연일', 'NNG'), ('급락세', 'NNG'), ('를', 'JKO'), ('보이', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('제롬', 'NNP'), ('파월', 'NNP'), ('미', 'NNG'), ('연방준비제도', 'NNG'), ('Fed', 'NNG'), ('의장', 'NNG'), ('이', 'JKS'), ('22', 'SN'), ('일', 'NNG'), ('(', 'SSO'), ('현지', 'NNG'), ('시간', 'NNG'), (')', 'SSC'), ('미', 'NNG'), ('상원은행위원회', 'NNP'), ('에', 'JKB'), ('한', 'MM'), ('발언', 'NNG'), ('이', 'JKS'), ('도화선', 'NNG'), ('이', 'JKS'), ('됐', 'VV'), ('다', 'EC')]
# [('파월', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('경기', 'NNG'), ('침체', 'NNG'), ('가능성', 'NNG'), ('이', 'JKS'), ('존재', 'NNG'), ('하', 'XSV'), ('며', 'EC'), ('경제', 'NNG'), ('연착륙', 'NNG'), ('은', 'JX'), ('매우', 'MAG'), ('도전', 'NNG'), ('적', 'XSN'), ('인', 'VCP'), ('일', 'NNG'), ('”', 'SSC'), ('이', 'VCP'), ('라면서', 'EC'), ('도', 'JX'), ('“', 'SSO'), ('인플레이션', 'NNG'), ('(', 'SSO'), ('물가', 'NNG'), ('상승', 'NNG'), (')', 'SSC'), ('이', 'JKS'), ('둔화', 'NNG'), ('하', 'XSV'), ('고', 'EC'), ('있', 'VX'), ('다는', 'ETM'), ('증거', 'NNG'), ('를', 'JKO'), ('확인', 'NNG'), ('할', 'XSV'), ('때', 'NNG'), ('까지', 'JX'), ('금리', 'NNG'), ('인상', 'NNG'), ('을', 'JKO'), ('지속', 'NNG'), ('하', 'XSV'), ('겠', 'EP'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('말', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('23', 'SN'), ('일', 'NNG'), ('코스피', 'NNG'), ('는', 'JX'), ('전날', 'NNG'), ('보다', 'JKB'), ('1', 'SN'), ('.', 'SY'), ('22', 'SN'), ('%', 'SY'), ('내린', 'VV'), ('2314', 'SN'), ('.', 'SY'), ('32', 'SN'), ('에', 'JKB'), ('마감', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('52', 'SN'), ('주', 'NNBC'), ('최저치', 'NNG'), ('(', 'SSO'), ('2339', 'SN'), ('.', 'SY'), ('64', 'SN'), (')', 'SSC'), ('를', 'JKO'), ('다시', 'MAG'), ('갈', 'VV'), ('아', 'EC'), ('치웠', 'VX'), ('다', 'EC')]
# [('장', 'NNG'), ('중', 'NNG'), ('에', 'JKB'), ('는', 'JX'), ('2306', 'SN'), ('.', 'SY'), ('48', 'SN'), ('까지', 'JX'), ('밀리', 'VV'), ('며', 'EC'), ('2300', 'SN'), ('선', 'NNG'), ('도', 'JX'), ('위태', 'NNG'), ('로웠', 'XSA'), ('다', 'EC')]
# [('코스닥', 'NNG'), ('은', 'JX'), ('전날', 'NNG'), ('보다', 'JKB'), ('4', 'SN'), ('.', 'SY'), ('36', 'SN'), ('%', 'SY'), ('급락', 'NNG'), ('한', 'XSA'), ('714', 'SN'), ('.', 'SY'), ('38', 'SN'), ('에', 'JKB'), ('장', 'NNG'), ('을', 'JKO'), ('마쳤', 'VV'), ('다', 'EC')]
# [('역시', 'MAJ'), ('52', 'SN'), ('주', 'NNBC'), ('최저치', 'NNG'), ('를', 'JKO'), ('새로', 'MAG'), ('썼', 'VV'), ('다', 'EC')]
# [('이날', 'NNG'), ('한국거래소', 'NNP'), ('에', 'JKB'), ('따르', 'VV'), ('면', 'EC'), ('코스피', 'NNG'), ('와', 'JC'), ('코스닥', 'NNG'), ('시장', 'NNG'), ('에', 'JKB'), ('상장', 'NNG'), ('된', 'XSV'), ('종목', 'NNG'), ('2502', 'SN'), ('개', 'NNBC'), ('가운데', 'NNG'), ('52', 'SN'), ('주', 'NNBC'), ('신저가', 'NNG'), ('(', 'SSO'), ('체결', 'NNG'), ('가', 'JKS'), ('기준', 'NNG'), (')', 'SSC'), ('를', 'JKO'), ('경신', 'NNG'), ('한', 'XSA'), ('종목', 'NNG'), ('수', 'NNG'), ('는', 'JX'), ('1391', 'SN'), ('개', 'NNBC'), ('(', 'SSO'), ('55', 'SN'), ('.', 'SY'), ('6', 'SN'), ('%)', 'SY'), ('에', 'JKB'), ('달했', 'VV'), ('다', 'EC')]
# [('특히', 'MAG'), ('코스피', 'NNG'), ('시장', 'NNG'), ('에서', 'JKB'), ('국내', 'NNG'), ('증시', 'NNG'), ('대표', 'NNG'), ('주인', 'NNG'), ('삼성전자', 'NNP'), ('(', 'SSO'), ('장중', 'NNG'), ('5', 'SN'), ('만', 'NR'), ('6800', 'SN'), ('원', 'NNBC'), (')', 'SSC'), ('와', 'JC'), ('SK하이닉스', 'NNP'), ('(', 'SSO'), ('8', 'SN'), ('만', 'NR'), ('9700', 'SN'), ('원', 'NNBC'), (')', 'SSC'), ('를', 'JKO'), ('비롯', 'NNG'), ('해', 'XSA'), ('카카오', 'NNP'), ('(', 'SSO'), ('6', 'SN'), ('만', 'NR'), ('6700', 'SN'), ('원', 'NNBC'), (')', 'SSC'), (',', 'SC'), ('카카오페이', 'NNP'), ('(', 'SSO'), ('6', 'SN'), ('만', 'NR'), ('4800', 'SN'), ('원', 'NNBC'), (')', 'SSC'), ('등', 'NNB'), ('이', 'JKS'), ('52', 'SN'), ('주', 'NNBC'), ('신저가', 'NNG'), ('를', 'JKO'), ('경신', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('최근', 'NNG'), ('개인', 'NNG'), ('의', 'JKG'), ('팔', 'NR'), ('자세', 'NNG'), ('가', 'JKS'), ('두드러진다', 'VV')]
# [('개미', 'NNG'), ('의', 'JKG'), ('‘', 'SY'), ('팔자', 'NNG'), ('’', 'SY'), ('는', 'JX'), ('시장', 'NNG'), ('은', 'JX'), ('인내심', 'NNG'), ('이', 'JKS'), ('바닥난', 'VV'), ('개인', 'NNG'), ('투자자', 'NNG'), ('의', 'JKG'), ('‘', 'SY'), ('항복', 'NNG'), ('신호', 'NNG'), ('’', 'SY'), ('란', 'VCP'), ('진단', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('이달', 'NNG'), ('들', 'VV'), ('어', 'EC'), ('15', 'SN'), ('거래일', 'NNG'), ('동안', 'NNG'), ('개인', 'NNG'), ('이', 'JKS'), ('순매도', 'NNG'), ('로', 'JKB'), ('거래', 'NNG'), ('를', 'JKO'), ('마친', 'VV'), ('건', 'NNB'), ('이날', 'NNG'), ('포함', 'NNG'), ('4', 'SN'), ('거래일', 'NNG'), ('(', 'SSO'), ('3', 'SN'), ('일', 'NNG'), ('·', 'SC'), ('16', 'SN'), ('일', 'NNG'), ('·', 'SC'), ('21', 'SN'), ('일', 'NNG'), ('·', 'SC'), ('23', 'SN'), ('일', 'NNG'), (')', 'SSC'), ('뿐', 'JX'), ('이', 'VCP'), ('다', 'EC')]
# [('순매도', 'NNG'), ('규모', 'NNG'), ('도', 'JX'), ('이달', 'NNG'), ('들', 'VV'), ('어', 'EC'), ('가장', 'MAG'), ('컸', 'VA'), ('다', 'EC')]
# [('그래픽', 'NNG'), ('=', 'SY'), ('그동안', 'MAG'), ('세', 'MM'), ('차례', 'NNG'), ('있', 'VV'), ('었', 'EP'), ('던', 'ETM'), ('개인', 'NNG'), ('투자자', 'NNG'), ('의', 'JKG'), ('순매도', 'NNG'), ('는', 'JX'), ('시장', 'NNG'), ('반등시', 'NNG'), ('손실', 'NNG'), ('폭', 'NNG'), ('을', 'JKO'), ('줄이', 'VV'), ('기', 'ETN'), ('위한', 'VV'), ('것', 'NNB'), ('이', 'VCP'), ('었', 'EP'), ('다면', 'EC'), (',', 'SC'), ('이날', 'NNG'), ('은', 'JX'), ('손해', 'NNG'), ('를', 'JKO'), ('무릅쓴', 'VV'), ('‘', 'SY'), ('투매', 'NNG'), ('’', 'SY'), ('의', 'JKG'), ('성격', 'NNG'), ('이', 'JKS'), ('강했', 'VV'), ('다는', 'ETM'), ('게', 'NNB'), ('시장', 'NNG'), ('의', 'JKG'), ('시각', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('박광남', 'NNP'), ('미래에셋증권', 'NNP'), ('디지털', 'NNG'), ('리서치', 'NNG'), ('팀장', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('코스피', 'NNG'), ('와', 'JC'), ('코스닥', 'NNG'), ('이', 'JKS'), ('한', 'MM'), ('달', 'NNBC'), ('간', 'NNG'), ('10', 'SN'), ('~', 'SY'), ('18', 'SN'), ('%', 'SY'), ('급락', 'NNG'), ('하', 'XSV'), ('자', 'EC'), ('투자심리', 'NNG'), ('가', 'JKS'), ('완전히', 'MAG'), ('무너졌', 'VV'), ('다', 'EC'), ('”', 'SSC'), ('며', 'EC'), ('“', 'SSO'), ('소위', 'NNG'), ('백기', 'NNG'), ('투항', 'NNG'), ('의', 'JKG'), ('모습', 'NNG'), ('”', 'SSC'), ('이', 'VCP'), ('라고', 'EC'), ('진단', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('무너지', 'VV'), ('는', 'ETM'), ('시장', 'NNG'), ('의', 'JKG'), ('잔해', 'NNG'), ('속', 'NNG'), ('에', 'JKB'), ('도', 'JX'), ('개인', 'NNG'), ('투자자', 'NNG'), ('는', 'JX'), ('국내', 'NNG'), ('증시', 'NNG'), ('에', 'JKB'), ('대한', 'VV'), ('믿음', 'NNG'), ('을', 'JKO'), ('보여', 'VV'), ('왔', 'VX'), ('다', 'EC')]
# [('23', 'SN'), ('일', 'NNG'), ('기준', 'NNG'), ('연초', 'NNG'), ('이후', 'NNG'), ('코스피', 'NNG'), ('시장', 'NNG'), ('에서', 'JKB'), ('외국인', 'NNG'), ('(', 'SSO'), ('14', 'SN'), ('조', 'NR'), ('4020', 'SN'), ('억', 'NR'), ('원', 'NNBC'), (')', 'SSC'), ('과', 'JC'), ('기관', 'NNG'), ('(', 'SSO'), ('12', 'SN'), ('조', 'NR'), ('7740', 'SN'), ('억', 'NR'), ('원', 'NNBC'), (')', 'SSC'), ('이', 'JKS'), ('27', 'SN'), ('조', 'NR'), ('1760', 'SN'), ('억', 'NR'), ('원', 'NNBC'), ('어치', 'NNG'), ('를', 'JKO'), ('팔', 'VV'), ('아', 'EC'), ('치울', 'VX'), ('때', 'NNG'), ('개인', 'NNG'), ('만', 'JX'), ('25', 'SN'), ('조', 'NR'), ('4190', 'SN'), ('억', 'NR'), ('원', 'NNBC'), ('순매수', 'NNG'), ('를', 'JKO'), ('기록', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('이경민', 'NNP'), ('대신증권', 'NNP'), ('투자전략', 'NNG'), ('팀장', 'NNP'), ('도', 'JX'), ('“', 'SSO'), ('수급', 'NNG'), ('의', 'JKG'), ('중심', 'NNG'), ('에', 'JKB'), ('있', 'VV'), ('던', 'ETM'), ('개인', 'NNG'), ('이', 'JKS'), ('버티', 'VV'), ('지', 'EC'), ('못하', 'VX'), ('며', 'EC'), ('매물', 'NNG'), ('이', 'JKS'), ('쏟아졌', 'VV'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('설명', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('그래픽', 'NNG'), ('=', 'SY'), ('김현서', 'NNP'), ('kim', 'SL'), ('.', 'SY'), ('원화값', 'NNG'), ('의', 'JKG'), ('경우', 'NNG'), ('‘', 'SY'), ('1', 'SN'), ('달러', 'NNG'), ('=', 'SY'), ('1300', 'SN'), ('원', 'NNBC'), ('’', 'SY'), ('시대', 'NNG'), ('가', 'JKS'), ('열렸', 'VV'), ('다', 'EC')]
# [('세계', 'NNG'), ('금융위기', 'NNG'), ('이후', 'NNG'), ('13', 'SN'), ('년', 'NNBC'), ('만', 'NNB'), ('이', 'VCP'), ('다', 'EC')]
# [('이날', 'NNG'), ('서울', 'NNP'), ('외환시장', 'NNG'), ('에서', 'JKB'), ('원화값', 'NNG'), ('은', 'JX'), ('전날', 'NNG'), ('(', 'SSO'), ('1297', 'SN'), ('.', 'SY'), ('3', 'SN'), ('원', 'NNBC'), (')', 'SSC'), ('보다', 'JKB'), ('4', 'SN'), ('.', 'SY'), ('5', 'SN'), ('원', 'NNBC'), ('내린', 'VV'), ('(', 'SSO'), ('환율', 'NNG'), ('상승', 'NNG'), (')', 'SSC'), ('달러', 'NNG'), ('당', 'XSN'), ('1301', 'SN'), ('.', 'SY'), ('8', 'SN'), ('원', 'NNBC'), ('에', 'JKB'), ('거래', 'NNG'), ('를', 'JKO'), ('마쳤', 'VV'), ('다', 'EC')]
# [('원화값', 'NNG'), ('이', 'JKS'), ('종가', 'NNG'), ('기준', 'NNG'), ('으로', 'JKB'), ('달러', 'NNG'), ('당', 'XSN'), ('1300', 'SN'), ('원', 'NNBC'), ('을', 'JKO'), ('밑', 'NNG'), ('돈', 'NNBC'), ('건', 'NNB'), ('세계', 'NNG'), ('금융위기', 'NNG'), ('때', 'NNG'), ('인', 'VCP'), ('2008', 'SN'), ('년', 'NNBC'), ('7', 'SN'), ('월', 'NNBC'), ('13', 'SN'), ('일', 'NNG'), ('(', 'SSO'), ('달러', 'NNG'), ('당', 'XSN'), ('1315', 'SN'), ('원', 'NNBC'), (')', 'SSC'), ('이후', 'NNG'), ('12', 'SN'), ('년', 'NNBC'), ('11', 'SN'), ('개월', 'NNBC'), ('여', 'XSN'), ('만', 'NNB'), ('이', 'VCP'), ('다', 'EC')]
# [('최근', 'NNG'), ('원화가치', 'NNG'), ('추락', 'NNG'), ('에', 'JKB'), ('는', 'JX'), ('날개', 'NNG'), ('가', 'JKS'), ('없', 'VA'), ('다', 'EC')]
# [('원화가치', 'NNG'), ('는', 'ETM'), ('종가', 'NNG'), ('기준', 'NNG'), ('으로', 'JKB'), ('지난', 'VV'), ('20', 'SN'), ('일', 'NNG'), ('부터', 'JX'), ('4', 'SN'), ('거래일', 'NNG'), ('연속', 'NNG'), ('연저점', 'NNG'), ('을', 'JKO'), ('갈아치우', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('이번', 'NNG'), ('주', 'NNG'), ('들', 'VV'), ('어', 'EC'), ('이날', 'NNG'), ('까지', 'JX'), ('달러', 'NNG'), ('당', 'XSN'), ('14', 'SN'), ('.', 'SY'), ('5', 'SN'), ('원', 'NNBC'), ('이', 'JKS'), ('빠졌', 'VV'), ('다', 'EC')]
# [('원화값', 'NNG'), ('이', 'JKS'), ('달러', 'NNG'), ('당', 'XSN'), ('1300', 'SN'), ('원', 'NNBC'), ('선', 'NNG'), ('을', 'JKO'), ('뚫', 'VV'), ('고', 'EC'), ('미끄러지', 'VV'), ('자', 'EC'), ('정부', 'NNG'), ('도', 'JX'), ('구두', 'NNG'), ('개입', 'NNG'), ('에', 'JKB'), ('나섰', 'VV'), ('지만', 'EC'), (',', 'SC'), ('원화값', 'NNG'), ('약세', 'NNG'), ('를', 'JKO'), ('막', 'VV'), ('기', 'ETN'), ('에', 'JKB'), ('는', 'JX'), ('역부족', 'NNG'), ('이', 'VCP'), ('었', 'EP'), ('다', 'EC')]
# [('환율', 'NNG'), ('방어', 'NNG'), ('도', 'JX'), ('쉽', 'VA'), ('지', 'EC'), ('않', 'VX'), ('다', 'EC')]
# [('물가', 'NNG'), ('가', 'JKS'), ('잡힐', 'VV'), ('때', 'NNG'), ('까지', 'JX'), ('원화값', 'NNG'), ('하락', 'NNG'), ('압력', 'NNG'), ('이', 'JKS'), ('이어질', 'VV'), ('수', 'NNB'), ('밖에', 'JX'), ('서다', 'NNG')]
# [('그렇', 'VA'), ('지', 'EC'), ('않', 'VX'), ('아도', 'EC'), ('수입', 'NNG'), ('물가', 'NNG'), ('등', 'NNB'), ('이', 'JKS'), ('뛰', 'VV'), ('며', 'EC'), ('비상', 'NNG'), ('이', 'JKS'), ('걸린', 'VV'), ('한국', 'NNG'), ('경제', 'NNG'), ('에', 'JKB'), ('빨간불이', 'VA'), ('켜', 'VV'), ('지', 'VX'), ('게', 'EC'), ('됐', 'VV'), ('다', 'EC')]
# [('원화값', 'NNG'), ('추락', 'NNG'), ('을', 'JKO'), ('이끄', 'VV'), ('는', 'ETM'), ('건', 'NNB'), ('기본', 'NNG'), ('적', 'XSN'), ('으로', 'JKB'), ('Fed', 'NNG'), ('의', 'JKG'), ('긴축', 'NNG'), ('이', 'JKS'), ('불', 'VV'), ('붙인', 'EC'), ('안전자산', 'NNG'), ('선호', 'NNG'), ('현상', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('하나은행', 'NNP'), ('서정훈', 'NNP'), ('연구원', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('경기', 'NNG'), ('침체', 'NNG'), ('를', 'JKO'), ('감수', 'NNG'), ('하', 'XSV'), ('더라도', 'EC'), ('금리', 'NNG'), ('를', 'JKO'), ('올리', 'VV'), ('겠', 'EP'), ('다는', 'ETM'), ('파월', 'NNP'), ('의', 'JKG'), ('발언', 'NNG'), ('에', 'JKB'), ('달러', 'NNG'), ('를', 'JKO'), ('사', 'VV'), ('려는', 'ETM'), ('수요', 'NNG'), ('가', 'JKS'), ('늘어난', 'VV'), ('게', 'NNB'), ('원화가치', 'NNG'), ('가', 'JKS'), ('달러', 'NNG'), ('당', 'XSN'), ('1300', 'SN'), ('원', 'NNBC'), ('밑', 'NNG'), ('으로', 'JKB'), ('떨어진', 'VV'), ('이유', 'NNG'), ('”', 'SSC'), ('라고', 'VCP'), ('말', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('수출', 'NNG'), ('의존도', 'NNG'), ('가', 'JKS'), ('높', 'VA'), ('은', 'ETM'), ('한국', 'NNG'), ('경제', 'NNG'), ('특성', 'NNG'), ('도', 'JX'), ('원화값', 'NNG'), ('약세', 'NNG'), ('의', 'JKG'), ('또', 'MAG'), ('다른', 'MM'), ('이유', 'NNG'), ('로', 'JKB'), ('꼽힌다', 'VV')]
# [('원자재', 'NNG'), ('가격', 'NNG'), ('상승', 'NNG'), ('등', 'NNB'), ('으로', 'JKB'), ('무역수지', 'NNG'), ('적자', 'NNG'), ('가', 'JKS'), ('쌓이', 'VV'), ('면서', 'EC'), ('원화가치', 'NNG'), ('가', 'JKS'), ('떨어지', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('산업통상자원부', 'NNG'), ('에', 'JKB'), ('따르', 'VV'), ('면', 'EC'), ('올해', 'NNG'), ('1', 'SN'), ('~', 'SY'), ('5', 'SN'), ('월', 'NNBC'), ('무역수지', 'NNG'), ('는', 'JX'), ('78', 'SN'), ('억', 'NR'), ('5000', 'SN'), ('만', 'NR'), ('달러', 'NNG'), ('적자', 'NNG'), ('를', 'JKO'), ('기록', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('지난해', 'NNG'), ('같', 'VA'), ('은', 'ETM'), ('기간', 'NNG'), ('에', 'JKB'), ('는', 'JX'), ('131', 'SN'), ('억', 'NR'), ('1000', 'SN'), ('만', 'NR'), ('달러', 'NNG'), ('흑자', 'NNG'), ('를', 'JKO'), ('기록', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('지난', 'VV'), ('10', 'SN'), ('일', 'NNG'), ('미국', 'NNG'), ('재무', 'NNG'), ('부가', 'NNG'), ('공개', 'NNG'), ('한', 'XSA'), ('‘', 'SY'), ('주요', 'NNG'), ('교역', 'NNG'), ('상대국', 'NNG'), ('의', 'JKG'), ('거시경제', 'NNG'), ('환율정책', 'NNG'), ('보고서', 'NNG'), ('’', 'SY'), ('에서', 'JKB'), ('도', 'JX'), ('“', 'SSO'), ('원자재', 'NNG'), ('가격', 'NNG'), ('상승', 'NNG'), ('에', 'JKB'), ('따른', 'VV'), ('상품', 'NNG'), ('무역수지', 'NNG'), ('의', 'JKG'), ('완화', 'NNG'), ('축소', 'NNG'), ('와', 'JC'), ('세계', 'NNG'), ('적', 'XSN'), ('인', 'VCP'), ('금리', 'NNG'), ('인상', 'NNG'), (',', 'SC'), ('지정학', 'NNG'), ('적', 'XSN'), ('불확실성', 'NNG'), ('고조', 'NNG'), ('에', 'JKB'), ('따른', 'VV'), ('상당', 'NNG'), ('한', 'XSA'), ('자본', 'NNG'), ('유출', 'NNG'), ('이', 'JKS'), ('원화', 'NNG'), ('약세', 'NNG'), ('의', 'JKG'), ('지속', 'NNG'), ('적', 'XSN'), ('원인', 'NNG'), ('이', 'JKS'), ('됐', 'VV'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('분석', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('안효성', 'NNP'), ('·', 'SC')]
# 2022-06-24의 문서 2 토큰화 결과:
# [('서울', 'NNP'), ('아파트', 'NNG'), ('값', 'NNG'), ('하락', 'NNG'), ('폭', 'NNG'), ('이', 'JKS'), ('커지', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('25', 'SN'), ('개', 'NNBC'), ('자치구', 'NNG'), ('중', 'NNG'), ('21', 'SN'), ('곳', 'NNG'), ('의', 'JKG'), ('아파트', 'NNG'), ('값', 'NNG'), ('이', 'JKS'), ('내렸', 'VV'), ('다', 'EC')]
# [('사진', 'NNG'), ('은', 'JX'), ('23', 'SN'), ('일', 'NNG'), ('서울', 'NNP'), ('강남구', 'NNP'), ('의', 'JKG'), ('한', 'MM'), ('부동산중개', 'NNG'), ('업소', 'NNG')]
# [('금리', 'NNG'), ('인상', 'NNG'), ('과', 'JC'), ('환율', 'NNG'), ('급등', 'NNG'), ('등', 'NNB'), ('의', 'JKG'), ('여파', 'NNG'), ('로', 'JKB'), ('서울', 'NNP'), ('아파트', 'NNG'), ('값', 'NNG'), ('하락', 'NNG'), ('폭', 'NNG'), ('이', 'JKS'), ('커지', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# ...
# [('그', 'NP'), ('는', 'JX'), ('아울러', 'MAG'), ('최근', 'NNG'), ('미국', 'NNG'), ('은행권', 'NNG'), ('불안', 'NNG'), ('에', 'JKB'), ('대해서', 'VV'), ('는', 'JX'), ('“', 'SSO'), ('은행권', 'NNG'), ('상황', 'NNG'), ('은', 'JX'), ('많이', 'MAG'), ('나아졌', 'VV'), ('다', 'EC'), ('”', 'SSC'), ('며', 'EC'), ('“', 'SSO'), ('은행', 'NNG'), ('시스템', 'NNG'), ('은', 'JX'), ('건전', 'NNG'), ('하', 'XSV'), ('고', 'EC'), ('회복', 'NNG'), ('탄력성', 'NNG'), ('이', 'JKS'), ('있', 'VV'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('했', 'VX'), ('다', 'EC')]
# [('그', 'NP'), ('는', 'JX'), ('“', 'SSO'), ('(', 'SSO'), ('마이클', 'NNP'), ('바', 'NNP'), ('금융', 'NNG'), ('감독', 'NNG'), ('부의장', 'NNG'), ('의', 'JKG'), ('주도', 'NNG'), ('로', 'JKB'), ('진행', 'NNG'), ('한', 'XSA'), (')', 'SSC'), ('이번', 'NNG'), ('리뷰', 'NNP'), ('를', 'JKO'), ('통해', 'VV'), ('어떻게', 'MAG'), ('더', 'MAG'), ('건전', 'NNG'), ('한', 'XSA'), ('감독시스템', 'NNG'), ('을', 'JKO'), ('구축', 'NNG'), ('할', 'XSV'), ('수', 'NNB'), ('있', 'VV'), ('을지', 'EC'), ('알', 'VV'), ('게', 'EC'), ('됐', 'VV'), ('다', 'EC'), ('”', 'SSC'), ('며', 'EC'), ('“', 'SSO'), ('이런', 'MM'), ('일', 'NNG'), ('이', 'JKS'), ('다시', 'MAG'), ('일어나', 'VV'), ('지', 'EC'), ('않', 'VX'), ('도록', 'EC'), ('하', 'VX'), ('겠', 'EP'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('강조', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('파월', 'NNP'), ('의장', 'NNG'), ('은', 'JX'), ('JP', 'SL'), ('모건', 'NNP'), ('체이스', 'NNG'), ('가', 'JKS'), ('퍼스트', 'NNP'), ('리퍼블릭', 'NNP'), ('을', 'JKO'), ('인수', 'NNG'), ('한', 'XSA'), ('데', 'NNB'), ('대해서', 'VV'), ('는', 'JX'), ('“', 'SSO'), ('(', 'SSO'), ('대형', 'NNG'), ('은행', 'NNG'), ('이', 'JKS'), ('인수', 'NNG'), ('하', 'XSV'), ('는', 'ETM'), ('게', 'NNB'), (')', 'SSC'), ('그것', 'NP'), ('이', 'JKS'), ('현실', 'NNG'), ('적', 'XSN'), ('”', 'SSC'), ('이', 'VCP'), ('라며', 'EC'), ('“', 'SSO'), ('이번', 'NNG'), ('인수', 'NNG'), ('는', 'JX'), ('좋', 'VA'), ('은', 'ETM'), ('결과', 'NNG'), ('를', 'JKO'), ('가져', 'VV'), ('왔', 'VX'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('말', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('월가', 'NNG'), ('는', 'JX'), ('파월', 'NNP'), ('의장', 'NNG'), ('의', 'JKG'), ('언급', 'NNG'), ('을', 'JKO'), ('두', 'VV'), ('고', 'EC'), ('예상', 'NNG'), ('보다', 'JKB'), ('다소', 'MAG'), ('매파', 'NNG'), ('적', 'XSN'), ('이', 'VCP'), ('라는', 'ETM'), ('데', 'NNB'), ('기우', 'VV'), ('는', 'ETM'), ('분위기', 'NNG'), ('다', 'VCP')]
# [('다이앤', 'NNP'), ('스', 'NNP'), ('웡', 'NNP'), ('크', 'NNP'), ('KPMG', 'SL'), ('수석', 'NNG'), ('이코노미스트', 'NNG'), ('는', 'JX'), ('“', 'SSO'), ('매파', 'NNG'), ('적', 'XSN'), ('인', 'VCP'), ('인상', 'NNG'), ('중단', 'NNG'), ('(', 'SSO'), ('hawkish', 'SL'), ('pause', 'SL'), (')', 'SSC'), ('”', 'SSC'), ('이', 'VCP'), ('라고', 'EC'), ('한', 'MM'), ('마디', 'NNBC'), ('로', 'JKB'), ('요약', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('투자회사', 'NNG'), ('오', 'VV'), ('안다', 'EC'), ('의', 'JKG'), ('에드워드', 'NNP'), ('모야', 'NNG'), ('수석', 'NNG'), ('시장', 'NNG'), ('분석가', 'NNG'), ('는', 'JX'), ('“', 'SSO'), ('이번', 'NNG'), ('금리', 'NNG'), ('인상', 'NNG'), ('이', 'JKS'), ('이번', 'NNG'), ('긴축', 'NNG'), ('사이클', 'NNG'), ('의', 'JKG'), ('마지막', 'NNG'), ('이', 'JKS'), ('될', 'VV'), ('것', 'NNB'), ('같', 'VA'), ('다', 'EC'), ('”', 'SSC'), ('면서도', 'VCP'), ('“', 'SSO'), ('연준', 'NNG'), ('은', 'JX'), ('최소한', 'NNG'), ('올해', 'NNG'), ('연말', 'NNG'), ('까지', 'JX'), ('는', 'JX'), ('금리', 'NNG'), ('를', 'JKO'), ('계속', 'MAG'), ('동결', 'NNG'), ('할', 'XSV'), ('것', 'NNB'), ('”', 'SSC'), ('이', 'VCP'), ('라고', 'EC'), ('말', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('버', 'VV'), ('덴', 'EC'), ('스', 'IC'), ('캐피털', 'NNG'), ('어드바이저', 'NNP'), ('스', 'XSN'), ('의', 'JKG'), ('메건', 'NNP'), ('호너', 'NNP'), ('먼', 'VA'), ('최고투자책임자', 'NNG'), ('(', 'SSO'), ('CIO', 'SL'), (')', 'SSC'), ('는', 'JX'), ('“', 'SSO'), ('이번', 'NNG'), ('에', 'JKB'), ('25', 'SN'), ('bp', 'SL'), ('인상', 'NNG'), ('은', 'JX'), ('필요', 'NNG'), ('했', 'XSV'), ('다', 'EC'), ('”', 'SSC'), ('면서도', 'VCP'), ('“', 'SSO'), ('파월', 'NNP'), ('의장', 'NNG'), ('은', 'JX'), ('다소', 'MAG'), ('매파', 'NNG'), ('적', 'XSN'), ('이', 'VCP'), ('었', 'EP'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('말', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('월가', 'NNG'), ('는', 'JX'), ('일단', 'MAG'), ('연준', 'NNG'), ('이', 'MM'), ('다음', 'NNG'), ('달', 'NNG'), ('부터', 'JX'), ('동결', 'NNG'), ('모드', 'NNG'), ('에', 'JKB'), ('돌입', 'NNG'), ('할', 'XSV'), ('것', 'NNB'), ('으로', 'JKB'), ('예상', 'NNG'), ('하', 'XSV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('CME', 'SL'), ('페드워치', 'NNG'), ('에', 'JKB'), ('따르', 'VV'), ('면', 'EC'), ('시장', 'NNG'), ('은', 'JX'), ('이날', 'NNG'), ('오후', 'NNG'), ('현재', 'MAG'), ('연준', 'NNG'), ('이', 'MM'), ('다음', 'NNG'), ('달', 'NNG'), ('FOMC', 'NNG'), ('에서', 'JKB'), ('금리', 'NNG'), ('를', 'JKO'), ('동결', 'NNG'), ('할', 'XSV'), ('확률', 'NNG'), ('을', 'JKO'), ('99', 'SN'), ('.', 'SY'), ('6', 'SN'), ('%', 'SY'), ('로', 'JKB'), ('보', 'VV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# [('추가', 'NNG'), ('인상', 'NNG'), ('에', 'JKB'), ('나설', 'VV'), ('확률', 'NNG'), ('은', 'JX'), ('0', 'SN'), ('%', 'SY'), ('다', 'EC')]
# [('더', 'MAG'), ('나아가', 'VV'), ('파월', 'NNP'), ('의장', 'NNG'), ('의', 'JKG'), ('언급', 'NNG'), ('과', 'JKB'), ('달리', 'MAG'), ('오', 'VV'), ('는', 'ETM'), ('7', 'SN'), ('월', 'NNBC'), ('부터', 'JX'), ('인하', 'NNG'), ('에', 'JKB'), ('나설', 'VV'), ('것', 'NNB'), ('이', 'VCP'), ('라는', 'ETM'), ('베팅', 'NNG'), ('이', 'IC'), ('점점', 'MAG'), ('많', 'VA'), ('아', 'EC'), ('지', 'VX'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC')]
# []
# 2023-05-04의 문서 12 토큰화 결과:
# [('미국', 'NNG'), ('이', 'JKS'), ('5', 'SN'), ('월', 'NNBC'), ('연방공개시장위원회', 'NNG'), ('FOMC', 'NNG'), ('에서', 'JKB'), ('금리', 'NNG'), ('를', 'JKO'), ('25', 'SN'), ('bp', 'SL'), ('(', 'SSO'), ('1', 'SN'), ('bp', 'SL'), ('=', 'SY'), ('0', 'SN'), ('.', 'SY'), ('01', 'SN'), ('%', 'SY'), ('포인트', 'NNG'), (')', 'SSC'), ('인상', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('로', 'JKB'), ('한', 'MM'), ('가운데', 'NNG'), (',', 'SC'), ('시장', 'NNG'), ('금리', 'NNG'), ('는', 'JX'), ('하락세', 'NNG'), ('를', 'JKO'), ('보일', 'VV'), ('것', 'NNB'), ('이란', 'NNG'), ('전망', 'NNG'), ('이', 'JKS'), ('나왔', 'VV'), ('다', 'EC')]
# [('권기중', 'NNP'), ('IBK투자증권', 'NNP'), ('연구원', 'NNP'), ('은', 'JX'), ('4', 'SN'), ('일', 'NNG'), ('“', 'SSO'), ('현재', 'NNG'), ('기준금리', 'NNG'), ('와', 'JKB'), ('의', 'JKG'), ('스프레드', 'NNG'), ('금리차', 'NNG'), ('는', 'JX'), ('높', 'VA'), ('지만', 'EC'), (',', 'SC'), ('연준', 'NNG'), ('이나', 'JC'), ('시장', 'NNG'), ('이', 'JKS'), ('바라보', 'VV'), ('는', 'ETM'), ('미래', 'NNG'), ('기준금리', 'NNG'), ('전망치', 'NNG'), ('와', 'JKB'), ('의', 'JKG'), ('스프레드', 'NNG'), ('는', 'JX'), ('축소', 'NNG'), ('되', 'XSV'), ('고', 'EC'), ('있', 'VX'), ('다', 'EC'), ('”', 'SSC'), ('면서', 'EC'), ('“', 'SSO'), ('금리', 'NNG'), ('고점', 'NNG'), ('도달', 'NNG'), ('가능성', 'NNG'), ('이', 'JKS'), ('높', 'VA'), ('아', 'EC'), ('진', 'VX'), ('만큼', 'NNB'), ('채권', 'NNG'), ('금리', 'NNG'), ('의', 'JKG'), ('상단', 'NNG'), ('은', 'JX'), ('막혀', 'VV'), ('있', 'VX'), ('을', 'ETM'), ('것', 'NNB'), ('”', 'SSC'), ('이', 'VCP'), ('라며', 'EC'), ('이', 'MM'), ('같이', 'MAG'), ('밝혔', 'VV'), ('다', 'EC')]
# [('연방준비제도', 'NNG'), ('(', 'SSO'), ('연준', 'NNG'), ('·', 'SC'), ('Fed', 'NNG'), (')', 'SSC'), ('는', 'JX'), ('2', 'SN'), ('~', 'SY'), ('3', 'SN'), ('일', 'NNG'), ('(', 'SSO'), ('현지', 'NNG'), ('시간', 'NNG'), (')', 'SSC'), ('이틀', 'NNG'), ('일정', 'NNG'), ('으로', 'JKB'), ('연', 'VV'), ('연방공개시장위원회', 'NNG'), ('FOMC', 'NNG'), ('정례회의', 'NNG'), ('를', 'JKO'), ('통해', 'VV'), ('기준금리', 'NNG'), ('를', 'JKO'), ('5', 'SN'), ('.', 'SY'), ('00', 'SN'), ('~', 'SY'), ('5', 'SN'), ('.', 'SY'), ('25', 'SN'), ('%', 'SY'), ('로', 'JKB'), ('25', 'SN'), ('bp', 'SL'), ('인상', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('지난', 'VV'), ('2007', 'SN'), ('년', 'NNBC'), ('8', 'SN'), ('월', 'NNBC'), ('이후', 'NNG'), ('거의', 'MAG'), ('16', 'SN'), ('년', 'NNBC'), ('만', 'NNB'), ('의', 'JKG'), ('최고치', 'NNG'), ('다', 'EC')]
# [('권', 'NNG'), ('연구원', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('여전히', 'MAG'), ('견고', 'NNG'), ('한', 'XSA'), ('일부', 'NNG'), ('주요', 'NNG'), ('경제', 'NNG'), ('지표', 'NNG'), ('들', 'XSN'), ('을', 'JKO'), ('고려', 'NNG'), ('할', 'XSV'), ('때', 'NNG'), ('이번', 'NNG'), ('연준', 'NNG'), ('의', 'JKG'), ('25', 'SN'), ('bp', 'SL'), ('인상', 'NNG'), ('은', 'JX'), ('불가피', 'NNG'), ('했', 'XSA'), ('을', 'ETM'), ('것', 'NNB'), ('”', 'SSC'), ('이', 'VCP'), ('라며', 'EC'), ('“', 'SSO'), ('확실', 'NNG'), ('하', 'XSA'), ('게', 'EC'), ('물가', 'NNG'), ('가', 'JKS'), ('잡혔', 'VV'), ('다는', 'ETM'), ('신호', 'NNG'), ('가', 'JKS'), ('확인', 'NNG'), ('되', 'XSV'), ('지', 'EC'), ('않', 'VX'), ('은', 'ETM'), ('상황', 'NNG'), ('에서', 'JKB'), ('의', 'JKG'), ('섣부른', 'VA'), ('동결', 'NNG'), ('은', 'JX'), ('시장', 'NNG'), ('내', 'NNB'), ('교란', 'NNG'), ('을', 'JKO'), ('줄', 'VV'), ('수', 'NNB'), ('있', 'VV'), ('었', 'EP'), ('고', 'EC'), ('연준', 'NNG'), ('에', 'JKB'), ('대한', 'VV'), ('신뢰', 'NNG'), ('성', 'XSN'), ('이', 'JKS'), ('크', 'VA'), ('게', 'EC'), ('무너졌', 'VV'), ('을', 'ETM'), ('수', 'NNB'), ('있', 'VV'), ('다', 'EC'), ('”', 'SSC'), ('고', 'EC'), ('설명', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('만약', 'NNG'), ('이번', 'NNG'), ('회의', 'NNG'), ('이전', 'NNG'), ('에', 'JKB'), ('물가', 'NNG'), ('나', 'JC'), ('고용', 'NNG'), ('과', 'JKB'), ('같', 'VA'), ('은', 'ETM'), ('주요', 'NNG'), ('경제', 'NNG'), ('지표', 'NNG'), ('의', 'JKG'), ('둔화세', 'NNG'), ('가', 'JKS'), ('조금', 'MAG'), ('더', 'MAG'), ('확인', 'NNG'), ('되', 'XSV'), ('었', 'EP'), ('더라도', 'EC'), (',', 'SC'), ('인플레이션', 'NNG'), ('이', 'JKS'), ('2', 'SN'), ('%', 'SY'), ('확인', 'NNG'), ('이', 'JKS'), ('되', 'VV'), ('지', 'EC'), ('않', 'VX'), ('은', 'ETM'), ('한', 'MM'), ('연준', 'NNG'), ('은', 'JX'), ('인상', 'NNG'), ('을', 'JKO'), ('단행', 'NNG'), ('했', 'XSV'), ('을', 'ETM'), ('것', 'NNB'), ('이', 'VCP'), ('라는', 'ETM'), ('평가', 'NNG'), ('다', 'VCP')]
# [('권', 'NNG'), ('연구원', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('시장', 'NNG'), ('역시', 'MAJ'), ('25', 'SN'), ('bp', 'SL'), ('인상', 'NNG'), ('에', 'JKB'), ('대해서', 'VV'), ('기대', 'NNG'), ('하', 'XSV'), ('고', 'EC'), ('있', 'VX'), ('었', 'EP'), ('기', 'ETN'), ('때문', 'NNB'), ('에', 'JKB'), (',', 'SC'), ('연준', 'NNG'), ('은', 'JX'), ('이번', 'NNG'), ('회의', 'NNG'), ('에서', 'JKB'), ('인상', 'NNG'), ('할', 'XSV'), ('여력', 'NNG'), ('이', 'JKS'), ('있', 'VA'), ('었', 'EP'), ('을', 'ETM'), ('것', 'NNB'), ('으로', 'JKB'), ('판단', 'NNG'), ('한다', 'XSV'), ('”', 'SSC'), ('고', 'EC'), ('말', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('다만', 'MAJ'), (',', 'SC'), ('그', 'NP'), ('는', 'JX'), ('추가', 'NNG'), ('적', 'XSN'), ('인', 'VCP'), ('금리', 'NNG'), ('인상', 'NNG'), ('은', 'JX'), ('힘들', 'VA'), ('것', 'NNB'), ('이', 'VCP'), ('라', 'EC'), ('주장', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('3', 'SN'), ('월', 'NNBC'), ('FOMC', 'NNG'), ('회의', 'NNG'), ('와', 'JC'), ('대비', 'NNG'), ('해서', 'XSV'), ('연준', 'NNG'), ('의', 'JKG'), ('긴축', 'NNG'), ('스탠스', 'NNG'), ('는', 'JX'), ('확실히', 'MAG'), ('완화', 'NNG'), ('됐', 'XSV'), ('다는', 'ETM'), ('이유', 'NNG'), ('에서', 'JKB'), ('다', 'MAG')]
# [('회견', 'NNG'), ('에서', 'JKB'), ('의', 'JKG'), ('파월', 'NNP'), ('은', 'JX'), ('여전히', 'MAG'), ('물가', 'NNG'), ('안정', 'NNG'), ('의지', 'NNG'), ('를', 'JKO'), ('드러냈', 'VV'), ('지만', 'EC'), ('연준', 'NNG'), ('은', 'JX'), ('이', 'MM'), ('회의', 'NNG'), ('에서', 'JKB'), ('물가', 'NNG'), ('안정', 'NNG'), ('과', 'JC'), ('금융안정', 'NNG'), ('사이', 'NNG'), ('에서', 'JKB'), ('의', 'JKG'), ('균형', 'NNG'), ('을', 'JKO'), ('찾', 'VV'), ('기', 'ETN'), ('위해', 'VV'), ('노력', 'NNG'), ('한', 'XSA'), ('것', 'NNB'), ('으로', 'JKB'), ('보인다', 'VV'), ('”', 'SSC'), ('고', 'EC'), ('설명', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('먼저', 'MAG'), ('제롬', 'NNP'), ('파월', 'NNP'), ('회견', 'NNG'), ('에서', 'JKB'), ('연내', 'NNG'), ('금리', 'NNG'), ('인하', 'NNG'), ('가능성', 'NNG'), ('이', 'JKS'), ('낮', 'VA'), ('을', 'ETM'), ('것', 'NNB'), ('임', 'VCP'), ('을', 'JKO'), ('간접', 'NNG'), ('적', 'XSN'), ('으로', 'JKB'), ('시사', 'NNG'), ('한', 'XSA'), ('가운데', 'NNG'), (',', 'SC'), ('인플레이션율', 'NNG'), ('의', 'JKG'), ('2', 'SN'), ('%', 'SY'), ('도달', 'NNG'), ('의', 'JKG'), ('중요', 'NNG'), ('성', 'XSN'), ('을', 'JKO'), ('강조', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('일자리', 'NNG'), ('도', 'JX'), ('여전히', 'MAG'), ('견고', 'NNG'), ('한', 'XSA'), ('만큼', 'NNB'), (',', 'SC'), ('노동시장', 'NNG'), ('의', 'JKG'), ('둔화', 'NNG'), ('조짐', 'NNG'), ('이', 'JKS'), ('크', 'VA'), ('게', 'EC'), ('보이', 'VV'), ('지', 'EC'), ('않', 'VX'), ('음', 'ETN'), ('을', 'JKO'), ('언급', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('다만', 'MAJ'), (',', 'SC'), ('연준', 'NNG'), ('의', 'JKG'), ('FOMC', 'NNG'), ('성명서', 'NNG'), ('를', 'JKO'), ('보', 'VV'), ('면', 'EC'), ('3', 'SN'), ('월', 'NNBC'), ('성명서', 'NNG'), ('에서', 'JKB'), ('쓰였', 'VV'), ('던', 'ETM'), ('주요', 'NNG'), ('문구', 'NNG'), ('가', 'JKS'), ('삭제', 'NNG'), ('됐', 'XSV'), ('다', 'EC')]
# [('권', 'NNG'), ('연구원', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('이', 'NP'), ('는', 'JX'), ('파월', 'NNP'), ('회견', 'NNG'), ('에서', 'JKB'), ('어떤', 'MM'), ('언급', 'NNG'), ('을', 'JKO'), ('했', 'VV'), ('든지', 'EC'), (',', 'SC'), ('3', 'SN'), ('월', 'NNBC'), ('대비', 'NNG'), ('긴축', 'NNG'), ('부담', 'NNG'), ('이', 'JKS'), ('완화', 'NNG'), ('됐', 'XSV'), ('음', 'ETN'), ('을', 'JKO'), ('시사', 'NNG'), ('한다', 'XSV'), ('”', 'SSC'), ('고', 'EC'), ('강조', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('또', 'MAG'), ('성명서', 'NNG'), ('에서', 'JKB'), ('는', 'JX'), ('지난번', 'NNG'), ('과', 'JC'), ('마찬가지', 'NNG'), ('로', 'JKB'), ('미국', 'NNG'), ('은행', 'NNG'), ('시스템', 'NNG'), ('의', 'JKG'), ('견고', 'NNG'), ('함', 'XSV'), ('을', 'JKO'), ('강조', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('권', 'NNG'), ('연구원', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('이', 'NP'), ('는', 'JX'), ('은행', 'NNG'), ('시스템', 'NNG'), ('의', 'JKG'), ('견고', 'NNG'), ('함', 'XSV'), ('에', 'JKB'), ('대한', 'VV'), ('완벽', 'NNG'), ('한', 'XSA'), ('확신', 'NNG'), ('을', 'JKO'), ('가졌', 'VV'), ('다기', 'ETN'), ('보다', 'JKB'), ('는', 'JX'), (',', 'SC'), ('사람', 'NNG'), ('들', 'XSN'), ('의', 'JKG'), ('불안감', 'NNG'), ('을', 'JKO'), ('잠재우', 'VV'), ('기', 'ETN'), ('위한', 'VV'), ('것', 'NNB'), ('으로', 'JKB'), ('해석', 'NNG'), ('된다', 'XSV'), ('”', 'SSC'), ('고', 'EC'), ('분석', 'NNG'), ('했', 'XSV'), ('다', 'EC')]
# [('권', 'NNG'), ('연구원', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('견고', 'NNG'), ('한', 'XSA'), ('물가', 'NNG'), ('및', 'MAJ'), ('고용', 'NNG'), ('지표', 'NNG'), ('의', 'JKG'), ('흐름', 'NNG'), ('만', 'JX'), ('을', 'JKO'), ('놓', 'VV'), ('고', 'EC'), ('보', 'VX'), ('면', 'EC'), ('연준', 'NNG'), ('의', 'JKG'), ('연내', 'NNG'), ('금리', 'NNG'), ('인하', 'NNG'), ('가능성', 'NNG'), ('은', 'JX'), ('희박', 'NNG'), ('해진다', 'XSA'), ('”', 'SSC'), ('면서도', 'VCP'), ('“', 'SSO'), ('이', 'NP'), ('는', 'JX'), ('추가', 'NNG'), ('적', 'XSN'), ('인', 'VCP'), ('크레딧', 'NNG'), ('위기', 'NNG'), ('가', 'JKS'), ('발생', 'NNG'), ('하', 'XSV'), ('지', 'EC'), ('않', 'VX'), ('았', 'EP'), ('을', 'ETM'), ('때', 'NNG'), ('”', 'SSC'), ('라고', 'VCP'), ('내', 'VX'), ('다', 'EC'), ('봤', 'VX'), ('다', 'EC')]
# [('미국', 'NNG'), ('채', 'NNB'), ('금리', 'NNG'), ('는', 'JX'), ('고점', 'NNG'), ('대비', 'NNG'), ('해서', 'XSV'), ('는', 'JX'), ('많이', 'MAG'), ('하락', 'NNG'), ('했', 'XSV'), ('지만', 'EC'), (',', 'SC'), ('그렇게', 'MAG'), ('빠르', 'VA'), ('게', 'EC'), ('하락', 'NNG'), ('한', 'XSA'), ('만큼', 'NNB'), ('최근', 'NNG'), ('박스권', 'NNG'), ('에', 'JKB'), ('갇힌', 'VV'), ('채', 'NNB'), ('등락', 'NNG'), ('을', 'JKO'), ('반복', 'NNG'), ('하', 'XSV'), ('면서', 'EC'), ('여전히', 'MAG'), ('예년', 'NNG'), ('대비', 'NNG'), ('높', 'VA'), ('은', 'ETM'), ('수준', 'NNG'), ('을', 'JKO'), ('유지', 'NNG'), ('하', 'XSV'), ('고', 'EC'), ('있', 'VX'), ('기', 'ETN'), ('때문', 'NNB'), ('에', 'JKB'), ('여전히', 'MAG'), ('경제주체', 'NNG'), ('들', 'XSN'), ('에게', 'JKB'), ('부담', 'NNG'), ('이', 'JKS'), ('되', 'VV'), ('는', 'ETM'), ('상황', 'NNG'), ('이', 'VCP'), ('다', 'EC')]
# [('권', 'NNG'), ('연구원', 'NNP'), ('은', 'JX'), ('“', 'SSO'), ('당국', 'NNG'), ('의', 'JKG'), ('은행', 'NNG'), ('시스템', 'NNG'), ('구제', 'NNG'), ('의지', 'NNG'), ('가', 'JKS'), ('확인', 'NNG'), ('되', 'XSV'), ('고', 'EC'), ('있', 'VX'), ('지만', 'EC'), (',', 'SC'), ('최근', 'NNG'), ('부각', 'NNG'), ('되', 'XSV'), ('고', 'EC'), ('있', 'VX'), ('는', 'ETM'), ('상업', 'NNG'), ('용', 'XSN'), ('부동산', 'NNG'), ('대출', 'NNG'), ('이슈', 'NNG'), ('나', 'JC'), ('다시', 'MAG'), ('증가', 'NNG'), ('한', 'XSA'), ('연준', 'NNG'), ('계정', 'NNG'), ('의', 'JKG'), ('은행', 'NNG'), ('기간', 'NNG'), ('대출', 'NNG'), ('플', 'NNG'), ('그램', 'NNG'), ('(', 'SSO'), ('BTFP', 'SL'), (')', 'SSC'), ('등', 'NNB'), ('을', 'JKO'), ('주시', 'NNG'), ('해야', 'XSV'), ('한다', 'VX'), ('”', 'SSC'), ('며', 'EC'), ('“', 'SSO'), ('크레딧', 'NNG'), ('불안감', 'NNG'), ('을', 'JKO'), ('반영', 'NNG'), ('하', 'XSV'), ('면서', 'EC'), ('미국', 'NNG'), ('채', 'NNB'), ('금리', 'NNG'), ('는', 'JX'), ('하락', 'NNG'), ('추세', 'NNG'), ('를', 'JKO'), ('계속', 'NNG'), ('해서', 'XSV'), ('보일', 'VV'), ('것', 'NNB'), ('”', 'SSC'), ('이', 'VCP'), ('라고', 'EC'), ('덧붙였', 'VV'), ('다', 'EC')]
# []

# %% [markdown]
# ### 토큰화까지 해뒀습니다 저는 여기까지에요

# %%
# 크롤링 결과물 불러오기 - 중앙일보 뉴스 (8분 소요)
mpck = MPCK()

news_pattern = ['\\[.*\\]','(?<=[가-힣])\\.','\\w{4,}\\@[a-zA-Z0-9\\-]{2,}\\.[a-z]{2,}(\\.[a-z]{2})?','....기자']
bone_pattern = []

result_path = './crawl_result/joongamg_news.json'
df = pd.read_json(result_path)
df = df.sort_values(by=["date"], ascending=False)

for pattern in news_pattern:
    df['content'] = df['content'].apply(lambda x: re.sub(pattern, '', x))
news2_df = df

news2_df['words']=" "
for i, row in df.iterrows() :
    try :
        tmp_df = news2_df['content']

        tokens = mpck.tokenize(tmp_df[i])
        row['words'] = '.'.join(tokens)
        df.loc[i, 'words'] = row['words']

    except Exception as ex :
        print("fail")

news2_df = news2_df.drop(['content', 'title'], axis=1)

# %%
# 크롤링 결과물 불러오기 - 머니투데이 뉴스 (3분 30초)
mpck = MPCK()

news_pattern = ['\\[.*\\]','(?<=[가-힣])\\.','\\w{4,}\\@[a-zA-Z0-9\\-]{2,}\\.[a-z]{2,}(\\.[a-z]{2})?','....기자']
bone_pattern = []

result_path = './crawl_result/moneytoday_news.json'
df = pd.read_json(result_path)
df = df.sort_values(by=["date"], ascending=False) 

for pattern in news_pattern:
    df['content'] = df['content'].apply(lambda x: re.sub(pattern, '', x))
news3_df = df

news3_df['words']=" " 
for i, row in df.iterrows() :

    try :
        tmp_df = news3_df['content']

        tokens = mpck.tokenize(tmp_df[i])
        row['words'] = '.'.join(tokens)
        df.loc[i, 'words'] = row['words']

    except Exception as ex :
        print("fail")

news3_df = news3_df.drop(['content', 'title'], axis=1)

# %%
# 크롤링 결과물 불러오기 - 의사록 
mpck = MPCK()

news_pattern = ['\\[.*\\]','(?<=[가-힣])\\.','\\w{4,}\\@[a-zA-Z0-9\\-]{2,}\\.[a-z]{2,}(\\.[a-z]{2})?','....기자']
bone_pattern = []

result_path = './crawl_result/minutes_re.tsv'
df = pd.read_csv(result_path, sep='\t')

for pattern in news_pattern:
    df['내용'] = df['내용'].apply(lambda x: re.sub(pattern, '', x))
min_df = df

min_df['words']=" "
for i, row in df.iterrows() :
    try :
        tmp_df = min_df['내용']

        tokens = mpck.tokenize(tmp_df[i])
        row['words'] = '.'.join(tokens)
        df.loc[i, 'words'] = row['words']

    except Exception as ex :
        print("fail")

min_df = min_df.drop('내용', axis=1) 
min_df = min_df.rename(columns={'날짜': 'date'})

# %%
# json 파일 구조가 달라져서 수정하고 진행
# import json

# # JSON 파일 읽기
# with open('./crawl_result/bone_report1.json', 'r') as file:
#     data = json.load(file)

# # 새로운 키와 값을 포함하는 리스트 생성
# new_data_list = []
# for key, value in data.items():
#     new_data = {"date": key, "text": value}
#     new_data_list.append(new_data)

# with open('new_data2.json', 'w', encoding='utf-8') as file:
#     json.dump(new_data_list, file, indent=4, ensure_ascii=False)

# %%
# 크롤링 결과물 불러오기 - 채권 보고서 
mpck = MPCK()

news_pattern = ['\\[.*\\]','(?<=[가-힣])\\.','\\w{4,}\\@[a-zA-Z0-9\\-]{2,}\\.[a-z]{2,}(\\.[a-z]{2})?','....기자', '전일', '채권시장']
bone_pattern = []

result_path = './crawl_result/bone_report.json'
df = pd.read_json(result_path)
df = df.sort_values(by=["date"], ascending=False)

for pattern in news_pattern:
    df['text'] = df['text'].apply(lambda x: re.sub(pattern, '', x))
bond_df = df

bond_df['words']=" "
for i, row in df.iterrows() :
    try :
        tmp_df = bond_df['text']

        tokens = mpck.tokenize(tmp_df[i])
        row['words'] = '.'.join(tokens)
        df.loc[i, 'words'] = row['words']

    except Exception as ex :
        print("fail")

bond_df = bond_df.drop('text', axis=1)

index_to_drop = 1179 # date가 없어서 오류나는 인덱스 삭제
bond_df.drop(index_to_drop, inplace=True)

# %%
# 전체 크롤링 데이터들 -> 데이터프레임으로 합치기
crawl = pd.concat([news1_df, news2_df, news3_df, min_df, bond_df])
crawl['date'] = pd.to_datetime(crawl['date']).dt.date
crawl
# Out:
#             date                                              words
# 7952  2024-03-21  마이너스금리/NNG.해제/NNG.엔/NNG.통화/NNG.대비/NNG.약세/NNG.보...
# 7947  2024-03-21  대해/VV.전기차/NNG.적용/NNG.하/VV.있/VV.고압/NNG.적층세라믹콘덴서...
# 7956  2024-03-21  국고채/NNG.시장/NNG.간밤/NNG.흐름/NNG.반영/NNG.하/XSV.강세/N...
# 7953  2024-03-21  달러/NNG.원대/NNG.하락/NNG.출발/NNG.하/VV.fed/NNG.fed/N...
# 7943  2024-03-21  지수/NNG.현지/NNG.일제히/MAG.상승/NNG.하/VV.다우존스산업평균지수/N...
# ...          ...                                                ...
# 2     2008-05-04  금리/NNG.인하/NNG.요구/NNG.부응/NNG.스쳐/VV.나타나/VV.금리/NN...
# 1     2008-04-28  대내외/NNG.요인/NNG.금리/NNG.상반/NNG.되/VV.영향/NNG.미치/VV...
# 20    2008-04-07  하단/NNG.상단/NNG.테스트/NNG.가능성/NNG.무게/NNG.글로벌/NNG.신...
# 0     2008-04-01  동향/NNG.강세/NNG.흐름/NNG.유지/NNG.되/XSV.환율/NNG.정책/NN...
# 39           NaT
#
# [60554 rows x 2 columns]

# %%
# # korean stop words 불러오기
# stopwords_path = 'korean_sotp_words.txt'
# stopwords = []
# with open(stopwords_path, 'r', encoding='utf-8') as file:
#     for line in file:
#         stopwords.append(line.strip())
# print(stopwords)  # 불용어 모음

# %%
# word = []
# for tag in text: #토큰화된 text
#     if tag[1] not in stopwords:
#         if tag[0] not in stopwords:
#             word.append(tag[0])

# %%
# 품사 태깅 제거
import re

def extract_hangul_words(text):
    words = ' '.join(re.findall('[가-힣]+', text))
    return words

crawl['words'] = crawl['words'].apply(extract_hangul_words)

# %%
# 콜금리에 date기준으로 크롤링 칼럼 추가하기
import pandas as pd

# Date 열을 datetime으로 변환하고 인덱스로 설정
call['date'] = pd.to_datetime(call['date'])
call.set_index('date', inplace=True)

crawl['date'] = pd.to_datetime(crawl['date'])
crawl.set_index('date', inplace=True)

# 중복된 인덱스 제거
call = call[~call.index.duplicated()]
crawl = crawl[~crawl.index.duplicated()]

# 동일한 날짜에 대해 열을 합치기
merged_df = pd.concat([call, crawl], axis=1)

# 'date' 열을 다시 열로 변환
merged_df.reset_index(inplace=True)

# 결과 출력
print(merged_df.columns)
print(merged_df)
# Out:
# Index(['date', 'price', 'label', 'words'], dtype='object')
#            date price label                                              words
# 0    2006-05-11   NaN   NaN  조 의거 하 의안 통화정책 방향 상정 하 토의 내용 국내외 경제동향 하 국제 유가 ...
# 1    2006-05-25   NaN   NaN  담당 보가 지급 결제 원활 위하 금융기관 일중 당좌대출 한도규제 폐지 하 일중 당좌...
# 2    2006-06-08   NaN   NaN  조 의거 하 의안 통화정책 방향 상정 하 토의 내용 국내외 경제동향 하 경기 선행 ...
# 3    2006-06-22   NaN   NaN  조건 구비 하 사항 명시 하 차액 결제 참가 기관 자금 조정 적수 보전 이자 정산 ...
# 4    2006-07-07   NaN   NaN  보 금융시장 동향 대하 보고 내용 별첨 조 의거 하 의안 통화정책 방향 상정 하 토...
# ...         ...   ...   ...                                                ...
# 5255 2024-03-22   NaN   NaN  요즘 상당 요금 고지서 한숨 나오 넘 마땅 일자리 구하 못하 건설현장 일용직 하 부...
# 5256 2024-03-24   NaN   NaN  있 건물 외경 고금리 작별 다가섰 전세계 금리 결정 금리 위크 요약 결과 다 고물가...
# 5257 2024-03-25   NaN   NaN  청계 견본주택 시민 단지 모형 살펴보 뉴스 청약 홈 개편 달 문 닫 분양시장 재개 ...
# 5258 2024-03-26   NaN   NaN  동향 약보합 마감 대외 요인 연동 되 흐름 지속 특별 이벤트 부재 속 매수 심리 이...
# 5259        NaT   NaN   NaN
#
# [5260 rows x 4 columns]

# %%
# 'label' 칼럼의 값이 '1(매파)'인 행과 '-1(비둘기파)'인 행으로 데이터프레임 분리
df_P = merged_df[merged_df['label'] == '1']
df_N = merged_df[merged_df['label'] == '-1']

# Nan인 행 제거
df_P = df_P.dropna()
df_N = df_N.dropna()

# 필요없는 열 제거 
df_P = df_P.drop(['date', 'price'], axis=1)
df_N = df_N.drop(['date', 'price'], axis=1)

word_df = pd.concat([df_P,df_N],axis=0)
x_tain = word_df["words"]
y_tain = word_df["label"]

# %%
# # 매파 words 빈도수 체크 
# import pandas as pd
# from nltk.tokenize import word_tokenize
# from collections import Counter

# # 텍스트 칼럼에서 단어 횟수 세기
# text = ' '.join(df_P['words'])  # 텍스트 칼럼의 모든 텍스트를 하나의 문자열로 결합
# tokens = word_tokenize(text)  # 텍스트를 단어로 토큰화
# word_counts = Counter(tokens)  # 단어 등장 횟수 카운트

# # 빈도수가 15 이상인 단어 필터링
# filtered_word_counts = {word: count for word, count in word_counts.items() if count >= 15}

# df_P_counts = pd.DataFrame(filtered_word_counts.items(), columns=['Word', 'Frequency'])
# df_P_counts['P'] = 1 # 라벨링 다시 추가

# %%
# # 비둘기파 words 빈도수 체크
# text = ' '.join(df_N['words'])  # 텍스트 칼럼의 모든 텍스트를 하나의 문자열로 결합
# tokens = word_tokenize(text)  # 텍스트를 단어로 토큰화
# word_counts = Counter(tokens)  # 단어 등장 횟수 카운트

# # 빈도수가 15 이상인 단어 필터링
# filtered_word_counts = {word: count for word, count in word_counts.items() if count >= 15}

# # 데이터프레임 생성
# df_N_counts = pd.DataFrame(filtered_word_counts.items(), columns=['Word', 'Frequency'])
# df_N_counts['N'] = 1

# %%
# df_B_counts.to_csv("dovish_count_1.csv", mode='w')

# %%
# P 1-gram
from collections import defaultdict
import pandas as pd

def generate_ngrams(text, n):
    ngrams = []
    for row in text:
        words = row.split()
        ngrams.extend([' '.join(words[i:i+n]) for i in range(len(words)-n+1)])
    return ngrams

def count_ngrams(ngrams):
    ngram_counts = defaultdict(int)
    for ngram in ngrams:
        ngram_counts[ngram] += 1
    return ngram_counts

n = 1
ngrams = generate_ngrams(df_P['words'], n)
ngram_counts = count_ngrams(ngrams)

# 빈도수가 15 이상인 n-gram만 선택
selected_ngrams = {ngram: count for ngram, count in ngram_counts.items() if count >= 30}

# 데이터프레임으로 변환
P_1gram_df = pd.DataFrame(list(selected_ngrams.items()), columns=['ngram', 'frequency'])
P_1gram_df['P'] = 1
P_1gram_df
# Out:
#      ngram  frequency  P
# 0       약세        506  1
# 1       영향        884  1
# 2       인하       1742  1
# 3       진행        412  1
# 4        되       8059  1
# ...    ...        ... ..
# 1274    대환         32  1
# 1275   코로나        333  1
# 1276    지사         31  1
# 1277   팬데믹         50  1
# 1278  비트코인         34  1
#
# [1279 rows x 3 columns]

# %%
# N 1-gram
from collections import defaultdict
import pandas as pd

def generate_ngrams(text, n):
    ngrams = []
    for row in text:
        words = row.split()
        ngrams.extend([' '.join(words[i:i+n]) for i in range(len(words)-n+1)])
    return ngrams

def count_ngrams(ngrams):
    ngram_counts = defaultdict(int)
    for ngram in ngrams:
        ngram_counts[ngram] += 1
    return ngram_counts

n = 1
ngrams = generate_ngrams(df_N['words'], n)
ngram_counts = count_ngrams(ngrams)

# 빈도수가 15 이상인 n-gram만 선택
selected_ngrams = {ngram: count for ngram, count in ngram_counts.items() if count >= 5}

# 데이터프레임으로 변환
N_1gram_df = pd.DataFrame(list(selected_ngrams.items()), columns=['ngram', 'frequency'])
N_1gram_df['N'] = -1
N_1gram_df
# Out:
#      ngram  frequency  N
# 0       강세        355 -1
# 1      우호적         50 -1
# 2      대내외         50 -1
# 3       여건        193 -1
# 4       인하       1777 -1
# ...    ...        ... ..
# 4065  건전재정          5 -1
# 4066  워크아웃          7 -1
# 4067  장마감후          6 -1
# 4068   부서장          6 -1
# 4069    대차          8 -1
#
# [4070 rows x 3 columns]

# %%
merged_df = pd.merge(P_1gram_df , N_1gram_df , on='ngram', how='inner')
merged_df = merged_df.drop(['P', 'N'], axis=1) 
merged_df = merged_df.rename(columns={'frequency_x': 'P_count'})
merged_df = merged_df.rename(columns={'frequency_y': 'N_count'})
merged_df.set_index('ngram', inplace=True)
merged_df
# Out:
#        P_count  N_count
# ngram
# 약세         506      307
# 영향         884      667
# 인하        1742     1777
# 진행         412      229
# 되         8059     6489
# ...        ...      ...
# 대환          32       14
# 코로나        333      407
# 지사          31        7
# 팬데믹         50       41
# 비트코인        34       22
#
# [1270 rows x 2 columns]

# %%
# merged_df.to_csv("final_count_1.csv", mode='w')

# %% [markdown]
# #### ----------------------------------------------------------- 2_gram ------------------------------------------------------------------

# %%
# 2-gram
from collections import defaultdict
import pandas as pd

def generate_ngrams(text, n):
    ngrams = []
    for row in text:
        words = row.split()
        ngrams.extend([' '.join(words[i:i+n]) for i in range(len(words)-n+1)])
    return ngrams

def count_ngrams(ngrams):
    ngram_counts = defaultdict(int)
    for ngram in ngrams:
        ngram_counts[ngram] += 1
    return ngram_counts

n = 2
ngrams = generate_ngrams(df_P['words'], n)
ngram_counts = count_ngrams(ngrams)

# 빈도수가 15 이상인 n-gram만 선택
selected_ngrams = {ngram: count for ngram, count in ngram_counts.items() if count >= 15}

# 데이터프레임으로 변환
selected_ngrams_df = pd.DataFrame(list(selected_ngrams.items()), columns=['ngram', 'frequency'])
selected_ngrams_df['N'] = 1
selected_ngrams_df
# Out:
#          ngram  frequency  N
# 0       순매수 상위         44  1
# 1       순매도 상위         44  1
# 2      상위 보험기금         22  1
# 3        상위 투신         22  1
# 4       상위 외국인         22  1
# ...        ...        ... ..
# 3083     물가 둔화         17  1
# 3084       목 목         18  1
# 3085     리 오프닝         33  1
# 3086  인플레이션 둔화         31  1
# 3087  특례 보금자리론         16  1
#
# [3088 rows x 3 columns]
