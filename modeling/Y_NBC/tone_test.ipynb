# %%
import pandas as pd

# %%
count_1 = pd.read_csv('./label_result/count_1gram.csv')
count_2 = pd.read_csv('./label_result/count_2gram.csv')
count_3 = pd.read_csv('./label_result/count_3gram.csv')
count_4 = pd.read_csv('./label_result/count_4gram.csv')
count_5 = pd.read_csv('./label_result/count_5gram.csv')

# %%
df = pd.concat([count_1, count_2, count_3, count_4, count_5], ignore_index=True)

# 결과 확인
print(df)
# Out:
#                                         ngram  P_count  N_count
# 0                                    대통령실/NNG      707      137
# 1                                     대변인/NNG      322      161
# 2                                      정부/NNG    16931    14319
# 3                                   제2금융권/NNG      527      625
# 4                                     고금리/NNG     4659     3517
# ...                                       ...      ...      ...
# 87944  당일/NNG 채권시장/NNG 미국/NNG 채권시장/NNG 강세/NNG       39        9
# 87945     금일/NNG 전략/NNG 국고채/NNG 금리/NNG 목표/NNG       71       10
# 87946       부담/NNG 인해/VV 약세/NNG 진행/NNG 전망/NNG       14        9
# 87947   전략/NNG 국고채/NNG 금리/NNG 목표/NNG 매도전략/NNG       41        8
# 87948   국고채/NNG 금리/NNG 목표/NNG 매도전략/NNG 제안/NNG       41        8
#
# [87949 rows x 3 columns]

# %%
import pandas as pd
import numpy as np

df.set_index('ngram', inplace=True)

# 열 추가
k = 0.5
df['P(word|P)'] = (df['P_count'] + k )/ (df['P_count'].sum() + 2 * k)
df['P(word|N)'] = (df['N_count'] + k )/ (df['N_count'].sum() + 2 * k)
df['log(P(word|P))'] = np.log(df['P(word|P)'])
df['log(P(word|N))'] = np.log(df['P(word|N)'])

# 폴라리티 스코어
words = [index_value for index_value in df.index]

# log 활용 underflow 방지
final_P = np.log(df['P_count'].sum() / (df['P_count'].sum() + df['N_count'].sum()) )
final_N = np.log(df['N_count'].sum() / (df['P_count'].sum() + df['N_count'].sum()) )
scores = []
for token in words:
    final_P += df['log(P(word|P))'][token]
    final_N += df['log(P(word|N))'][token]
    final_P = np.exp(final_P)
    final_N = np.exp(final_N)
    a = final_P / (final_P + final_N)
    b = final_N / (final_P + final_N)
    scores.append(a / b)
    # final_P = np.log(df['P_count'].sum() / (df['P_count'].sum() + df['N_count'].sum()) )
    # final_N = np.log(df['N_count'].sum() / (df['P_count'].sum() + df['N_count'].sum()) )
df['Polarity'] = scores
df
# 시드 단어 분류
P_seed_words = []
N_seed_words = []
for word, pola in zip(df.index, df['Polarity']):
    if pola > 1.3 :
        P_seed_words.append(word)
    elif pola < 0.7 :
        N_seed_words.append(word)
    else :
        pass

# %%
P_seed_words
# Out:
# ['대통령실/NNG',
#  '대변인/NNG',
#  '차질/NNG',
#  '대통령/NNG',
#  '주재/NNG',
#  '민생/NNG',
#  '대환/NNG',
#  '영업이익/NNG',
#  '뛰어넘/VV',
#  '고물가/NNG',
#  '인상기/NNG',
#  '세대/NNG',
#  '인상/NNG',
#  '금융부채/NNG',
#  '오를수록/VV',
#  '분위/NNG',
#  '노트/NNG',
#  '고령자/NNG',
#  '달할/VV',
#  '보입니다/VV',
#  '주담대/NNG',
#  '스트레스/NNG',
#  '차주/NNG',
#  '내년/NNG',
#  '최종/NNG',
#  '원리금균등상환방식/NNG',
#  '택할/VV',
#  '씨/NNG',
#  '올리/VV',
#  '올릴/VV',
#  '액티브/NNG',
#  '총괄/NNG',
#  '챗/NNG',
#  '주도주/NNG',
#  '공급망/NNG',
#  '푸드/NNG',
#  '모디/NNG',
#  '총리/NNG',
#  '공장/NNG',
#  '침체/NNG',
#  '압력/NNG',
#  '침체국면/NNG',
#  '제안/NNG',
#  '희소성/NNG',
#  '채굴/NNG',
#  '커질/VA',
#  '식품/NNG',
#  '스토어/NNG',
#  '로봇/NNG',
#  '자율주행/NNG',
#  '연대/NNG',
#  '오전/NNG',
#  '공익/NNG',
#  '방카슈랑스/NNG',
#  '소비자보호법/NNG',
#  '분담/NNG',
#  '맞춰질/VV',
#  '페드워치/NNG',
#  '연이/VV',
#  '벌어지/VV',
#  '역전폭/NNG',
#  '하단/NNG',
#  '짚/VV',
#  '상방/NNG',
#  '사용량/NNG',
#  '인플레이션/NNG',
#  '부연/NNG',
#  '신선식품/NNG',
#  '물가/NNG',
#  '연말/NNG',
#  '긴축/NNG',
#  '물가연동채권/NNG',
#  '정상화/NNG',
#  '오버/NNG',
#  '전무/NNG',
#  '자산시장/NNG',
#  'PCE/NNG',
#  '발걸음/NNG',
#  '나을/VA',
#  '대체투자/NNG',
#  '사업장/NNG',
#  '블라인드/NNG',
#  '병/NNG',
#  '평가손실/NNG',
#  '임대형/NNG',
#  '코어/NNG',
#  '가격지수/NNG',
#  '그/VV',
#  '파운드리/NNG',
#  '선심성/NNG',
#  '봅니다/VX',
#  '탐사/NNG',
#  '시추/NNG',
#  '해상/NNG',
#  '끈적/NNG',
#  '피벗/NNG',
#  '깔렸/VV',
#  '실린다/VV',
#  '통화정책방향회의/NNG',
#  '내려오/VV',
#  '피부/NNG',
#  '생산자/NNG',
#  '뛸/VV',
#  '역전/NNG',
#  '잡히/VV',
#  '시동/NNG',
#  '에너지/NNG',
#  '식료품/NNG',
#  '표면금리/NNG',
#  '금융업계/NNG',
#  '신성장/NNG',
#  '레버리지론/NNG',
#  '발행어음/NNG',
#  '흥미/NNG',
#  '초고/NNG',
#  '최고가/NNG',
#  '실거래/NNG',
#  '면적/NNG',
#  '한남/NNG',
#  '타워/NNG',
#  '팰리스/NNG',
#  '손바뀜/NNG',
#  '부동/NNG',
#  '산원/NNG',
#  '인포/NNG',
#  '막차/NNG',
#  '서초/NNG',
#  '가구/NNG',
#  '불러일으킬/VV',
#  '박탈/NNG',
#  '체이스/NNG',
#  '긴축정책/NNG',
#  '가까워졌/VA',
#  '주최/NNG',
#  '최고점/NNG',
#  '원자재/NNG',
#  '건수/NNG',
#  '확률/NNG',
#  '고신용자/NNG',
#  '국민/NNG',
#  '점수/NNG',
#  '역차별/NNG',
#  '훌쩍/MAG',
#  '연설/NNG',
#  '운용부/NNG',
#  '매파/NNG',
#  '석/NNG',
#  '중립/NNG',
#  '예대금리차/NNG',
#  '공시/NNG',
#  '스텝/NNG',
#  '올렸/VV',
#  '빅/NNG',
#  '원대/NNG',
#  '치솟/VV',
#  '재작년/NNG',
#  '피봇/NNG',
#  '간다고/VV',
#  '메시지/NNG',
#  '프로젝트파이낸싱/NNG',
#  'PF/NNG',
#  '앞당긴/VV',
#  '되돌리/VV',
#  '레인지/NNG',
#  '오후/NNG',
#  '원선/NNG',
#  '물가지수/NNG',
#  '주거비/NNG',
#  '중고차/NNG',
#  '대주단/NNG',
#  '지원금/NNG',
#  '메타/NNG',
#  '화상/NNG',
#  '파트너십/NNG',
#  '스팩/NNG',
#  '케이뱅크/NNG',
#  '해제/NNG',
#  '영상/NNG',
#  '만좌/NNG',
#  '독과점/NNG',
#  '페드/NNG',
#  '저자/NNG',
#  '번영/NNG',
#  '제국/NNG',
#  '민심/NNG',
#  '정권/NNG',
#  '누렸/VV',
#  '자릿수/NNG',
#  '인권/NNG',
#  '수렁/NNG',
#  '침공/NNG',
#  '뛰/VV',
#  '갈팡질팡/MAG',
#  '진심/NNG',
#  '내려왔/VV',
#  '난제/NNG',
#  '임명/NNG',
#  '팬데믹/NNG',
#  '우크라이나/NNG',
#  '실거주/NNG',
#  '유예/NNG',
#  '예정자/NNG',
#  '국토/NNG',
#  '트일/VV',
#  '여당/NNG',
#  '씨앗/NNG',
#  '임대차/NNG',
#  '여경/NNG',
#  '희/NNG',
#  '갱신청구권/NNG',
#  '지지층/NNG',
#  '자이/NNG',
#  '대단/NNG',
#  '사진/NNG',
#  '취재/NNG',
#  '꺾이/VV',
#  '한미/NNG',
#  '취재진/NNG',
#  '일문일답/NNG',
#  '거리/NNG',
#  '외식/NNG',
#  '식비/NNG',
#  '동월/NNG',
#  '인건비/NNG',
#  '원재료/NNG',
#  '호소/NNG',
#  '메뉴/NNG',
#  '참석자/NNG',
#  '전송/NNG',
#  '한눈/NNG',
#  '업데이트/NNG',
#  '송환/NNG',
#  '이송/NNG',
#  '훈련/NNG',
#  '주석/NNG',
#  '화재/NNG',
#  '진압/NNG',
#  '고립/NNG',
#  '학년도/NNG',
#  '축하/NNG',
#  '착용/NNG',
#  '윤/NNG',
#  '당선인/NNG',
#  '원전/NNG',
#  '통단/NNG',
#  '전시회/NNG',
#  '용품/NNG',
#  '피트/NNG',
#  '니스/NNG',
#  '캠핑/NNG',
#  '열린다/VV',
#  '기상청/NNG',
#  '두드리/VV',
#  '넥타이/NNG',
#  '푸른/VA',
#  '통제/NNG',
#  '운행/NNG',
#  '쌓였/VV',
#  '전역/NNG',
#  '정보시스템/NNG',
#  '빚어지/VV',
#  '얼어붙/VV',
#  '열차/NNG',
#  '운전/NNG',
#  '출근길/NNG',
#  '대입/NNG',
#  '시기상조/NNG',
#  '전망대/NNG',
#  '평탄/NNG',
#  '말씀/NNG',
#  '나쁠/VA',
#  '물가수준/NNG',
#  '진척/NNG',
#  '질서/NNG',
#  '주택가격/NNG',
#  '간다는/VX',
#  '유심히/MAG',
#  '배운/VV',
#  '부동산정책/NNG',
#  '공공요금/NNG',
#  '안대/NNG',
#  '상단/NNG',
#  '기조연설/NNG',
#  '재화/NNG',
#  '2차전지/NNG',
#  '이연/NNG',
#  '고강/NNG',
#  '주요인/NNG',
#  '화근/NNG',
#  '뒤늦/VA',
#  '영/NNG',
#  '끌/NNG',
#  '영혼/NNG',
#  '엇박자/NNG',
#  '정점/NNG',
#  '인플레/NNG',
#  '서술/NNG',
#  '속도조절/NNG',
#  '연방준비제도의장/NNG',
#  '어닝서프라이즈/NNG',
#  '데이터센터/NNG',
#  '상무/NNG',
#  '장관/NNG',
#  '연구개발/NNG',
#  '지원계획/NNG',
#  '챔피언/NNG',
#  '레이팅/NNG',
#  '저지른/VV',
#  '테라/NNG',
#  '루나/NNG',
#  '징역형/NNG',
#  '검찰/NNG',
#  '가상/NNG',
#  '코인/NNG',
#  '캡/NNG',
#  '이더리움/NNG',
#  '로이터/NNG',
#  '스와프/NNG',
#  '당일/NNG',
#  '타이트/NNG',
#  '횟수/NNG',
#  '달째/NNG',
#  'FF/NNG',
#  '금융채/NNG',
#  '은행채/NNG',
#  '기업공개/NNG',
#  '호황기/NNG',
#  '꺼낸/VV',
#  '통방문/NNG',
#  '헤드라인/NNG',
#  '질의/NNG',
#  '실질소득/NNG',
#  '내내/MAG',
#  '취업자/NNG',
#  '혼/NNG',
#  '출산율/NNG',
#  '중간재/NNG',
#  '증감/NNG',
#  '시사점/NNG',
#  '전가/NNG',
#  '잠정/NNG',
#  '연휴/NNG',
#  '확정치/NNG',
#  '순부채/NNG',
#  '대칭/NNG',
#  '구매력/NNG',
#  '누증/NNG',
#  '유의미/NNG',
#  '분절/NNG',
#  '여가/NNG',
#  '비은행권/NNG',
#  '신생아/NNG',
#  '특례/NNG',
#  '가파른/VA',
#  '포워드/NNG',
#  '주택도시기금/NNG',
#  '부동산개발/NNG',
#  '채/NNG',
#  '늘어날수록/VV',
#  '적자/NNG',
#  '증권자금/NNG',
#  '급격/NNG',
#  '플레이션/NNG',
#  '가격전가/NNG',
#  '강달러/NNG',
#  '건전재정/NNG',
#  '대손충당금/NNG',
#  '편/NNG',
#  '가공식품/NNG',
#  '내년도/NNG',
#  '택/NNG',
#  '식/NNG',
#  '정세/NNG',
#  '증산/NNG',
#  '입국/NNG',
#  '적자폭/NNG',
#  '고령/NNG',
#  '교란/NNG',
#  '품목/NNG',
#  '무역수지/NNG',
#  '담대/NNG',
#  '가하/NNG',
#  '노동통계국/NNG',
#  '개입/NNG',
#  '겨울/NNG',
#  '온도/NNG',
#  '놀라/VV',
#  '보여서/VV',
#  '공식화/NNG',
#  '환호/NNG',
#  '오래갈/VV',
#  '시름/NNG',
#  '무주택/NNG',
#  '청년/NNG',
#  '청약통장/NNG',
#  '우대형/NNG',
#  '청약저축/NNG',
#  '무주택자/NNG',
#  '당첨/NNG',
#  '공공분양/NNG',
#  '연착륙/NNG',
#  '살피/VV',
#  '원화가치/NNG',
#  '러시아/NNG',
#  '명절/NNG',
#  '여행/NNG',
#  '해외여행/NNG',
#  '럭셔리/NNG',
#  '서학/NNG',
#  '개미/NNG',
#  '단연/MAG',
#  '질주/NNG',
#  '제동/NNG',
#  '독주/NNG',
#  '떠오른/VV',
#  '수다/NNG',
#  '株/NNG',
#  '이미지/NNG',
#  '머스크/NNG',
#  '굳건/NNG',
#  '유행/NNG',
#  '심상/NNG',
#  '물타기/NNG',
#  '구매자/NNG',
#  '수리/NNG',
#  '충전/NNG',
#  '치킨게임/NNG',
#  '반격/NNG',
#  '반값/NNG',
#  '친환경/NNG',
#  '뛰어드/VV',
#  '통계/NNG',
#  '출산/NNG',
#  '여겨졌/VV',
#  '실사/NNG',
#  '응답/NNG',
#  '가전제품/NNG',
#  '내수기업/NNG',
#  '산업통상자원부/NNG',
#  '비제조업/NNG',
#  '역성장/NNG',
#  '캐나다/NNG',
#  '싸우/VV',
#  '규탄/NNG',
#  '사옥/NNG',
#  '오너/NNG',
#  '파킹/NNG',
#  '모임/NNG',
#  '무기/NNG',
#  '촬영/NNG',
#  '공지/NNG',
#  '주민/NNG',
#  '장려금/NNG',
#  '양육/NNG',
#  '만남/NNG',
#  '출생/NNG',
#  '전기요금/NNG',
#  '국영/NNG',
#  'TV/NNG',
#  '월별/NNG',
#  '연구센터/NNG',
#  '캐리/NNG',
#  '갑론을박/NNG',
#  '행보/NNG',
#  '올려야/VV',
#  '가속/NNG',
#  '지양/NNG',
#  '이뤄지기/VV',
#  '맞춰졌/VV',
#  '여론조사/NNG',
#  '사모/NNG',
#  '특별자산/NNG',
#  '빈/NNG',
#  '한계기업/NNG',
#  '회도/NNG',
#  '중앙값/NNG',
#  '놀라울/VA',
#  '제조기업/NNG',
#  '청구서/NNG',
#  '내후년/NNG',
#  '인명/NNG',
#  '주택청약/NNG',
#  '일자/NNG',
#  '상생/NNG',
#  '런/NNG',
#  '확연/NNG',
#  '방역/NNG',
#  '오프닝/NNG',
#  '금리격차/NNG',
#  '멈췄/VV',
#  '철수/NNG',
#  '허가/NNG',
#  '돼지/NNG',
#  '장사/NNG',
#  '소주/NNG',
#  '식사/NNG',
#  '가게/NNG',
#  '폐업/NNG',
#  '노란/VA',
#  '공제금/NNG',
#  '소기업/NNG',
#  '협동조합/NNG',
#  '회가/NNG',
#  '국세/NNG',
#  '건드리/VV',
#  '월평균/NNG',
#  '측은/NNG',
#  '고통/NNG',
#  '금융기업/NNG',
#  '수도/NNG',
#  '도드라졌/VV',
#  '내준/VV',
#  '넘겼/VV',
#  '내줬/VV',
#  '먹거리/NNG',
#  '전광판/NNG',
#  '탑승/NNG',
#  '이르/VA',
#  '가든/NNG',
#  '명령/NNG',
#  '합계출산율/NNG',
#  '출간/NNG',
#  '청년층/NNG',
#  '예산/NNG',
#  '대졸/NNG',
#  '부유/NNG',
#  '재산권/NNG',
#  '그래야/VV',
#  '메울/VV',
#  '식량/NNG',
#  '우울/NNG',
#  '늘린다/VV',
#  '희생/NNG',
#  '블랙스완/NNG',
#  '그래픽/NNG',
#  '민첩/NNG',
#  '기사/NNG',
#  '일러스트/NNG',
#  '불어난/VV',
#  '외상/NNG',
#  '당정/NNG',
#  '가득/MAG',
#  '도약/NNG',
#  '페스티벌/NNG',
#  '야간/NNG',
#  '다채/NNG',
#  '머무를/VV',
#  '요리/NNG',
#  '대회/NNG',
#  '브랜드/NNG',
#  '확고히/MAG',
#  '작품/NNG',
#  '첫걸음/NNG',
#  '즐거움/NNG',
#  '용역/NNG',
#  '힐링/NNG',
#  '음식점/NNG',
#  '총사업비/NNG',
#  '대포/NNG',
#  '폰/NNG',
#  '요금/NNG',
#  '중개업/NNG',
#  '피해자/NNG',
#  '경찰/NNG',
#  '법사/NNG',
#  '추징/NNG',
#  '취약계층/NNG',
#  '취해야/VV',
#  '들썩일/VV',
#  '천천히/MAG',
#  '붙잡/VV',
#  '물류/NNG',
#  '세계화/NNG',
#  '상장/NNG',
#  '순자산/NNG',
#  '올라선/VV',
#  '복리/NNG',
#  '복무/NNG',
#  '국방부/NNG',
#  '여긴다/VV',
#  '인색/NNG',
#  '분석가/NNG',
#  '들였/VV',
#  '미팅/NNG',
#  '클로징/NNG',
#  '제언/NNG',
#  '마이너스성장률/NNG',
#  '질지/VX',
#  '선회/NNG',
#  '놓친/VV',
#  '세율/NNG',
#  '올라간/VV',
#  '올린/VV',
#  '입안자/NNG',
#  '가팔라졌/VA',
#  '연이/NNG',
#  '코앞/NNG',
#  '휘발유/NNG',
#  '엘/NNG',
#  '카메라/NNG',
#  '안보/NNG',
#  '서방/NNG',
#  '루블화/NNG',
#  '숲/NNG',
#  '연료비/NNG',
#  '쉽사리/MAG',
#  '루피/NNG',
#  '부대표/NNG',
#  '임계/NNG',
#  '응답기업/NNG',
#  '연대보증/NNG',
#  '이겨낼/VV',
#  '따를/VV',
#  '예하/NNG',
#  '신임/NNG',
#  '준거/NNG',
#  '사법/NNG',
#  '지지율/NNG',
#  '주담/NNG',
#  '올라와/VV',
#  '래미/NNG',
#  '퍼/VV',
#  '기승/NNG',
#  '교통비/NNG',
#  '미뤘/VV',
#  '국립/NNG',
#  '쳤/VV',
#  '한파/NNG',
#  '실업보험/NNG',
#  '청구자/NNG',
#  '팍팍/NNG',
#  '유류세/NNG',
#  '국산/NNG',
#  '돼지고기/NNG',
#  '우유/NNG',
#  '리츠/NNG',
#  '자금시장/NNG',
#  '주유소/NNG',
#  '통폐합/NNG',
#  '시니어/NNG',
#  '채무조정/NNG',
#  '협력/NNG',
#  '대란/NNG',
#  '비상/NNG',
#  '행정/NNG',
#  '북부/NNG',
#  '스타트업/NNG',
#  '국무/NNG',
#  '동생/NNG',
#  '정상회담/NNG',
#  '관계개선/NNG',
#  '핵/NNG',
#  '미사일/NNG',
#  '의제/NNG',
#  '올랐으나/VV',
#  'ISM/NNG',
#  '하나하나/MAG',
#  '묶이/VV',
#  '수산물/NNG',
#  '해양/NNG',
#  '환경보호/NNG',
#  '플라스틱/NNG',
#  '저감/NNG',
#  '취약차주/NNG',
#  '고용창출/NNG',
#  '순환매/NNG',
#  '고/NNG',
#  '도매/NNG',
#  '보류/NNG',
#  '진료/NNG',
#  '장단기물/NNG',
#  '임재/NNG',
#  '전기/NNG',
#  '가스/NNG',
#  '다중채무/NNG',
#  '사이언스/NNG',
#  '킹/MAG',
#  '줍/VV',
#  '중견/NNG',
#  '나눴/VV',
#  '고삐/NNG',
#  '죄/VV',
#  '1기신도시/NNG',
#  '중구/NNG',
#  '오찬/NNG',
#  '스탠더드/NNG',
#  '혁파/NNG',
#  '어둡/VA',
#  '과자/NNG',
#  '판매점/NNG',
#  '슈퍼마켓/NNG',
#  '요동치/VV',
#  '원화값/NNG',
#  '되돌아갔/VV',
#  '시카고상업거래소/NNG',
#  '루/NNG',
#  '국책연구기관/NNG',
#  '하향세/NNG',
#  '금융시장국/NNG',
#  '잔여/NNG',
#  '지수화/NNG',
#  '쪼그라들/VV',
#  '산업활동/NNG',
#  '바라본/VV',
#  '부동산정보/NNG',
#  '아실/NNG',
#  '혁신성장/NNG',
#  '첨단산업/NNG',
#  '이자보상배율/NNG',
#  '위기극복/NNG',
#  '신산업/NNG',
#  '합한/VV',
#  '당/MAG',
#  '정책위/NNG',
#  '전략산업/NNG',
#  '성장기업/NNG',
#  '민간기업/NNG',
#  '몸살/NNG',
#  '수사/NNG',
#  '피해액/NNG',
#  '비극/NNG',
#  '특별법/NNG',
#  '숨/NNG',
#  '북쪽/NNG',
#  '관통/NNG',
#  '유지보수/NNG',
#  '라인/NNG',
#  '주차장/NNG',
#  '콘크리트/NNG',
#  '낙하/NNG',
#  '파손/NNG',
#  '누수/NNG',
#  '주차/NNG',
#  '점령/NNG',
#  '전기료/NNG',
#  '가구수/NNG',
#  '청구권/NNG',
#  '유찰/NNG',
#  '번번이/MAG',
#  '법사위/NNG',
#  '좌석/NNG',
#  '형량/NNG',
#  '재판부/NNG',
#  '자살/NNG',
#  '범행/NNG',
#  '대검찰청/NNG',
#  '재판/NNG',
#  '가중평균/NNG',
#  '달래/VV',
#  '실리콘밸리/NNG',
#  '위태/NNG',
#  '표지어음/NNG',
#  '양사/NNG',
#  '풀린다/VV',
#  '확약/NNG',
#  '사업구조/NNG',
#  '디스플레이/NNG',
#  '이어진다고/VV',
#  '연결기준/NNG',
#  '메모리/NNG',
#  '환급액/NNG',
#  '오명/NNG',
#  '신년사/NNG',
#  '방정식/NNG',
#  '자동차보험료/NNG',
#  '실손/NNG',
#  '군대/NNG',
#  '운전자/NNG',
#  '군/NNG',
#  '부상/NNG',
#  '코리아디스카운트/NNG',
#  '큽니다/VA',
#  '쉴/VV',
#  '혁신기업/NNG',
#  '줍니다/VV',
#  '암호화폐/NNG',
#  '경착륙/NNG',
#  '근로시간/NNG',
#  '앞질렀/VV',
#  '숙련/NNG',
#  '포브스/NNG',
#  '인구비중/NNG',
#  '시장가치/NNG',
#  '출원/NNG',
#  '안전망/NNG',
#  '참여율/NNG',
#  '러셀지수/NNG',
#  '캐시/NNG',
#  '몰이/NNG',
#  '케이스/NNG',
#  '영업손실/NNG',
#  '적자전환/NNG',
#  '사업부문/NNG',
#  '앤/NNG',
#  '뒷걸음질/NNG',
#  '리뉴얼/NNG',
#  '커머스/NNG',
#  '흑자전환/NNG',
#  '닷컴/NNG',
#  '외관/NNG',
#  '익일/NNG',
#  '벤처기업/NNG',
#  '스리/NNG',
#  '가중치/NNG',
#  '얼라이언스/NNG',
#  '건너뛰/VV',
#  '여객/NNG',
#  '방점/NNG',
#  '대회의실/NNG',
#  '바우처/NNG',
#  '가맹점/NNG',
#  '연고점/NNG',
#  '올라온/VV',
#  '약세장/NNG',
#  '이차전지/NNG',
#  '손익분기점/NNG',
#  '벤처캐피탈/NNG',
#  '본원/NNG',
#  '시가총액상위주/NNG',
#  '트인/VV',
#  '가리키/VV',
#  '원조/NNG',
#  '프라임/NNG',
#  '대표기업/NNG',
#  '스튜어드십코드/NNG',
#  '상장기업/NNG',
#  '대학원/NNG',
#  '우스/NNG',
#  '관리처분/NNG',
#  '택지/NNG',
#  '제의/NNG',
#  '원자/NNG',
#  '잠정치/NNG',
#  '인허가/NNG',
#  '사업지/NNG',
#  '불균형/NNG',
#  '해고/NNG',
#  '올린다/VV',
#  '셰어/NNG',
#  '빗/NNG',
#  '썸/NNG',
#  '음식/NNG',
#  '믹/NNG',
#  '상상/NNG',
#  '두기/NNG',
#  '농축수산물/NNG',
#  '데이터베이스/NNG',
#  '동국/NNG',
#  '폴/NNG',
#  '개량/NNG',
#  '취임식/NNG',
#  '매/NNG',
#  '의복/NNG',
#  '잠재우/VV',
#  '오른다/VV',
#  '하원/NNG',
#  '알린/VV',
#  '전한/VV',
#  '돌연/MAG',
#  '러셀/NNG',
#  '현안/NNG',
#  '분량/NNG',
#  '디지털/NNG',
#  '로비/NNG',
#  '집무실/NNG',
#  '외교/NNG',
#  '국정/NNG',
#  '생필품/NNG',
#  '폭등/NNG',
#  '高/NNG',
#  '과점/NNG',
#  '중대재해/NNG',
#  '오픈런/NNG',
#  '여사/NNG',
#  '초등학생/NNG',
#  '돌봄/VV',
#  '비대/NNG',
#  '지휘/NNG',
#  '회담/NNG',
#  '참모/NNG',
#  '여소/NNG',
#  '야대/NNG',
#  '국익/NNG',
#  '특검/NNG',
#  '공격/NNG',
#  '거짓/NNG',
#  '드렸/VV',
#  '헌법/NNG',
#  '민/NNG',
#  '공작/NNG',
#  '죄송/NNG',
#  '잘못/NNG',
#  '진실/NNG',
#  '출마/NNG',
#  '방한/NNG',
#  '명예/NNG',
#  '수용/NNG',
#  '대중교통/NNG',
#  '참여기업/NNG',
#  '아웃/NNG',
#  '스톡/NNG',
#  '관치금융/NNG',
#  '연합/NNG',
#  '금융정보업체/NNG',
#  '웨/VV',
#  '봉쇄/NNG',
#  '드릴/VX',
#  '올려/VV',
#  '드리/VX',
#  '대통령령/NNG',
#  '술/NNG',
#  '행정처분/NNG',
#  '법무부/NNG',
#  '폭행/NNG',
#  '마스크/NNG',
#  '품질/NNG',
#  '번호판/NNG',
#  '인력난/NNG',
#  '모태펀드/NNG',
#  '캠퍼스/NNG',
#  '에프/NNG',
#  '구간별/NNG',
#  '브루킹스연구소/NNG',
#  '보탰/VV',
#  '손실보상/NNG',
#  '성역/NNG',
#  '견디/VV',
#  '지하/NNG',
#  '임차인/NNG',
#  '기간조정/NNG',
#  '폴란드/NNG',
#  '크레딧스프레드/NNG',
#  '미매각/NNG',
#  '여전채/NNG',
#  '재정거래/NNG',
#  '붙임/NNG',
#  '허리띠/NNG',
#  '졸라매/VV',
#  '방영/NNG',
#  '각별히/MAG',
#  '가까울/VA',
#  '부두/NNG',
#  '컨테이너/NNG',
#  '수출액/NNG',
#  '총장/NNG',
#  '고층/NNG',
#  '가격경쟁/NNG',
#  '이어질까/VV',
#  '관치/NNG',
#  '국민경제/NNG',
#  '도덕/NNG',
#  '국토연구원/NNG',
#  '회관/NNG',
#  '릴레이/NNG',
#  '산연/NNG',
#  '발제/NNG',
#  '상고하저/NNG',
#  '맹점/NNG',
#  '학장/NNG',
#  '주택정책/NNG',
#  '전시/NNG',
#  '전임/NNG',
#  '문재/NNG',
#  '스탠다드/NNG',
#  '매트/NNG',
#  '발행한도/NNG',
#  '키움/VV',
#  '마감일/NNG',
#  '정확도/NNG',
#  '신년/NNG',
#  '동학/NNG',
#  '경유/NNG',
#  '두바이유/NNG',
#  '주둔/NNG',
#  '키/NNG',
#  '오일쇼크/NNG',
#  '카페/NNG',
#  '인스타그램/NNG',
#  '붙잡혔/VV',
#  '선이자/NNG',
#  '진술/NNG',
#  '액도/NNG',
#  '공공/NNG',
#  '끈/NNG',
#  '주무/NNG',
#  '안전진단/NNG',
#  '밟/VV',
#  '히/VV',
#  '마라톤/NNG',
#  '공급관리자협회/NNG',
#  '클라우드/NNG',
#  '외환당국/NNG',
#  '추석/NNG',
#  '재무제표/NNG',
#  '플러스알파/NNG',
#  '전문점/NNG',
#  '고용보고서/NNG',
#  '국무부/NNG',
#  '발사/NNG',
#  '부대/NNG',
#  ...]

# %%
N_seed_words
# Out:
# ['투자부문/NNG',
#  '이득/NNG',
#  'ELS/NNG',
#  '주가연계증권/NNG',
#  '추천/NNG',
#  '스트레스금리/NNG',
#  '하한/NNG',
#  '가산금리/NNG',
#  '여윳돈/NNG',
#  '물/VV',
#  '펀드/NNG',
#  '자산배분/NNG',
#  '수혜/NNG',
#  '투자성향/NNG',
#  '센트/NNG',
#  '집중투자/NNG',
#  '주식형/NNG',
#  '국유기업/NNG',
#  '기대수익률/NNG',
#  '결정짓/VV',
#  '디플레이션/NNG',
#  'ROE/NNG',
#  '굵직/NNG',
#  '판매사/NNG',
#  '인간/NNG',
#  '갤럭시/NNG',
#  '감사원/NNG',
#  '판매자/NNG',
#  '파생상품/NNG',
#  '지켜보/VV',
#  '파생/NNG',
#  '입찰/NNG',
#  '대차/NNG',
#  '인하/NNG',
#  '공매도/NNG',
#  '내수/NNG',
#  '절상/NNG',
#  '완만/NNG',
#  '탈피/NNG',
#  '선진/NNG',
#  '갭/NNG',
#  '엔저/NNG',
#  '제로금리정책/NNG',
#  '고시금리/NNG',
#  '양도성예금증서/NNG',
#  'CD/NNG',
#  '증권사/NNG',
#  '딜러/NNG',
#  '재간접펀드/NNG',
#  '이탈리아/NNG',
#  '제로금리/NNG',
#  '양적완화/NNG',
#  '내릴/VV',
#  '금리동결/NNG',
#  '농산물/NNG',
#  '차별화/NNG',
#  '안전자산/NNG',
#  '공고히/MAG',
#  '철저/NNG',
#  '리그/NNG',
#  '심정/NNG',
#  '강변/NNG',
#  '유로/NNG',
#  '충당부채/NNG',
#  '촉매제/NNG',
#  '디커플링/NNG',
#  '지점/NNG',
#  '낙찰/NNG',
#  '연방준비제도이사회/NNG',
#  '신용등급/NNG',
#  '성향/NNG',
#  '문구/NNG',
#  '내려도/VV',
#  '무방/NNG',
#  '표명/NNG',
#  '삽입/NNG',
#  '급속히/MAG',
#  '울퉁불퉁/MAG',
#  '견해/NNG',
#  '공사비/NNG',
#  '연면적/NNG',
#  '달라질/VA',
#  '완/VV',
#  '뱅/MAG',
#  '제2차세계대전/NNG',
#  '위대/NNG',
#  '서명/NNG',
#  '이스라엘/NNG',
#  '온/NNG',
#  '인하/VV',
#  '적시/NNG',
#  '판다/VV',
#  '할아버지/NNG',
#  '홀/NNG',
#  '반려/NNG',
#  '견/NNG',
#  '상가/NNG',
#  '일감/NNG',
#  '부스/NNG',
#  '피/VV',
#  '계열/NNG',
#  '폭설/NNG',
#  '대주/NNG',
#  '실태/NNG',
#  '임박/NNG',
#  '커뮤니케이션/NNG',
#  '내린다는/VV',
#  '미시/NNG',
#  '국제화/NNG',
#  '받아들여야/VV',
#  '부양정책/NNG',
#  '부양책/NNG',
#  '구조개혁/NNG',
#  '중공업/NNG',
#  '호전/NNG',
#  'guidance/NNG',
#  '내린다고/VV',
#  '신장/NNG',
#  '구조조정/NNG',
#  '비록/MAG',
#  '증세/NNG',
#  '특이/NNG',
#  '역레포/NNG',
#  '혼조세/NNG',
#  '형/NNG',
#  '살리/VV',
#  '장내/NNG',
#  '콜/NNG',
#  '레포/NNG',
#  '콜시장/NNG',
#  '지준/NNG',
#  '모기지론/NNG',
#  '밝혔으며/VV',
#  '염려/NNG',
#  '직접금융/NNG',
#  '발행금액/NNG',
#  '우량물/NNG',
#  '공모주/NNG',
#  '개진/NNG',
#  '동위원/NNG',
#  '제약요인/NNG',
#  '확전/NNG',
#  '당행/NNG',
#  '나타/NNG',
#  '기인/NNG',
#  '미약/NNG',
#  '늦춰질/VV',
#  '려/NNG',
#  '과실/NNG',
#  '히/NNG',
#  '계/NNG',
#  '파급경로/NNG',
#  '정책수단/NNG',
#  '변동금리부/NNG',
#  '저인플레이션/NNG',
#  '유로지역/NNG',
#  '유념/NNG',
#  '금융중개기능/NNG',
#  '비우량/NNG',
#  '국외/NNG',
#  '실효환율/NNG',
#  '주식자금/NNG',
#  '으/NNG',
#  '본드/NNG',
#  '근/NNG',
#  '가계부/NNG',
#  '대두/NNG',
#  '포지션/NNG',
#  '멕시코/NNG',
#  '행이/NNG',
#  '위상/NNG',
#  '비추/VV',
#  '교환/NNG',
#  '부양/NNG',
#  '긴요/NNG',
#  '이루어질/VV',
#  '베이비부머/NNG',
#  '은퇴/NNG',
#  '불안정성/NNG',
#  '왔으며/VX',
#  '공조/NNG',
#  '워크아웃/NNG',
#  '금융경제/NNG',
#  '따/VV',
#  '보였으며/VV',
#  '나갈/VV',
#  '나아갈/VV',
#  '의결문/NNG',
#  '작/NNG',
#  '결정시/NNG',
#  '비우량물/NNG',
#  '신용시장/NNG',
#  '예대율/NNG',
#  '평잔/NNG',
#  '몸담/VV',
#  '요즘/MAG',
#  '오락가락/MAG',
#  '변신/NNG',
#  '뉴질랜드/NNG',
#  '유로존/NNG',
#  '랜드/NNG',
#  '균형점/NNG',
#  '간단히/MAG',
#  '납입금/NNG',
#  '수령/NNG',
#  '강점/NNG',
#  '저금리/NNG',
#  '국을/NNG',
#  '전격/NNG',
#  '불어넣/VV',
#  '비결/NNG',
#  '아이콘/NNG',
#  '재미/NNG',
#  '미친다는/VV',
#  '까먹/VV',
#  '비관론/NNG',
#  '그친다/VV',
#  '할부/NNG',
#  '렌터카/NNG',
#  '차종/NNG',
#  '팔려/VV',
#  '필/VV',
#  '의결권/NNG',
#  '트럼프/NNG',
#  '디자인/NNG',
#  '문의/NNG',
#  '엄마/NNG',
#  '복안/NNG',
#  '상하/NNG',
#  '상환금액/NNG',
#  '주택대출/NNG',
#  '중앙정부/NNG',
#  '쉬/MAG',
#  '라이트/NNG',
#  '메커니즘/NNG',
#  '봄/NNG',
#  '낙인/NNG',
#  '상품권/NNG',
#  '주창/NNG',
#  '무척/MAG',
#  '외자/NNG',
#  '퇴직금/NNG',
#  '연체/NNG',
#  '압류/NNG',
#  '합계/NNG',
#  '이자보상비율/NNG',
#  '내심/NNG',
#  '양회/NNG',
#  '인생/NNG',
#  '까닭/NNG',
#  '살릴/VV',
#  '법칙/NNG',
#  '퇴직/NNG',
#  '다니/VV',
#  '산업화/NNG',
#  '혹시/MAG',
#  '입각/NNG',
#  '각계/NNG',
#  '궁금증/NNG',
#  '박사/NNG',
#  '비춰/VV',
#  '피셔/NNG',
#  '주택구입자금/NNG',
#  '청춘/NNG',
#  '상권/NNG',
#  '발길/NNG',
#  '시너지효과/NNG',
#  '발휘/NNG',
#  '입체/NNG',
#  '이루어진/VV',
#  '가치평가/NNG',
#  '산림/NNG',
#  '체육/NNG',
#  '방문객/NNG',
#  '객실/NNG',
#  '개/NNG',
#  '수법/NNG',
#  '대부업/NNG',
#  '소액결제/NNG',
#  '꾸리/VV',
#  '착수/NNG',
#  '징수/NNG',
#  '저물가/NNG',
#  '고수익/NNG',
#  '거래비용/NNG',
#  '사업소득/NNG',
#  '시납/NNG',
#  '은행지점/NNG',
#  '현역/NNG',
#  '전산/NNG',
#  '사모채/NNG',
#  '금리체계/NNG',
#  '유럽연합/NNG',
#  '데스/NNG',
#  '거시경제정책/NNG',
#  '역력/NNG',
#  '여기/VV',
#  '순이자마진/NNG',
#  '주택구입자/NNG',
#  '매수우위/NNG',
#  '응찰률/NNG',
#  '크레딧채권/NNG',
#  '급기야/MAG',
#  '진료비/NNG',
#  '경제전문가/NNG',
#  '나비/NNG',
#  '중기부/NNG',
#  '위험관리/NNG',
#  '현물시장/NNG',
#  '신흥시장/NNG',
#  '캐리트레이드/NNG',
#  '기법/NNG',
#  '싸/VA',
#  '건설업종/NNG',
#  '돌아온/VV',
#  '저우/NNG',
#  '역세권/NNG',
#  '띨/VV',
#  '하이브리드/NNG',
#  '부실자산/NNG',
#  '사스/NNG',
#  '새희망홀씨/NNG',
#  '불만/NNG',
#  '무장/NNG',
#  '정파/NNG',
#  '제일/NNG',
#  '출로/NNG',
#  '담화/NNG',
#  '강보합세/NNG',
#  '장초/NNG',
#  '채권딜러/NNG',
#  '화폐/NNG',
#  '넘겨/VV',
#  '지급준비금/NNG',
#  '어업/NNG',
#  '탈/VV',
#  '반도체업종/NNG',
#  '매수기회/NNG',
#  '뮤/NNG',
#  '상용차/NNG',
#  '경기민감업종/NNG',
#  '택배/NNG',
#  '하이일드채권/NNG',
#  '신조/NNG',
#  '화살/NNG',
#  '나타낸/VV',
#  '조립/NNG',
#  '사격/NNG',
#  '해외진출/NNG',
#  '수명/NNG',
#  '알파/NNG',
#  '터졌/VV',
#  '환수/NNG',
#  '사기범/NNG',
#  '무단/NNG',
#  '구청/NNG',
#  '변호사/NNG',
#  '준다고/VX',
#  '메워/VV',
#  '일당/NNG',
#  '사연/NNG',
#  '딸/NNG',
#  '아버지/NNG',
#  '매기/VV',
#  '금값/NNG',
#  '금선물/NNG',
#  '강세장/NNG',
#  '기다릴/VV',
#  '결제성자금/NNG',
#  '중기물/NNG',
#  '에이/NNG',
#  '열/NNG',
#  '각기/MAG',
#  '함/NNG',
#  '대출시/NNG',
#  '실직/NNG',
#  '발병/NNG',
#  '살려야/VV',
#  '우량/NNG',
#  '저성장/NNG',
#  '재취업/NNG',
#  '성명서/NNG',
#  '골머리/NNG',
#  '갈아탄/VV',
#  '임원회의/NNG',
#  '시장참가자/NNG',
#  '배송/NNG',
#  '시너지/NNG',
#  '투자전략/NNG',
#  '유로환율/NNG',
#  '합병/NNG',
#  '공인/NNG',
#  '보험약관/NNG',
#  '불공정거래/NNG',
#  '계약서/NNG',
#  '합리/NNG',
#  '유동/NNG',
#  '만기일/NNG',
#  '소각/NNG',
#  '기할/VV',
#  '전기전자/NNG',
#  '가격제한폭/NNG',
#  '니케/NNG',
#  '성장전략/NNG',
#  '마중물/NNG',
#  '거버넌스/NNG',
#  '자사주/NNG',
#  '특임/NNG',
#  '현금자동입출금기/NNG',
#  '트리/NNG',
#  '고분/NNG',
#  '양날/NNG',
#  '땅값/NNG',
#  '재개발재건축/NNG',
#  '대량/NNG',
#  '생성/NNG',
#  '다가온/VV',
#  '소홀/NNG',
#  '쥐꼬리/NNG',
#  '메리트/NNG',
#  '본지/NNG',
#  '투자이익/NNG',
#  '붙이/VV',
#  '상담센터/NNG',
#  '생활자금/NNG',
#  '진/VV',
#  '엇갈리/VV',
#  '헤지펀드/NNG',
#  '부적격/NNG',
#  '강등/NNG',
#  '재테크/NNG',
#  '지면/NNG',
#  '퇴/NNG',
#  '리모델링/NNG',
#  '결렬/NNG',
#  '공천/NNG',
#  '물음/NNG',
#  '룰/NNG',
#  '실무자/NNG',
#  '대하/VV',
#  '인연/NNG',
#  '일수/NNG',
#  '지점장/NNG',
#  '점유/NNG',
#  '한결/MAG',
#  '반가운/VA',
#  '땅/NNG',
#  '이듬해/NNG',
#  '주가지수/NNG',
#  '구실/NNG',
#  '상담/NNG',
#  '위조/NNG',
#  '신분증/NNG',
#  '적발/NNG',
#  '벌금/NNG',
#  '허브/NNG',
#  '움직여야/VV',
#  '타사/NNG',
#  '신분/NNG',
#  'NIM/NNG',
#  '국책은행/NNG',
#  '지표물/NNG',
#  '미연준의장/NNG',
#  '삭제/NNG',
#  'BBB-등급/NNG',
#  '크레딧물/NNG',
#  '섹터별/NNG',
#  '조항/NNG',
#  '담합/NNG',
#  '핀테크/NNG',
#  '결제서비스/NNG',
#  '비효율/NNG',
#  '라임/NNG',
#  '대출태도/NNG',
#  '깐깐/NNG',
#  '고령사회/NNG',
#  '교보/NNG',
#  '민간채권평가사/NNG',
#  '팁/NNG',
#  '출구전략/NNG',
#  '인내심/NNG',
#  '이코노믹/NNG',
#  '챙길/VV',
#  '예멘/NNG',
#  '엔달러/NNG',
#  '금방/MAG',
#  '가까웠/VV',
#  '일희일비/NNG',
#  '트레이드/NNG',
#  '가장/NNG',
#  '착취/NNG',
#  '챙긴/VV',
#  '조직원/NNG',
#  '허위/NNG',
#  '등록업체/NNG',
#  '체불/NNG',
#  '사회간접자본/NNG',
#  '하도급/NNG',
#  '고의/NNG',
#  '사업주/NNG',
#  '펀치/NNG',
#  '최강/NNG',
#  '밝힘/VV',
#  '이라크/NNG',
#  '소멸/NNG',
#  '상품팀/NNG',
#  '영업부/NNG',
#  '발행사/NNG',
#  '플랜트/NNG',
#  '발행시장/NNG',
#  '부서/NNG',
#  '경합/NNG',
#  '좌파/NNG',
#  '양자/NNG',
#  '시공사/NNG',
#  '패소/NNG',
#  '우선협상대상자/NNG',
#  '모델링/NNG',
#  '초저금리/NNG',
#  '지날수록/VV',
#  '민자/NNG',
#  '점장/NNG',
#  'effect/NNG',
#  '상공인/NNG',
#  '보호무역/NNG',
#  '낙후/NNG',
#  '투자수익률/NNG',
#  '가상통화/NNG',
#  '녹/NNG',
#  '일가/NNG',
#  '청신호/NNG',
#  '맴돌/VV',
#  '실로/NNG',
#  '중도금/NNG',
#  '세탁기/NNG',
#  '영화관/NNG',
#  '강연/NNG',
#  '급상승/NNG',
#  '준공후미분양/NNG',
#  '만기일시상환/NNG',
#  '전염/NNG',
#  '진흥공단/NNG',
#  '원한다/VV',
#  '출렁였/VV',
#  '막연/NNG',
#  '블록체인/NNG',
#  '홍수/NNG',
#  '전문지/NNG',
#  '급식/NNG',
#  '자연재해/NNG',
#  '동네/NNG',
#  '건조/NNG',
#  '남아프리카공화국/NNG',
#  '환영/NNG',
#  '되레/MAG',
#  '출국/NNG',
#  '인파/NNG',
#  '산재/NNG',
#  '운/NNG',
#  '개인자금/NNG',
#  '유아/NNG',
#  '환율정책/NNG',
#  '퇴직연금/NNG',
#  '여정/NNG',
#  '보유량/NNG',
#  '금융중개지원대출/NNG',
#  '기축통화국/NNG',
#  '경정/NNG',
#  '멈춰/VV',
#  '고치/VV',
#  '피력/NNG',
#  'strong/NNG',
#  '단서/NNG',
#  '심도/NNG',
#  '시각차/NNG',
#  '던졌/VV',
#  '파장/NNG',
#  '매도우위/NNG',
#  '가한/VV',
#  '임차료/NNG',
#  '다보스포럼/NNG',
#  '귀결/NNG',
#  '잡혀/VV',
#  '버튼/NNG',
#  '정답/NNG',
#  '존경/NNG',
#  '짜/VV',
#  '특사/NNG',
#  '집니다/VX',
#  '물러서/VV',
#  '살포/NNG',
#  '드러난/VV',
#  '넘쳐/VV',
#  '죽음/NNG',
#  '불통/NNG',
#  '고소/NNG',
#  '탄핵/NNG',
#  '백약/NNG',
#  '눌려/VV',
#  '전면전/NNG',
#  '기쁨/NNG',
#  '보편/NNG',
#  '뼈/NNG',
#  '감추/VV',
#  '배임/NNG',
#  '욕망/NNG',
#  '써야/VV',
#  '부동산임대업/NNG',
#  '자진/NNG',
#  '경영자/NNG',
#  '규준/NNG',
#  '지방채/NNG',
#  '흘러/VV',
#  '헬스케어업종/NNG',
#  '못지/VA',
#  '평일/NNG',
#  '대포통장/NNG',
#  '기득권/NNG',
#  '맨/NNG',
#  '배당주/NNG',
#  '춘계/NNG',
#  '유가증권/NNG',
#  '스캔들/NNG',
#  '불량/NNG',
#  '나뉜다/VV',
#  '기본형/NNG',
#  '지명/NNG',
#  '특유/NNG',
#  '참전/NNG',
#  '학대/NNG',
#  '촌/NNG',
#  '일정액/NNG',
#  '수익형/NNG',
#  '걸어서/VV',
#  '홍보관/NNG',
#  '엄정/NNG',
#  '세탁/NNG',
#  '원고/NNG',
#  '떨/VV',
#  '신보/NNG',
#  '요율/NNG',
#  '신용경색/NNG',
#  '달랐/VA',
#  '승승장구/NNG',
#  '무한정/NNG',
#  '떴/VV',
#  '정한다/VV',
#  '가이드/NNG',
#  '하한선/NNG',
#  '설득/NNG',
#  '주택분양/NNG',
#  '시장성/NNG',
#  '기촉법/NNG',
#  '민영/NNG',
#  '경영권/NNG',
#  '겸비/NNG',
#  '박사학위/NNG',
#  '자식/NNG',
#  '후배/NNG',
#  '세출/NNG',
#  '증권회사/NNG',
#  '정해진다/VV',
#  '걸린다는/VV',
#  '저축은행사태/NNG',
#  '판촉/NNG',
#  '끼친/VV',
#  '각광/NNG',
#  '랜딩/NNG',
#  '들어맞/VV',
#  '개연/NNG',
#  '가락/NNG',
#  '기다려야/VV',
#  '지/NNG',
#  '몰릴/VV',
#  '서비스산업/NNG',
#  '원엔/NNG',
#  '노릇/NNG',
#  '잡/NNG',
#  '닦/VV',
#  '오토바이/NNG',
#  '상주/NNG',
#  '일용직/NNG',
#  '가리기/NNG',
#  '핫/NNG',
#  '따져볼/VV',
#  '쉬워/VA',
#  '보인다면/VV',
#  '무제한/NNG',
#  '난이도/NNG',
#  '이익률/NNG',
#  '배수/NNG',
#  '장만/NNG',
#  '조건부/NNG',
#  '공정거래위원회/NNG',
#  '치료비/NNG',
#  '론/NNG',
#  '톱/NNG',
#  '최소가입금액/NNG',
#  '소액투자자/NNG',
#  '폈/VV',
#  '벌금형/NNG',
#  '개포/NNG',
#  '회복국면/NNG',
#  '설령/MAG',
#  '탈퇴/NNG',
#  '기간프리미엄/NNG',
#  '대형사/NNG',
#  '이기/VV',
#  '뜸/NNG',
#  '결함/NNG',
#  '결/NNG',
#  '이차보전/NNG',
#  '클러스터/NNG',
#  '유기/NNG',
#  '조작/NNG',
#  '선결/NNG',
#  '특별지원/NNG',
#  '손쉬운/VA',
#  '끊긴/VV',
#  '현장조사/NNG',
#  '페루/NNG',
#  '중남미/NNG',
#  '제조업체인/NNG',
#  '살려/VV',
#  '조례/NNG',
#  '섬/NNG',
#  '험난/NNG',
#  '신흥국시장/NNG',
#  '선진국시장/NNG',
#  '잠재력/NNG',
#  '멀티/NNG',
#  '포착/NNG',
#  '브렉시트/NNG',
#  '과대평가/NNG',
#  '사업자등록/NNG',
#  '남길/VV',
#  '국공채/NNG',
#  '종신/NNG',
#  '즉시연금/NNG',
#  '월지/NNG',
#  '실비/NNG',
#  '분할상환대출/NNG',
#  '생전/NNG',
#  '뺐/VV',
#  '약하/VA',
#  '준다는/VV',
#  '사물인터넷/NNG',
#  '이점/NNG',
#  '매진/NNG',
#  '해운사/NNG',
#  '자금조달계획/NNG',
#  '축산/NNG',
#  '칭찬/NNG',
#  '오랜만/NNG',
#  '판도/NNG',
#  '표정/NNG',
#  '여수신/NNG',
#  '경비/NNG',
#  '희소식/NNG',
#  '금리구조/NNG',
#  '공짜/NNG',
#  '똑똑/NNG',
#  '어제/NNG',
#  '디플레/NNG',
#  '변한/VV',
#  '가담/NNG',
#  '돌/NNG',
#  '달러지수/NNG',
#  '저축률/NNG',
#  '컨소시엄/NNG',
#  '브라질/NNG',
#  '공정위/NNG',
#  '메신저/NNG',
#  '한껏/MAG',
#  '레버리지효과/NNG',
#  '택지지구/NNG',
#  '살아가/VV',
#  '거래금액/NNG',
#  '이머징마켓/NNG',
#  '내주/NNG',
#  '개수/NNG',
#  '지켜본/VV',
#  '한발/MAG',
#  '일비/NNG',
#  '마침/MAG',
#  '외화채권/NNG',
#  '친/VV',
#  '연체액/NNG',
#  '실명/NNG',
#  '넘어갈/VV',
#  '그리스/NNG',
#  '구제금융/NNG',
#  '포르투갈/NNG',
#  '스페인/NNG',
#  '수입차/NNG',
#  '녹인/NNG',
#  '공상/NNG',
#  '신용공여/NNG',
#  '프리워크아웃/NNG',
#  '롤오버/NNG',
#  '법정관리/NNG',
#  '움직인다면/VV',
#  '생겨/VV',
#  '꼴찌/NNG',
#  '짓눌렀/VV',
#  '부침/NNG',
#  '국방비/NNG',
#  '관료/NNG',
#  '바/NNG',
#  '리보/NNG',
#  '유로달러환율/NNG',
#  '지지력/NNG',
#  '낙폭과대/NNG',
#  '머뭇거리/VV',
#  '영하/NNG',
#  '수량/NNG',
#  '굿/NNG',
#  '움직일지/VV',
#  '투자자산/NNG',
#  '적립금/NNG',
#  '야심/NNG',
#  '전단채/NNG',
#  '능가/NNG',
#  '돋보이/VV',
#  '머/VV',
#  '방송서비스/NNG',
#  '시총상위/NNG',
#  '온건/NNG',
#  '바이어/NNG',
#  '개인연금/NNG',
#  '찾아왔/VV',
#  '억제책/NNG',
#  '공방/NNG',
#  '정책당국자/NNG',
#  '도대체/MAG',
#  '덴마크/NNG',
#  '나간다/VV',
#  '장단점/NNG',
#  '쏠렸/VV',
#  '퇴임/NNG',
#  '갤러리/NNG',
#  '양면/NNG',
#  '코스피200지수/NNG',
#  '만기수익률/NNG',
#  '은행업종/NNG',
#  '마침내/MAG',
#  '튼/VV',
#  '노사정/NNG',
#  '블/NNG',
#  '해피/NNG',
#  '급부상/NNG',
#  '파격/NNG',
#  '마약/NNG',
#  '본다고/VV',
#  '모간/NNG',
#  '반대표/NNG',
#  '외화차입/NNG',
#  '미흡/NNG',
#  '애초/NNG',
#  '흐른/VV',
#  '팽창/NNG',
#  '요지부동/NNG',
#  '상실/NNG',
#  '메일/NNG',
#  '결정과정/NNG',
#  '평등/NNG',
#  '보육/NNG',
#  '새/VV',
#  '플랫/NNG',
#  '수익률차이/NNG',
#  '배당률/NNG',
#  '마이너스통장대출/NNG',
#  '헝가리/NNG',
#  '짭짤/NNG',
#  '종신보험/NNG',
#  '예정이율/NNG',
#  '환매/NNG',
#  '가이드라인/NNG',
#  '분주/NNG',
#  '응급/NNG',
#  '아베노믹스/NNG',
#  '고배/NNG',
#  '랩어카운트/NNG',
#  '일임/NNG',
#  '실전/NNG',
#  '정규/NNG',
#  '학력/NNG',
#  '명함/NNG',
#  '어머니/NNG',
#  '마당/NNG',
#  '해요/VX',
#  '학원/NNG',
#  '곽/NNG',
#  '세기/NNG',
#  '붙인/VV',
#  '안쪽/NNG',
#  '얹/VV',
#  '감자/NNG',
#  '고난/NNG',
#  '골라야/VV',
#  '스튜디오/NNG',
#  '국정감사/NNG',
#  '보증서/NNG',
#  '실업/NNG',
#  '출구/NNG',
#  '트러스트/NNG',
#  '퇴직자/NNG',
#  '채운/VV',
#  '업력/NNG',
#  '차용/NNG',
#  '통념/NNG',
#  '예정일/NNG',
#  '하이브리드차/NNG',
#  '이변/NNG',
#  '심리지표/NNG',
#  '넘쳐나/VV',
#  '정크본드/NNG',
#  '중단기물/NNG',
#  '문항/NNG',
#  '부담금/NNG',
#  '과징금/NNG',
#  '영업익/NNG',
#  '가뭄/NNG',
#  '보증비율/NNG',
#  '늘린다는/VV',
#  '판매수수료/NNG',
#  '파생결합증권/NNG',
#  '힐/NNG',
#  '초고층/NNG',
#  '저층/NNG',
#  '해안/NNG',
#  '치유/NNG',
#  '서민층/NNG',
#  '그림자금융/NNG',
#  '어찌/MAG',
#  '높이/NNG',
#  'ROA/NNG',
#  '공적자금/NNG',
#  '어려우/VA',
#  '끊임없/VA',
#  '비화/NNG',
#  '머문/VV',
#  '이머징국가/NNG',
#  '숏커버/NNG',
#  '차익매물/NNG',
#  '전구간/NNG',
#  '중개수수료/NNG',
#  '역마진/NNG',
#  '금리연동/NNG',
#  '휴업/NNG',
#  '나간다/VX',
#  '시원/NNG',
#  '월급통장/NNG',
#  '치중/NNG',
#  '거쳤/VV',
#  '엘리트/NNG',
#  '공산품/NNG',
#  '낀/VV',
#  '약할/VA',
#  '이룬/VV',
#  '국지/NNG',
#  '스테이/NNG',
#  '채권펀드/NNG',
#  '환매수수료/NNG',
#  '상담원/NNG',
#  '컨벤션/NNG',
#  '생태/NNG',
#  '다우존스산업지수/NNG',
#  '액티브펀드/NNG',
#  '이메일/NNG',
#  '굴복/NNG',
#  '도왔/VV',
#  '개관/NNG',
#  '불입/NNG',
#  '기본이율/NNG',
#  '꽉/MAG',
#  '휘둘리/VV',
#  '산업단지/NNG',
#  '기업가정신/NNG',
#  '통관기준/NNG',
#  '엔환율/NNG',
#  '주변국/NNG',
#  '빨라야/VA',
#  '안전장치/NNG',
#  '구원/NNG',
#  '오래가/VV',
#  '앞뒤/NNG',
#  '산물/NNG',
#  '으로/NNG',
#  '풋옵션/NNG',
#  '숙박업/NNG',
#  '시산/NNG',
#  '비정규직/NNG',
#  '경기순환/NNG',
#  '이루어지/VV',
#  '마다/NNG',
#  '수익구조/NNG',
#  '외/VA',
#  '스왑/NNG',
#  '편입비중/NNG',
#  ...]

# %%
df_P = pd.read_csv('./label_result/df_P_1gram_test.csv')
df_N = pd.read_csv('./label_result/df_N_1gram_test.csv')

# %%
def dict_date(date_list, token_list) :
    date_token = {}
    for date, tokens in zip(date_list, token_list):
        if date not in date_token:
            date_token[date] = [tokens]
        else:
            date_token[date].append(tokens)
    return date_token
# 사용법 csv파일들 tolist() 사용하셔서 list로 만들고 date_token자리에 넣으시면 됩니다.
N_date_list = df_N['date'].tolist()
N_token_list = df_N['tokens'].tolist()
N_date_token = dict_date(N_date_list, N_token_list)

# %%
date_sents_list = {}
for date, sents in N_date_token.items():
    for sent in sents:
        # date_sents_list에 해당 날짜의 리스트가 없으면 새로 생성하고 문장을 추가
        if date not in date_sents_list:
            date_sents_list[date] = [sent]
        # 이미 해당 날짜의 리스트가 존재하면 해당 리스트에 문장을 추가
        else:
            date_sents_list[date].append(sent)

# 문장의 톤 계산
date_sents_tone = {}
for date, sents_list in date_sents_list.items():
    pos = 0
    neg = 0
    for sent in sents_list:
        for word in sent:
            if word in P_seed_words:
                pos += 1
            elif word in N_seed_words:
                neg += 1
    # 날짜별 톤 계산 후 저장
    if pos != 0:
        date_sents_tone[date] = neg / pos
    else:
        date_sents_tone[date] = 0.0

# %%
date_sents_tone
# Out:
# {'2024-03-21': 0.0}

# %%
date_sents_list = {}
for date, sents in N_date_token.items():
    for sent in sents:
        
        if date not in date_sents_list:
            date_sents_list[date] = sent
        else:
            date_sents_list[date].append(sent)
# 문장의 톤 계산
date_sents_tone = {}
for date, sents_list in date_sents_list.items():
    print(sents_list)
    pos = 0
    neg = 0
    for sent in sents_list:
        for word in sent:
            if word in P_seed_words:
                pos += 1
            elif word in N_seed_words:
                neg += 1
    print(pos)
    print(neg)
    # 날짜별 톤 계산 후 저장
    if pos != 0:
        date_sents_tone[date] = neg / pos
    else:
        date_sents_tone[date] = 0.0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 8
#       6             date_sents_list[date] = sent
#       7         else:
# ----> 8             date_sents_list[date].append(sent)
#       9 # 문장의 톤 계산
#      10 date_sents_tone = {}
#
# AttributeError: 'str' object has no attribute 'append'

# %%
date_sents_list
# Out:
# {'2024-03-21': ["[('지난/VV',), ('일/NNG',), ('오후/NNG',), ('업/NNG',), ('비트/NNG',), ('라운지/NNG',), ('비트코인/NNG',), ('시세/NNG',), ('나오/VV',), ('있/VX',)]",
#   "[('뉴스/NNG',), ('최근/NNG',), ('하락세/NNG',), ('보이/VV',), ('가상화폐/NNG',), ('비트코인/NNG',), ('일/NNG',), ('현지/NNG',), ('시간/NNG',), ('미/NNG',), ('연방준비제도/NNG',), ('Fed/NNG',), ('연준/NNG',), ('연내/NNG',), ('차례/NNG',), ('기준금리/NNG',), ('인하/NNG',), ('전망/NNG',), ('유지/NNG',), ('이상/NNG',), ('급등/NNG',)]",
#   "[('미/NNG',), ('가상화폐/NNG',), ('거래소/NNG',), ('코인/NNG',), ('베이스/NNG',), ('따르/VV',), ('미/NNG',), ('시간/NNG',), ('이날/NNG',), ('오후/NNG',), ('서부/NNG',), ('시간/NNG',), ('오후/NNG',), ('현재/MAG',), ('비트코인/NNG',), ('가격/NNG',), ('전/NNG',), ('급등/NNG',), ('달러/NNG',), ('거래/NNG',)]",
#   "[('앞서/MAG',), ('비트코인/NNG',), ('지난/VV',), ('일/NNG',), ('역대/NNG',), ('최고가/NNG',), ('달러/NNG',), ('기록/NNG',), ('뒤/NNG',), ('일/NNG',), ('간/VV',), ('하락/NNG',), ('곡선/NNG',), ('그렸/VV',)]",
#   "[('전날/NNG',), ('고점/NNG',), ('대비/NNG',), ('하락/NNG',), ('달러/NNG',), ('선/NNG',), ('위협/NNG',)]",
#   "[('지난/VV',), ('일/NNG',), ('발표/NNG',), ('생산자/NNG',), ('물가지수/NNG',), ('시장/NNG',), ('예상치/NNG',), ('웃돌/VV',), ('연준/NNG',), ('금리/NNG',), ('인하/NNG',), ('시기/NNG',), ('늦/VA',), ('질/VX',), ('있/VV',), ('우려/NNG',), ('제기/NNG',)]",
#   "[('비트코인/NNG',), ('가격/NNG',), ('끌어올리/VV',), ('현물/NNG',), ('비트코인/NNG',), ('상장지수펀드/NNG',), ('ETF/NNG',), ('자금/NNG',), ('유입/NNG',), ('줄어들/VV',), ('차익실현/NNG',), ('매물/NNG',), ('쏟아져/VV',), ('나왔/VV',)]",
#   "[('연준/NNG',), ('이날/NNG',), ('기준금리/NNG',), ('현재/MAG',), ('수준/NNG',), ('유지/NNG',), ('연내/NNG',), ('금리/NNG',), ('차례/NNG',), ('인하/NNG',), ('기존/NNG',), ('구상/NNG',), ('유지/NNG',), ('가격/NNG',), ('급반등/NNG',)]",
#   "[('투자은행/NNG',), ('애널리스트/NNG',), ('금리/NNG',), ('비트코인/NNG',), ('가격/NNG',), ('사이/NNG',), ('반비례/NNG',), ('관계/NNG',), ('있/VA',), ('왔/VX',), ('연준/NNG',), ('금리/NNG',), ('인상/NNG',), ('때/NNG',), ('시장/NNG',), ('유동성/NNG',), ('회수/NNG',), ('기술주/NNG',), ('함께/MAG',), ('비트코인/NNG',), ('영향/NNG',), ('미쳤/VV',), ('말/NNG',)]",
#   "[('이어/NNG',), ('연준/NNG',), ('금리/NNG',), ('인하/NNG',), ('시장/NNG',), ('유동성/NNG',), ('공급/NNG',), ('비트코인/NNG',), ('같/VA',), ('위험자산/NNG',), ('될/VV',), ('있/VV',), ('비트코인/NNG',), ('때로/MAG',), ('시장/NNG',), ('변동성/NNG',), ('민감/NNG',), ('주/NNG',), ('거래/NNG',), ('특징/NNG',), ('있/VV',), ('언급/NNG',)]",
#   "[('지난/VV',), ('일/NNG',), ('마이너스금리/NNG',), ('정책/NNG',), ('종료/NNG',), ('선언/NNG',), ('일본은행/NNG',), ('연내/NNG',), ('추가/NNG',), ('금리/NNG',), ('인상/NNG',), ('있/VV',), ('관측/NNG',), ('나오/VV',), ('있/VX',)]",
#   "[('빠르/VA',), ('될/VV',), ('가능성/NNG',), ('거론/NNG',)]",
#   "[('일본은행/NNG',), ('총재/NNG',), ('회견/NNG',), ('마이너스금리/NNG',), ('해제/NNG',), ('방안/NNG',), ('대해/VV',), ('설명/NNG',), ('있/VX',)]",
#   "[('일/NNG',), ('신문/NNG',), ('닛케이/NNG',), ('따르/VV',), ('마이너스금리/NNG',), ('해제/NNG',), ('엔저/NNG',), ('계속/MAG',), ('되/VV',), ('물가/NNG',), ('대폭/MAG',), ('상승/NNG',), ('경우/NNG',), ('연내/NNG',), ('추가/NNG',), ('금리/NNG',), ('인상/NNG',), ('있/VV',), ('이란/NNG',), ('예측/NNG',), ('금융시장/NNG',), ('퍼지/NNG',), ('있/VX',)]",
#   "[('앞서/MAG',), ('田/NNG',), ('和/NNG',), ('男/NNG',), ('총재/NNG',), ('일/NNG',), ('회견/NNG',), ('완화/NNG',), ('금융/NNG',), ('환경/NNG',), ('계속/NNG',), ('추가/NNG',), ('금리/NNG',), ('인상/NNG',), ('대해/VV',), ('부정/NNG',), ('않/VX',)]",
#   "[('실제/NNG',), ('일본/NNG',), ('마이너스금리/NNG',), ('정책/NNG',), ('해제/NNG',), ('단기/NNG',), ('금리/NNG',), ('유도/NNG',), ('목표/NNG',), ('끌어올렸/VV',), ('엔저/NNG',), ('상황/NNG',), ('계속/NNG',), ('있/VX',)]",
#   "[('일본/NNG',), ('정부/NNG',), ('조심/NNG',), ('변화/NNG',), ('추구/NNG',), ('전망/NNG',), ('일/NNG',), ('외환시장/NNG',), ('달러/NNG',), ('한때/NNG',), ('엔/NNG',), ('올랐/VV',)]",
#   "[('일본/NNG',), ('대형/NNG',), ('은행/NNG',), ('간부/NNG',), ('대해/VV',), ('닛케이/NNG',), ('엔화가치/NNG',), ('하락/NNG',), ('원유/NNG',), ('가격/NNG',), ('상승/NNG',), ('물가/NNG',), ('계속/MAG',), ('오를/VV',), ('있/VV',)]",
#   "[('이럴/VA',), ('경우/NNG',), ('조기/NNG',), ('추가/NNG',), ('금리/NNG',), ('인상/NNG',), ('강요/NNG',), ('말/NNG',)]",
#   "[('닛케이/NNG',), ('따르/VV',), ('가장/MAG',), ('유력/NNG',), ('금리/NNG',), ('인상/NNG',), ('시기/NNG',)]",
#   "[('금융정책결정회의/NNG',), ('마이너스금리/NNG',), ('해제/NNG',), ('후/NNG',), ('간/NNG',), ('물가/NNG',), ('일본/NNG',), ('경제/NNG',), ('흐름/NNG',), ('판단/NNG',), ('금리/NNG',), ('올린다는/VV',)]",
#   "[('이럴/VA',), ('경우/NNG',), ('급격/NNG',), ('금리/NNG',), ('인상/NNG',), ('느낌/NNG',), ('주/VV',), ('않/VX',), ('시장/NNG',), ('혼란/NNG',), ('억제/NNG',), ('있/VV',)]",
#   "[('미국/NNG',), ('대선/NNG',), ('변수/NNG',)]",
#   "[('공화당/NNG',), ('후보/NNG',), ('확정/NNG',), ('트럼프/NNG',), ('대통령/NNG',), ('당선/NNG',), ('경우/NNG',), ('미국/NNG',), ('연방준비제도/NNG',), ('Fed/NNG',), ('연준/NNG',), ('의장/NNG',), ('재임/NNG',), ('않/VX',), ('가능성/NNG',), ('높/VA',)]",
#   "[('그럴/VA',), ('경우/NNG',), ('시장/NNG',), ('흐름/NNG',), ('크/VA',), ('바뀔/VV',), ('있/VV',), ('전/NNG',), ('움직이/VV',), ('좋/VA',), ('의견/NNG',)]",
#   "[('시나리오/NNG',), ('금리/NNG',), ('인상/NNG',)]"]}

# %%
date_sents_tone
# Out:
# {'2024-03-21': 0.0}

# %%
import ast

# 문자열을 파이썬 리스트로 변환
N_token_list = ast.literal_eval(N_token_list)

# 결과 출력
print(N_token_list[0])

# %%
# tokens = NBC 문장 ngram들
import numpy as np

def NBC_test(df, labels, tokens):
    # 전체 라벨에 대해서 확률들 계산
    # 가장 큰 확률의 라벨 반환
    probs = {}
    idxs = df.index # ngram들
    for label in labels:
        probs[label] = np.log(df[label].sum() / df[labels].sum().sum())
        for token in tokens:
            if token not in idxs: continue
            probs[label] += df[f'log_{label}'][token]
        probs[label] = np.exp(probs[label])

    results = []
    for label in labels:
        results.append( probs[label] / sum(probs.values()) )

    return labels[ np.argmax(results) ]

# %%
# 문장 = ['ngram1', 'ngram2', ...]
# 긍정_사전 = ['ngram1', 'ngram2']
# 부정_사전 = ['ngram4', 'ngram5']

pos = 0
neg = 0
for ngram in N_date_token:
    if ngram in P_seed_words:
        pos += 1
    elif ngram in N_seed_words:
        neg += 1

문장tone = '긍정' if pos > neg else '부정'

문서tone = ['문장1tone', '문장2tone', '문장3tone'] # 긍정 2, 부정 1
문서tone = 2/3 # 긍정쪽으로 0 ~ 1사이의 값 -> 기준금리 범위를 0~1사이로 조정하여 비교
