# %%
from konlpy.tag import Mecab
mecab = Mecab(dicpath=r"C:\mecab\mecab-ko-dic")

# %%
f = open('debenture_data.csv', 'r', encoding='utf-8')
news = f.read()

f.close()

token = [token for token in mecab.pos(news) if token[1] in ['NNG','NNP', 'VV', 'VA', 'VX']]
token

# %%
import pandas as pd

# %%
df = pd.read_json("news_test.json")
df = df.sort_values(by=["date"], ascending=False)
# 데이터프레임 확인
print(df)
# Out:
#          date                                    title  \
# 7  2023-10-19       중동분쟁 고조·미 국채금리 급등…원/달러 환율 1360원 육박
# 3  2023-10-13        닷새만에 반락한 美증시…물가와 채권금리에 눌렸다 [뉴욕마감]
# 5  2023-10-13         소비자물가지수 예상상회에 국채금리 반등…나스닥 -0.63%
# 8  2023-10-12      40년 금리 패러다임 끝났다…주식 줄이고 채권 늘릴 때[오미주]
# 2  2023-10-04          옐런 美 재무장관 "고금리 장기화? 확정된 것은 아니다"
# 1  2023-10-04     "금리 안 떨어진다"…'추석 연휴 끝' 영끌족, 커지는 이자 압박
# 4  2023-09-26        '긴축 종료 시사' ECB 위원 "금리인하 베팅은 시기상조"
# 6  2023-09-26         코람코더원리츠, 고금리 환경 속 안전한 투자처 될 것-삼성
# 0  2023-09-21         계속되는 미국발 '고금리 신호'…국내은행 대출금리도 오른다
# 10 2023-01-10      "금리 도대체 언제 떨어져?"…"올 3분기 정점 찍고 내년부터"
# 11 2023-01-10   자금 '두둑', 급할 게 없다…은행 고금리 특판 왜 안 보이나 했더니
# 9  2023-01-01    [신년사]이창용 한은 총재 "내년에도 물가안정" 기준금리 더 오른다
# 14 2023-01-01        "금리 인상 중단에 채권금리도 하락…개인투자자 단기채 주목"
# 12 2022-01-14  "금리인상 부담" 나스닥 2.5% 급락...테슬라 6.7%↓[뉴욕마감]
# 13 2022-01-13             與 "기존 대출 고정금리 전환 프로그램 도입할 것"
# 15 2020-03-16       필리핀 중앙은행 "금리 0.25%p보다 더 많이 인하할 수도"
# 16 2020-03-16           [Asia오전]美 파격 '제로금리'에도 투심 불안 여전
# 17 2020-03-16        [마켓시그널] 연준 긴급 금리 인하에도… 매수 타이밍은 아직
# 18 2020-03-16           한은, 임시 금통위 개최…사상 첫 0%대 금리 초읽기?
# 19 2020-03-16              금리인하 총알·포탄 다쓴 美연준...남은 무기는?
# 20 2020-03-16         내일부터 주담대 금리 '또' 떨어진다…크게는 0.11%p↓
# 21 2020-03-16                [속보]한은, 임시 금통위 개최…금리인하 전망
#
#                                               content
# 7   원/달러 환율이 장중 한때 1360원에 근접했다. 중동분쟁 긴장감이 고조되고 미국 ...
# 3   나흘 연속 오르던 뉴욕증시가 인플레이션 재발우려와 국채수익률 반등으로 인해 하락세로...
# 5   나흘 연속 오르던 뉴욕증시가 인플레이션 재발우려와 국채수익률 반등으로 인해 하락세로...
# 8   현재 미국 금융시장은 금리 하락세가 막을 내리는 거대한 변화를 겪고 있어 주식 비중...
# 2   재닛 옐런 미국 재무장관이 금리가 장기간 상승세를 유지할 것이란 전망은 '기정사실'...
# 1   미국 국채 금리 급등이 국내 가계대출 금리 상승으로 이어질 것으로 전망된다. 추석 ...
# 4   유럽중앙은행(ECB)이 최근 금리인상 종료를 시사했지만, 금리인하의 통화완화를 논하...
# 6   삼성증권이    에 대한 투자의견을 '매수', 목표주가를 5900원으로 유지했다. ...
# 0   미국 연방준비위원회(연준)이 기준금리를 동결했지만, '매파적 신호'에 국내 은행의 ...
# 10  세계 각국 중앙은행들이 인플레이션(물가상승)을 잡기 위해 빠른 속도로 기준금리를 끌...
# 11  새해 첫 주나 설 명절 전후 쏟아지던 은행 특판(특별판매) 예금이 자취를 감췄다. ...
# 9   이창용 한국은행 총재가 1일 "국민의 생활에 가장 중요한 물가가 목표수준을 상회하는...
# 14  올해 채권시장은 지난해와는 다른 양상을 보일 것으로 예상된다. 올해 미국 연방준비제...
# 12  뉴욕증시가 하락 마감했다. 대형 기술주들이 대거 약세를 보이면서 나스닥은 2% 이상...
# 13  더불어민주당이 금리 상승에 따라 서민과 실수요자의 대출 어려움을 덜어주기 위해 변동...
# 15  (서울=뉴스1) 김서연 기자 = 필리핀 중앙은행이 신종 코로나바이러스 감염증(코로나...
# 16  16일 아시아 주요국 증시가 상승과 하락을 거듭하고 있다. 미 연방준비제도(연준)의...
# 17  시장을 흔드는 이슈들을 날카로운 시선으로 분석하고 오늘 장 대응전략을 제시하는 '마...
# 18  이주열 한국은행 총재가 임시 금융통화위원회 회의를 소집했다. 기준금리 인하 등 최근...
# 19  “연준이 무기고에서 가장 큰 무기를 꺼내들었다”  15일(현지시간) 미국 중앙은행인...
# 20  저금리 기조가 이어지면서 변동형 주택담보대출(주담대) 금리 기준이 되는 코픽스(CO...
# 21                                          16일 한국은행.

# %%
def preprocess_and_tokenize(text):

    tokens = [token for token in mecab.pos(text) if token[1] in ['NNG','NNP', 'VV', 'VA', 'VX']]
    
    return tokens
# "date"를 기준으로 그룹화하여 각 그룹에 대해 토큰화 작업 수행
grouped_tokens = df.groupby("date")["content"].apply(lambda x: [preprocess_and_tokenize(news) for news in x])

# %%
grouped_tokens
# Out:
# date
# 2020-03-16    [[(서울, NNP), (뉴스, NNG), (김서연, NNP), (기자, NNG),...
# 2022-01-13    [[(더불, VV), (민주당, NNP), (금리, NNG), (상승, NNG), ...
# 2022-01-14    [[(뉴욕, NNP), (증시, NNG), (하락, NNG), (마감, NNG), ...
# 2023-01-01    [[(이창용, NNP), (한국은행, NNP), (총재, NNG), (국민, NNG...
# 2023-01-10    [[(세계, NNG), (각국, NNG), (중앙은행, NNG), (인플레이션, N...
# 2023-09-21    [[(미국, NNP), (연방, NNG), (준비, NNG), (위원회, NNG),...
# 2023-09-26    [[(유럽, NNP), (중앙은행, NNG), (최근, NNG), (금리, NNG)...
# 2023-10-04    [[(재닛, NNP), (옐런, NNP), (미국, NNP), (재무, NNG), ...
# 2023-10-12    [[(미국, NNP), (금융, NNG), (시장, NNG), (금리, NNG), ...
# 2023-10-13    [[(나흘, NNG), (연속, NNG), (오르, VV), (뉴욕, NNP), (...
# 2023-10-19    [[(달러, NNG), (환율, NNG), (장중, NNG), (한때, NNG), ...
# Name: content, dtype: object

# %%
# # 결과 출력 (예시)
# for date, tokens_list in grouped_tokens.items():
#     print("Date:", date)
#     for tokens in tokens_list:
#         print(tokens)

# %%
pip install ekonlpy

# %%
import konlpy as kn
import MeCab as mc
import ekonlpy as ek
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
from ekonlpy.tag import Mecab
from ekonlpy.sentiment import MPCK
mpck = MPCK()

df = pd.read_json("news_test.json")
df = df.sort_values(by=["date"], ascending=False)
# 데이터프레임 확인

df['token']="" #빈 값을 가진 token column 추가
df['ngram']="" #빈 값을 가진 ngram column 추가

for i, row in df.iterrows() :

    try :
        tmp_df = df['content']
        #임시 데이터프레임에 불러온 기사의 본문 내용 리스트로 저장

        tokens = mpck.tokenize(tmp_df[i])
        row['token'] = '.'.join(tokens)
        df.loc[i, 'token'] = row['token']
        #eKoNLPy로 tokenizing 한 것을 데이터프레임에 column 추가

        print("success")
        if i % 100 == 0 :
            print('{}/{} : 성공'.format(i, df.shape[0]))
    except Exception as ex :
        print("fail")
        #print("{} : {}".format(i, str(ex)))

df.to_csv("news_test.csv", mode='w')

# %%
df
# Out:
#          date                                    title  \
# 7  2023-10-19       중동분쟁 고조·미 국채금리 급등…원/달러 환율 1360원 육박
# 3  2023-10-13        닷새만에 반락한 美증시…물가와 채권금리에 눌렸다 [뉴욕마감]
# 5  2023-10-13         소비자물가지수 예상상회에 국채금리 반등…나스닥 -0.63%
# 8  2023-10-12      40년 금리 패러다임 끝났다…주식 줄이고 채권 늘릴 때[오미주]
# 2  2023-10-04          옐런 美 재무장관 "고금리 장기화? 확정된 것은 아니다"
# 1  2023-10-04     "금리 안 떨어진다"…'추석 연휴 끝' 영끌족, 커지는 이자 압박
# 4  2023-09-26        '긴축 종료 시사' ECB 위원 "금리인하 베팅은 시기상조"
# 6  2023-09-26         코람코더원리츠, 고금리 환경 속 안전한 투자처 될 것-삼성
# 0  2023-09-21         계속되는 미국발 '고금리 신호'…국내은행 대출금리도 오른다
# 10 2023-01-10      "금리 도대체 언제 떨어져?"…"올 3분기 정점 찍고 내년부터"
# 11 2023-01-10   자금 '두둑', 급할 게 없다…은행 고금리 특판 왜 안 보이나 했더니
# 9  2023-01-01    [신년사]이창용 한은 총재 "내년에도 물가안정" 기준금리 더 오른다
# 14 2023-01-01        "금리 인상 중단에 채권금리도 하락…개인투자자 단기채 주목"
# 12 2022-01-14  "금리인상 부담" 나스닥 2.5% 급락...테슬라 6.7%↓[뉴욕마감]
# 13 2022-01-13             與 "기존 대출 고정금리 전환 프로그램 도입할 것"
# 15 2020-03-16       필리핀 중앙은행 "금리 0.25%p보다 더 많이 인하할 수도"
# 16 2020-03-16           [Asia오전]美 파격 '제로금리'에도 투심 불안 여전
# 17 2020-03-16        [마켓시그널] 연준 긴급 금리 인하에도… 매수 타이밍은 아직
# 18 2020-03-16           한은, 임시 금통위 개최…사상 첫 0%대 금리 초읽기?
# 19 2020-03-16              금리인하 총알·포탄 다쓴 美연준...남은 무기는?
# 20 2020-03-16         내일부터 주담대 금리 '또' 떨어진다…크게는 0.11%p↓
# 21 2020-03-16                [속보]한은, 임시 금통위 개최…금리인하 전망
#
#                                               content  \
# 7   원/달러 환율이 장중 한때 1360원에 근접했다. 중동분쟁 긴장감이 고조되고 미국 ...
# 3   나흘 연속 오르던 뉴욕증시가 인플레이션 재발우려와 국채수익률 반등으로 인해 하락세로...
# 5   나흘 연속 오르던 뉴욕증시가 인플레이션 재발우려와 국채수익률 반등으로 인해 하락세로...
# 8   현재 미국 금융시장은 금리 하락세가 막을 내리는 거대한 변화를 겪고 있어 주식 비중...
# 2   재닛 옐런 미국 재무장관이 금리가 장기간 상승세를 유지할 것이란 전망은 '기정사실'...
# 1   미국 국채 금리 급등이 국내 가계대출 금리 상승으로 이어질 것으로 전망된다. 추석 ...
# 4   유럽중앙은행(ECB)이 최근 금리인상 종료를 시사했지만, 금리인하의 통화완화를 논하...
# 6   삼성증권이    에 대한 투자의견을 '매수', 목표주가를 5900원으로 유지했다. ...
# 0   미국 연방준비위원회(연준)이 기준금리를 동결했지만, '매파적 신호'에 국내 은행의 ...
# 10  세계 각국 중앙은행들이 인플레이션(물가상승)을 잡기 위해 빠른 속도로 기준금리를 끌...
# 11  새해 첫 주나 설 명절 전후 쏟아지던 은행 특판(특별판매) 예금이 자취를 감췄다. ...
# 9   이창용 한국은행 총재가 1일 "국민의 생활에 가장 중요한 물가가 목표수준을 상회하는...
# 14  올해 채권시장은 지난해와는 다른 양상을 보일 것으로 예상된다. 올해 미국 연방준비제...
# 12  뉴욕증시가 하락 마감했다. 대형 기술주들이 대거 약세를 보이면서 나스닥은 2% 이상...
# 13  더불어민주당이 금리 상승에 따라 서민과 실수요자의 대출 어려움을 덜어주기 위해 변동...
# 15  (서울=뉴스1) 김서연 기자 = 필리핀 중앙은행이 신종 코로나바이러스 감염증(코로나...
# 16  16일 아시아 주요국 증시가 상승과 하락을 거듭하고 있다. 미 연방준비제도(연준)의...
# 17  시장을 흔드는 이슈들을 날카로운 시선으로 분석하고 오늘 장 대응전략을 제시하는 '마...
# 18  이주열 한국은행 총재가 임시 금융통화위원회 회의를 소집했다. 기준금리 인하 등 최근...
# 19  “연준이 무기고에서 가장 큰 무기를 꺼내들었다”  15일(현지시간) 미국 중앙은행인...
# 20  저금리 기조가 이어지면서 변동형 주택담보대출(주담대) 금리 기준이 되는 코픽스(CO...
# 21                                          16일 한국은행.
#
#                                                 token ngram
# 7   달러/NNG.장중/NNG.근접/NNG.하/VV.분쟁/NNG.긴장/NNG.고조/NNG...
# 3   연속/NNG.오르/VV.인플레이션/NNG.재발/NNG.우려/NNG.국채/NNG.수익...
# 5   연속/NNG.오르/VV.인플레이션/NNG.재발/NNG.우려/NNG.국채/NNG.수익...
# 8   금융시장/NNG.금리/NNG.하락/NNG.막/NNG.내리/VV.변화/NNG.겪/VV...
# 2   금리/NNG.장기간/NNG.상승/NNG.유지/NNG.하/VV.전망/NNG.기정사실/...
# 1   국채/NNG.금리/NNG.급등/NNG.가계/NNG.대출/NNG.금리/NNG.상승/N...
# 4   ecb/NNG.ecb/NNG.금리/NNG.인상/NNG.종료/NNG.시사/NNG.하/...
# 6   투자의견/NNG.매수/NNG.목표가격/NNG.유지/NNG.하/VV.대출/NNG.만기...
# 0   fed/NNG.fed/NNG.금리/NNG.동결/NNG.하/VV.매파/NNG.신호/N...
# 10  세계/NNG.각국/NNG.인플레이션/NNG.물가/NNG.상승/NNG.잡/VV.위하/...
# 11  새해/NNG.주/NNG.설/NNG.명절/NNG.전후/NNG.쏟/VV.은행/NNG.특...
# 9   국민/NNG.생활/NNG.가장/MAG.중요/NNG.물가/NNG.목표/NNG.수준/N...
# 14  채권시장/NNG.양상/NNG.보/VV.예상/NNG.되/VV.fed/NNG.fed/N...
# 12  하락/NNG.마감/NNG.하/VV.대거/MAG.약세/NNG.보/VV.나스닥/NNG....
# 13  더불/VV.금리/NNG.상승/NNG.서민/NNG.실수요자/NNG.대출/NNG.어렵/...
# 15  뉴스/NNG.기자/NNG.신종/NNG.코로나/NNG.바이러스/NNG.코로나/NNG....
# 16  증시/NNG.상승/NNG.하락/NNG.거듭/MAG.하/VV.미/NNG.fed/NNG...
# 17  시장/NNG.흔드/VV.이슈/NNG.날카롭/VA.시선/NNG.분석/NNG.하/XSV...
# 18  임시/NNG.소집/NNG.하/VV.금리/NNG.인하/NNG.코로나/NNG.확산/NN...
# 19  fed/NNG.무기고/NNG.가장/MAG.크/VA.꺼내/VV.현지/NNG.fed/N...
# 20  저금리/NNG.기조/NNG.이어지/VV.변동/NNG.주택담보대출/NNG.주택담보대출...
# 21
