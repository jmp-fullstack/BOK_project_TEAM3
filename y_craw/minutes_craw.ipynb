# %%
pip install PyMuPDF

# %%
# 의사록 pdf 다운받기
import requests
from bs4 import BeautifulSoup
import os

if not os.path.exists('pdf_files'):
    os.makedirs('pdf_files')

for page_num in range(1, 41): 
    URL = f'https://www.bok.or.kr/portal/bbs/B0000245/list.do?menuNo=200761&pageIndex={page_num}'
    resp = requests.get(URL)
    soup = BeautifulSoup(resp.text, 'html.parser')
    
    li_list = []
    li = soup.find('div', class_='bdLine type2').find('ul').find('li')
    li_li = li.find_next_siblings('li')
    li_list.append(li)
    li_list.extend(li_li)
    
    for j in range(0, len(li_list)):
        try:
            link = li_list[j].find('div', class_='fileGoupBox').find('ul').find_all('li')[1].find('a').attrs['href']
            title = li_list[j].find('div', class_='row').find('span').find('a').find('span').text.strip()
            pdf_url = 'https://www.bok.or.kr' + link

            response = requests.get(pdf_url)
            with open(f'pdf_files/{title}.pdf', 'wb') as f:
                f.write(response.content)

            print(f"{title} 다운로드 완료")

        except Exception as e:
            print("Error:", e)

# %%
import fitz
import os
import pandas as pd
import re

def extract_date_from_filename(file_name):
    # 파일 이름에서 날짜 정보 추출
    match = re.search(r'(\d{4}\.\d{1,2}\.\d{1,2})', file_name)
    
    if match:
        return match.group(1)
    else:
        return None

folder_path = "./minutes_pdfs"
tsv_file = "minutes.tsv"

data = []
file_list = os.listdir(folder_path)

for file_name in file_list:
    file_path = os.path.join(folder_path, file_name)
    
    # 파일인 경우에만 처리
    if os.path.isfile(file_path) and file_name.lower().endswith('.pdf'):
        try:
            doc = fitz.open(file_path)
            # 파일 이름에서 날짜 정보 추출
            date_str = extract_date_from_filename(file_name)
            if date_str:
                try:
                    date = pd.to_datetime(date_str, format='%Y.%m.%d')
                except ValueError:
                    print("Invalid date format in file name:", file_name)
                    date = None
            else:
                print("Date information not found in file name:", file_name)
                date = None
            
            # 파일별로 텍스트 추출하여 데이터에 추가
            text = ""
            for page in doc:
                text += page.get_text()
            
            # 날짜와 텍스트를 데이터에 추가
            data.append({"날짜": date, "내용": text})
            doc.close()
        except Exception as e:
            print("Error processing file:", file_name)
            print(e)
            continue  # 오류 발생한 파일 건너뛰기

df = pd.DataFrame(data)
df.to_csv(tsv_file, sep='\t', index=False)

print("TSV 파일이 생성되었습니다:", tsv_file)

# %%
df
# Out:
#             날짜                                                 내용
# 0   2006-05-11  금융통화위원회 의사록\n2006년도 제10차 회의\n1. 일    자     200...
# 1   2006-05-25  금융통화위원회 의사록\n2006년도 제11차 회의\n1. 일    자     200...
# 2   2006-06-08  금융통화위원회 의사록\n2006년도 제12차 회의\n1. 일    자     200...
# 3   2006-06-22  금융통화위원회 의사록\n2006년도 제13차 회의\n1. 일    자     200...
# 4   2006-07-07  금융통화위원회 의사록\n2006년도 제14차 회의\n1. 일    자     200...
# ..         ...                                                ...
# 308 2023-04-11  2023년도 제7차\n금융통화위원회(정기) 의사록\n한\n국\n은\n행\n- 1 -...
# 309 2024-01-11  2024년도 제1차\n금융통화위원회(정기) 의사록\n한\n국\n은\n행\n- 1 -...
# 310 2024-01-25  2024년도 제2차\n금융통화위원회(정기) 의사록\n한\n국\n은\n행\n- 1 -...
# 311 2024-02-08  2024년도 제3차\n금융통화위원회(정기) 의사록\n한\n국\n은\n행\n- 1 -...
# 312 2024-02-22  2024년도 제4차\n금융통화위원회(정기) 의사록\n한\n국\n은\n행\n- 1 -...
#
# [313 rows x 2 columns]

# %%
import fitz
import os
import pandas as pd
import re
import json

def extract_date_from_filename(file_name):
    # 파일 이름에서 날짜 정보 추출
    match = re.search(r'(\d{4}\.\d{1,2}\.\d{1,2})', file_name)
    
    if match:
        return match.group(1)
    else:
        return None

folder_path = "./minutes_pdfs"
json_file = "minutes.json"

data = []
file_list = os.listdir(folder_path)

for file_name in file_list:
    file_path = os.path.join(folder_path, file_name)
    
    # 파일인 경우에만 처리
    if os.path.isfile(file_path) and file_name.lower().endswith('.pdf'):
        try:
            doc = fitz.open(file_path)
            # 파일 이름에서 날짜 정보 추출
            date_str = extract_date_from_filename(file_name)
            if date_str:
                try:
                    date = pd.to_datetime(date_str, format='%Y.%m.%d')
                except ValueError:
                    print("Invalid date format in file name:", file_name)
                    date = None
            else:
                print("Date information not found in file name:", file_name)
                date = None
            
            # 파일별로 텍스트 추출하여 데이터에 추가
            text = ""
            for page in doc:
                text += page.get_text()
            
            # 날짜와 텍스트를 데이터에 추가
            data.append({"날짜": date.strftime('%Y-%m-%d'), "내용": text})  # 날짜를 문자열로 변환
            doc.close()
        except Exception as e:
            print("Error processing file:", file_name)
            print(e)
            continue  # 오류 발생한 파일 건너뛰기

# JSON 파일로 저장
with open(json_file, 'w') as f:
    json.dump(data, f)

print("JSON 파일이 생성되었습니다:", json_file)
# Out:
# Error processing file: 금융통화위원회 의사록(2015년도 제20차)(2015.10.29.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2015년도 제21차)(2015.11.12.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2015년도 제22차)(2015.11.26.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2015년도 제23차)(2015.12.10.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2015년도 제24차)(2015.12.16.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2015년도 제25차)(2015.12.24.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2016년도 제16차)(2016.8.11.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2016년도 제18차)(2016.9.9.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2016년도 제20차)(2016.10.13.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2016년도 제22차)(2016.11.11.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2016년도 제23차)(2016.11.24.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2016년도 제24차)(2016.12.15.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2016년도 제25차)(2016.12.21.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2016년도 제26차)(2016.12.29.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2016년도 제2차)(2016.1.28.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2016년도 제3차)(2016.2.16).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2016년도 제4차)(2016.2.25.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제10차)(2017.5.25.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제12차)(2017.6.22.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제13차)(2017.7.13.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제15차)(2017.8.10.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제16차)(2017.8.31.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제18차)(2017.9.21.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제1차)(2017.1.13.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제21차)(2017.11.9.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제22차)(2017.11.30.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제23차)(2017.12.7.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제24차)(2017.12.14.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제25차)(2017.12.28.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제2차)(2017.1.26.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2017년도 제8차)(2017.4.27.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2018년도 제19차)(2018.10.18.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2018년도 제22차)(2018.11.30.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2018년도 제3차)(2018.2.8.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2018년도 제4차)(2018.2.27.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2018년도 제5차)(2018.3.8.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2018년도 제6차)(2018.3.29.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2018년도 제7차)(2018.4.12.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2019년도 제12차)(2019.6.20.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2019년도 제24차)(2019.12.26.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2019년도 제4차)(2019.2.28.).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2019년도 제9차)(2019.5.9).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2020년도 제23차)(2020.10.29).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2020년도 제26차)(2020.12.10).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2021년도 제10차)(2021.5.27).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2021년도 제11차)(2021.6.10).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2021년도 제4차)(2021.2.25).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2021년도 제5차)(2021.3.11).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2021년도 제6차)(2021.3.25).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2021년도 제7차)(2021.4.15).pdf
# cannot open broken document
# Error processing file: 금융통화위원회 의사록(2023년도 제16차)(2023.8.24).pdf
# cannot open broken document
# JSON 파일이 생성되었습니다: minutes.json
